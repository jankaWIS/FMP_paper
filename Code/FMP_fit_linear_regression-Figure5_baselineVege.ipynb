# %% [markdown]
# ##### top

# %% [markdown]
# # FMP modelling for Figure 5 (Vegetarian)
#
# This notebook runs Bayesian models on Dataset 5 (dataset with Vegetarian condition) that is described in the article to assess interaction between perception and memory difficulty levels in the FMP. We fit the following formulas to mean score within the condition. Throughout the notebook, I use `task` as a term for memory difficulty levels (M, UD, FD-e, FD-v), `difficulty` as a term for perceptual difficulty levels (1, 2, 3), and `userID` as a variable denoting individual participants. It is the exact same principle and code as the `FMP_fit_linear_regression-Figure5.ipynb` but it sets the FD-v (Vege) as a reference level instead of UD.
#
#
# * Model task and difficulty interaction with user as a random effect. Equation:
#     * _correct_flt ~ task * difficulty + (1|userID)_
# * Model task and difficulty as main effects without interaction with user as a random effect. Equation:
#     * _correct_flt ~ task + difficulty + (1|userID)_
#
#
#
# We model mean accuracy per participant per condition.
#
#
# * [Models](#Models)
# * [Plot results](#Plot-results)
# * [Compare all data](#Compare-all-data)
# * [Save the inference](#Save-the-inference)

# %%
import os, sys
import pickle
from os.path import join as opj
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

az.style.use("arviz-darkgrid")
SEED = 7355608


# Importing module for functions
functions_modul =  "./functions"
sys.path.insert(0, functions_modul)

# import all processing and plotting functions
from bayesian_modelling_functions import fit_model, print_model

path_general = "../"
path_data = opj(path_general, "Data", "datasets")
path_inference_data = opj(path_general, "Data", "model_inference_data")


# set the numer of CPU
num_cpu = min(4, os.cpu_count()-1)
print(f'We will have {num_cpu} cores.\n')

path_dic = {
#     'dataset_1' : opj(path_data, 'FMP_dataset_1.csv'),
#     'dataset_2': opj(path_data, 'FMP_dataset_2.csv'),
#     'dataset_3': opj(path_data, 'FMP_dataset_3.csv'),
#     'concat_datasets_123': opj(path_data, 'FMP_concat_datasets_123.csv'),
#     'dataset_4': opj(path_data, 'FMP_dataset_4.csv'),
    'dataset_5': opj(path_data, 'FMP_dataset_5.csv'),
}


# load all dataframes
df_dic = {}

# only selected cols
select_cols = ['stim1', 'stim2', 'target', 'RT', 'userID', 'difficulty', 'levels', 'task', 'correct_flt', 'order']


for f in path_dic.keys():   
    if f=="first_pilot":
        df_dic[f] = pd.read_csv(path_dic[f], usecols=(set(['correct_check'])|set(select_cols))-set(['correct_flt']))
        # convert boolean answers to floats to be able to do mean
        df_dic[f]['correct_flt'] = df_dic[f].correct_check.astype(float)
    elif 'longitudinal_' in f:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols+['target_loc', 'target_loc_simple'])
    else:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols)
    
    df_dic[f]["Experiment"] = f
        

    # clean
    df_dic[f].reset_index(drop=True, inplace=True)
    
    if 'Unnamed: 0' in df_dic[f].columns:
        df_dic[f].drop('Unnamed: 0', inplace=True, axis=1)
        
    
    # find low performing participants
    tt = df_dic[f].loc[df_dic[f]['task'].isin(['face matching', 'perc', 'perception'])].groupby(['userID', 'difficulty']).correct_flt.mean()

    drop_ptc = tt[tt<=0.5].reset_index().userID.values
    print(f'\nIn {f} dropping {len(drop_ptc)} participants for low accuracy in FM.')
    print(tt[tt<=0.5])

    # and remove them
    df_dic[f] = df_dic[f].loc[~df_dic[f]['userID'].isin(drop_ptc)]
    # clean up
    drop_ptc, tt = None, None
    
    print(f"\nThere is now N={df_dic[f]['userID'].unique().size} participants in {f}.")



#####
# rename the levels
rename_tasks_dic = {'perception':'Matching', 'perc':'Matching', 'blank':'Unfilled Delay', 'faces':'Filled Delay - emotions', 
                    'math':'Filled Delay - math', 'veg':'Filled Delay - veg'}

# define orders
hue_order = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions']
hue_order_math = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - math']
hue_order_veg = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - veg']



# rename the memory task labels in the df
for f in df_dic.keys():
    if f=='noise':
        continue
    df_dic[f]['task'] = df_dic[f]['task'].map(rename_tasks_dic).fillna(df_dic[f]['task'])
# Out:
# We will have 4 cores.
#
#
# In dataset_5 dropping 0 participants for low accuracy in FM.
# Series([], Name: correct_flt, dtype: float64)
#
# There is now N=83 participants in dataset_5.

# %%
# select only specific datasets and prepare them
datasets2fit = ['dataset_5']

df_dic_fit = {}


for f in datasets2fit:
    data=None
    
    # groupby and make means for ptc and condition
    data = df_dic[f].groupby(['userID', 'task', 'difficulty'], observed=False).correct_flt.mean().reset_index()

    # convert all variables to categories
    # categorical_cols = data.columns[data.dtypes == object].tolist() + ['difficulty']
    categorical_cols = ['userID', 'task', 'difficulty']
    for col in categorical_cols:
        if col == 'task':
            # specify the order that we want
            data[col] = pd.Categorical(data[col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - veg'], ordered=True)
            #['Unfilled Delay', 'Matching', 'Filled Delay - emotions']
            
            # also do it for the original datasets
            df_dic[f][col] = pd.Categorical(df_dic[f][col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - veg'], ordered=True)
        else:
            data[col] = data[col].astype("category")
            df_dic[f][col] = df_dic[f][col].astype("category")

    # check
    print('\n',f)
    df_dic[f].info()
        
    # save
    df_dic_fit[f] = data.copy()

# # drop them for now
# data[data.correct_flt.isna()]
# Out:
#  dataset_5
# <class 'pandas.core.frame.DataFrame'>
# Index: 19920 entries, 0 to 19919
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userID       19920 non-null  category
#  1   target       19920 non-null  object
#  2   stim1        19920 non-null  object
#  3   stim2        19920 non-null  object
#  4   correct_flt  19534 non-null  float64
#  5   RT           19534 non-null  float64
#  6   task         19920 non-null  category
#  7   order        19920 non-null  int64
#  8   difficulty   19920 non-null  category
#  9   levels       19920 non-null  int64
#  10  Experiment   19920 non-null  object
# dtypes: category(3), float64(2), int64(2), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Model as means
# [top](#top)

# %%
model_assumptions = {
    "correct_flt ~ task * difficulty + (1|userID)": "Each user has their own baseline performance, but the effect of task and difficulty is assumed to be the same across all users.",
    "correct_flt ~ task + difficulty + (1|userID)": "Assumes that each user has their own baseline performance, but the effects of task and difficulty are consistent across all users without any interaction between task and difficulty.",
}

# define what we want to run
base_lvl = ['Filled Delay - veg', 'Matching', 'Unfilled Delay', 'Filled Delay - emotions']
formulas2run = [
    "correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)",
    "correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)",
]

# %%
# define where we will store the results
model_dic_bernoulli = {}
result_dic_bernoulli = {}

for f in df_dic_fit.keys():
    print(f'\nFitting dataset {f}\n')
    # create datasets
    if f not in model_dic_bernoulli.keys():
        model_dic_bernoulli[f] = {}
    if f not in result_dic_bernoulli.keys():
        result_dic_bernoulli[f] = {}
    
    for formula in formulas2run:
        print(f'\nFitting formula {formula}\n')
    
        model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula] = fit_model(formula, df_dic_fit[f], categorical_cols, base_lvl=base_lvl,
                                                                                      num_cpu=num_cpu, check_priors=False, sample_priors=False)
# Out:
# Sampling 4 chains, 0 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:22
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 23 seconds.

# %%
model_dic_bernoulli[f][formulas2run[0]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 996
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7405, sigma: 0.7299)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8952 0.8952 0.8952])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8223 0.8223])
#             C(task, levels=base_lvl):difficulty ~ Normal(mu: [0. 0. 0. 0. 0. 0.], sigma: [1.4025 1.4025
#                 1.4025 1.4025 1.4025 1.4025])
#
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.7299))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.155)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
model_dic_bernoulli[f][formulas2run[1]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 996
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7405, sigma: 0.6714)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8952 0.8952 0.8952])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8223 0.8223])
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.6714))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.155)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# ### check priors

# %%
model_dic_bernoulli[f][formulas2run[0]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), C(task, levels=base_lvl):difficulty, Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nMatching, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nMatching, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 2'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
model_dic_bernoulli[f][formulas2run[1]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>]], dtype=object)

# %% [markdown]
# ### check posterior

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[0]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[1]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %% [markdown]
# ---
# ## Plot results

# %% [markdown]
# ## FMP dataset 6 -- with Vege condition
# [top](#top)

# %%
f = 'dataset_5'

print(f'Dataset: {f}')
for formula in formulas2run:
    print(f'\nFitting formula {formula}\n')
    print_model(model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula])
# Out:
# Dataset: dataset_5
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1009]  0.022  0.031  -0.035    0.080      0.000    0.000    3816.0
# 1|userID[s_102]  -0.059  0.030  -0.117   -0.005      0.000    0.000    4213.0
# 1|userID[s_1022]  0.060  0.031   0.004    0.118      0.000    0.000    4263.0
# 1|userID[s_1023]  0.106  0.032   0.047    0.166      0.000    0.000    4210.0
# 1|userID[s_1024] -0.139  0.031  -0.199   -0.083      0.000    0.000    4219.0
# 1|userID[s_1088]  0.085  0.031   0.026    0.142      0.001    0.000    3706.0
# 1|userID[s_1091]  0.038  0.031  -0.019    0.098      0.000    0.000    4275.0
# 1|userID[s_1096] -0.105  0.031  -0.162   -0.047      0.000    0.000    4302.0
# 1|userID[s_1101] -0.050  0.031  -0.105    0.013      0.000    0.000    4427.0
# 1|userID[s_1124]  0.048  0.031  -0.010    0.108      0.000    0.000    4695.0
# 1|userID[s_113]  -0.061  0.031  -0.120   -0.005      0.000    0.000    4512.0
# 1|userID[s_1143]  0.174  0.031   0.118    0.236      0.001    0.000    3708.0
# 1|userID[s_1176]  0.113  0.032   0.052    0.171      0.000    0.000    4485.0
# 1|userID[s_1207]  0.021  0.030  -0.036    0.080      0.000    0.000    3867.0
# 1|userID[s_1208] -0.081  0.031  -0.140   -0.024      0.000    0.000    4603.0
# 1|userID[s_1216] -0.025  0.030  -0.082    0.033      0.000    0.000    4132.0
# 1|userID[s_1233]  0.086  0.030   0.032    0.144      0.000    0.000    3900.0
# 1|userID[s_1244] -0.082  0.031  -0.137   -0.024      0.000    0.000    3742.0
# 1|userID[s_1258] -0.116  0.031  -0.175   -0.056      0.000    0.000    4609.0
# 1|userID[s_1260] -0.022  0.031  -0.077    0.039      0.000    0.000    4496.0
# 1|userID[s_1287]  0.069  0.032   0.012    0.132      0.000    0.000    4534.0
# 1|userID[s_129]  -0.080  0.031  -0.137   -0.022      0.000    0.000    4927.0
# 1|userID[s_1292] -0.175  0.031  -0.232   -0.117      0.000    0.000    3934.0
# 1|userID[s_1294]  0.060  0.031   0.004    0.122      0.000    0.000    4391.0
# 1|userID[s_1302]  0.009  0.032  -0.051    0.069      0.001    0.001    4042.0
# 1|userID[s_1305] -0.157  0.032  -0.217   -0.098      0.001    0.000    4130.0
# 1|userID[s_1308] -0.031  0.031  -0.094    0.022      0.000    0.000    4425.0
# 1|userID[s_1319] -0.049  0.031  -0.106    0.008      0.000    0.000    4576.0
# 1|userID[s_1325] -0.048  0.030  -0.108    0.008      0.000    0.000    3899.0
# 1|userID[s_143]   0.056  0.031  -0.001    0.114      0.000    0.000    4354.0
#
#                   ess_tail  r_hat
# 1|userID[s_1009]    2648.0    1.0
# 1|userID[s_102]     2924.0    1.0
# 1|userID[s_1022]    2861.0    1.0
# 1|userID[s_1023]    2696.0    1.0
# 1|userID[s_1024]    2749.0    1.0
# 1|userID[s_1088]    2647.0    1.0
# 1|userID[s_1091]    2841.0    1.0
# 1|userID[s_1096]    2790.0    1.0
# 1|userID[s_1101]    2392.0    1.0
# 1|userID[s_1124]    2795.0    1.0
# 1|userID[s_113]     2776.0    1.0
# 1|userID[s_1143]    2834.0    1.0
# 1|userID[s_1176]    2577.0    1.0
# 1|userID[s_1207]    2611.0    1.0
# 1|userID[s_1208]    2910.0    1.0
# 1|userID[s_1216]    2779.0    1.0
# 1|userID[s_1233]    2867.0    1.0
# 1|userID[s_1244]    2602.0    1.0
# 1|userID[s_1258]    2715.0    1.0
# 1|userID[s_1260]    2711.0    1.0
# 1|userID[s_1287]    2590.0    1.0
# 1|userID[s_129]     2860.0    1.0
# 1|userID[s_1292]    2649.0    1.0
# 1|userID[s_1294]    2431.0    1.0
# 1|userID[s_1302]    2442.0    1.0
# 1|userID[s_1305]    3243.0    1.0
# 1|userID[s_1308]    2787.0    1.0
# 1|userID[s_1319]    2843.0    1.0
# 1|userID[s_1325]    2699.0    1.0
# 1|userID[s_143]     2809.0    1.0
# ...
#
#                                                      mean     sd  hdi_3%  \
# 1|userID[s_781]                                    -0.071  0.031  -0.132
# 1|userID[s_819]                                     0.083  0.030   0.026
# 1|userID[s_829]                                    -0.040  0.032  -0.103
# 1|userID[s_868]                                     0.031  0.031  -0.031
# 1|userID[s_874]                                     0.013  0.031  -0.048
# 1|userID[s_88]                                      0.025  0.031  -0.035
# 1|userID[s_884]                                     0.000  0.032  -0.055
# 1|userID[s_897]                                     0.144  0.032   0.083
# 1|userID[s_930]                                    -0.179  0.032  -0.239
# 1|userID[s_931]                                    -0.149  0.031  -0.208
# 1|userID[s_934]                                    -0.039  0.031  -0.096
# 1|userID[s_937]                                     0.116  0.031   0.056
# 1|userID[s_945]                                    -0.146  0.031  -0.201
# 1|userID[s_948]                                    -0.052  0.031  -0.113
# 1|userID[s_961]                                     0.127  0.032   0.067
# 1|userID[s_989]                                    -0.047  0.031  -0.105
# 1|userID_sigma                                      0.095  0.008   0.079
# C(task, levels=base_lvl)[Matching]                  0.099  0.016   0.069
# C(task, levels=base_lvl)[Unfilled Delay]            0.018  0.017  -0.013
# C(task, levels=base_lvl)[Filled Delay - emotions]  -0.068  0.017  -0.099
# C(task, levels=base_lvl):difficulty[Matching, 2]   -0.016  0.024  -0.059
# C(task, levels=base_lvl):difficulty[Matching, 3]    0.005  0.023  -0.038
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.026  0.023  -0.068
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.012  0.024  -0.057
# C(task, levels=base_lvl):difficulty[Filled Dela... -0.002  0.023  -0.045
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.050  0.024   0.010
# Intercept                                           0.769  0.016   0.738
# difficulty[2]                                      -0.025  0.016  -0.055
# difficulty[3]                                      -0.094  0.017  -0.126
# sigma                                               0.107  0.003   0.103
#
#                                                     hdi_97%  mcse_mean  \
# 1|userID[s_781]                                      -0.013      0.000
# 1|userID[s_819]                                       0.138      0.000
# 1|userID[s_829]                                       0.016      0.000
# 1|userID[s_868]                                       0.086      0.001
# 1|userID[s_874]                                       0.070      0.000
# 1|userID[s_88]                                        0.085      0.000
# 1|userID[s_884]                                       0.064      0.000
# 1|userID[s_897]                                       0.201      0.000
# 1|userID[s_930]                                      -0.121      0.000
# 1|userID[s_931]                                      -0.091      0.000
# 1|userID[s_934]                                       0.019      0.000
# 1|userID[s_937]                                       0.172      0.000
# 1|userID[s_945]                                      -0.087      0.000
# 1|userID[s_948]                                       0.004      0.000
# 1|userID[s_961]                                       0.184      0.001
# 1|userID[s_989]                                       0.011      0.000
# 1|userID_sigma                                        0.110      0.000
# C(task, levels=base_lvl)[Matching]                    0.130      0.000
# C(task, levels=base_lvl)[Unfilled Delay]              0.049      0.000
# C(task, levels=base_lvl)[Filled Delay - emotions]    -0.037      0.000
# C(task, levels=base_lvl):difficulty[Matching, 2]      0.029      0.001
# C(task, levels=base_lvl):difficulty[Matching, 3]      0.049      0.000
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.017      0.000
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.034      0.000
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.042      0.000
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.099      0.000
# Intercept                                             0.797      0.000
# difficulty[2]                                         0.005      0.000
# difficulty[3]                                        -0.063      0.000
# sigma                                                 0.112      0.000
#
#                                                     mcse_sd  ess_bulk  \
# 1|userID[s_781]                                       0.000    4272.0
# 1|userID[s_819]                                       0.000    4141.0
# 1|userID[s_829]                                       0.000    4852.0
# 1|userID[s_868]                                       0.000    3457.0
# 1|userID[s_874]                                       0.000    4373.0
# 1|userID[s_88]                                        0.000    4280.0
# 1|userID[s_884]                                       0.001    4898.0
# 1|userID[s_897]                                       0.000    4772.0
# 1|userID[s_930]                                       0.000    4330.0
# 1|userID[s_931]                                       0.000    4271.0
# 1|userID[s_934]                                       0.000    4120.0
# 1|userID[s_937]                                       0.000    4039.0
# 1|userID[s_945]                                       0.000    4245.0
# 1|userID[s_948]                                       0.000    4400.0
# 1|userID[s_961]                                       0.000    3959.0
# 1|userID[s_989]                                       0.000    4057.0
# 1|userID_sigma                                        0.000    1086.0
# C(task, levels=base_lvl)[Matching]                    0.000    2252.0
# C(task, levels=base_lvl)[Unfilled Delay]              0.000    2048.0
# C(task, levels=base_lvl)[Filled Delay - emotions]     0.000    2300.0
# C(task, levels=base_lvl):difficulty[Matching, 2]      0.000    2154.0
# C(task, levels=base_lvl):difficulty[Matching, 3]      0.000    2590.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.000    2114.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.000    2342.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2315.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2486.0
# Intercept                                             0.000    1096.0
# difficulty[2]                                         0.000    1788.0
# difficulty[3]                                         0.000    2182.0
# sigma                                                 0.000    6803.0
#
#                                                     ess_tail  r_hat
# 1|userID[s_781]                                       2622.0    1.0
# 1|userID[s_819]                                       2855.0    1.0
# 1|userID[s_829]                                       2399.0    1.0
# 1|userID[s_868]                                       2279.0    1.0
# 1|userID[s_874]                                       2618.0    1.0
# 1|userID[s_88]                                        3065.0    1.0
# 1|userID[s_884]                                       2721.0    1.0
# 1|userID[s_897]                                       2655.0    1.0
# 1|userID[s_930]                                       3088.0    1.0
# 1|userID[s_931]                                       2761.0    1.0
# 1|userID[s_934]                                       2471.0    1.0
# 1|userID[s_937]                                       2684.0    1.0
# 1|userID[s_945]                                       2485.0    1.0
# 1|userID[s_948]                                       3034.0    1.0
# 1|userID[s_961]                                       2875.0    1.0
# 1|userID[s_989]                                       2461.0    1.0
# 1|userID_sigma                                        2239.0    1.0
# C(task, levels=base_lvl)[Matching]                    3050.0    1.0
# C(task, levels=base_lvl)[Unfilled Delay]              3089.0    1.0
# C(task, levels=base_lvl)[Filled Delay - emotions]     3155.0    1.0
# C(task, levels=base_lvl):difficulty[Matching, 2]      2624.0    1.0
# C(task, levels=base_lvl):difficulty[Matching, 3]      2900.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    2763.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    2859.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    3238.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2993.0    1.0
# Intercept                                             1886.0    1.0
# difficulty[2]                                         2984.0    1.0
# difficulty[3]                                         3006.0    1.0
# sigma                                                 3156.0    1.0
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1009]  0.023  0.031  -0.036    0.081      0.000      0.0    4228.0
# 1|userID[s_102]  -0.059  0.031  -0.117   -0.001      0.000      0.0    4394.0
# 1|userID[s_1022]  0.061  0.032  -0.002    0.117      0.001      0.0    3963.0
# 1|userID[s_1023]  0.106  0.031   0.050    0.166      0.000      0.0    4150.0
# 1|userID[s_1024] -0.138  0.030  -0.195   -0.083      0.000      0.0    3983.0
# 1|userID[s_1088]  0.086  0.031   0.029    0.145      0.000      0.0    4040.0
# 1|userID[s_1091]  0.039  0.031  -0.021    0.094      0.000      0.0    4078.0
# 1|userID[s_1096] -0.104  0.031  -0.163   -0.046      0.000      0.0    4320.0
# 1|userID[s_1101] -0.049  0.031  -0.106    0.011      0.000      0.0    3990.0
# 1|userID[s_1124]  0.050  0.031  -0.005    0.111      0.000      0.0    3994.0
# 1|userID[s_113]  -0.060  0.031  -0.118   -0.004      0.000      0.0    4031.0
# 1|userID[s_1143]  0.174  0.031   0.113    0.232      0.001      0.0    3729.0
# 1|userID[s_1176]  0.114  0.031   0.056    0.173      0.000      0.0    4029.0
# 1|userID[s_1207]  0.021  0.032  -0.036    0.081      0.000      0.0    4063.0
# 1|userID[s_1208] -0.081  0.031  -0.137   -0.018      0.000      0.0    3991.0
# 1|userID[s_1216] -0.025  0.031  -0.083    0.032      0.001      0.0    3814.0
# 1|userID[s_1233]  0.087  0.032   0.024    0.144      0.000      0.0    4767.0
# 1|userID[s_1244] -0.081  0.032  -0.144   -0.021      0.000      0.0    4229.0
# 1|userID[s_1258] -0.115  0.031  -0.176   -0.059      0.000      0.0    3973.0
# 1|userID[s_1260] -0.021  0.031  -0.082    0.033      0.001      0.0    3784.0
# 1|userID[s_1287]  0.069  0.031   0.010    0.126      0.000      0.0    4187.0
# 1|userID[s_129]  -0.079  0.031  -0.135   -0.018      0.001      0.0    3837.0
# 1|userID[s_1292] -0.175  0.030  -0.230   -0.119      0.001      0.0    3570.0
# 1|userID[s_1294]  0.061  0.031   0.003    0.117      0.000      0.0    4034.0
# 1|userID[s_1302]  0.011  0.031  -0.048    0.069      0.000      0.0    4257.0
# 1|userID[s_1305] -0.156  0.031  -0.214   -0.098      0.000      0.0    3995.0
# 1|userID[s_1308] -0.030  0.031  -0.092    0.025      0.000      0.0    4239.0
# 1|userID[s_1319] -0.049  0.032  -0.109    0.009      0.000      0.0    4253.0
# 1|userID[s_1325] -0.047  0.031  -0.109    0.010      0.000      0.0    4488.0
# 1|userID[s_143]   0.058  0.031  -0.002    0.115      0.001      0.0    3788.0
#
#                   ess_tail  r_hat
# 1|userID[s_1009]    2666.0    1.0
# 1|userID[s_102]     2987.0    1.0
# 1|userID[s_1022]    2681.0    1.0
# 1|userID[s_1023]    3208.0    1.0
# 1|userID[s_1024]    3143.0    1.0
# 1|userID[s_1088]    2849.0    1.0
# 1|userID[s_1091]    2574.0    1.0
# 1|userID[s_1096]    3132.0    1.0
# 1|userID[s_1101]    2879.0    1.0
# 1|userID[s_1124]    3144.0    1.0
# 1|userID[s_113]     3029.0    1.0
# 1|userID[s_1143]    3035.0    1.0
# 1|userID[s_1176]    2805.0    1.0
# 1|userID[s_1207]    2553.0    1.0
# 1|userID[s_1208]    2838.0    1.0
# 1|userID[s_1216]    2586.0    1.0
# 1|userID[s_1233]    2851.0    1.0
# 1|userID[s_1244]    2791.0    1.0
# 1|userID[s_1258]    2939.0    1.0
# 1|userID[s_1260]    2869.0    1.0
# 1|userID[s_1287]    2660.0    1.0
# 1|userID[s_129]     2814.0    1.0
# 1|userID[s_1292]    3098.0    1.0
# 1|userID[s_1294]    3297.0    1.0
# 1|userID[s_1302]    3038.0    1.0
# 1|userID[s_1305]    2747.0    1.0
# 1|userID[s_1308]    2610.0    1.0
# 1|userID[s_1319]    3028.0    1.0
# 1|userID[s_1325]    2309.0    1.0
# 1|userID[s_143]     2352.0    1.0
# ...
#
#                                                     mean     sd  hdi_3%  \
# 1|userID[s_719]                                   -0.002  0.031  -0.060
# 1|userID[s_731]                                    0.031  0.032  -0.026
# 1|userID[s_736]                                    0.096  0.031   0.034
# 1|userID[s_754]                                   -0.038  0.030  -0.097
# 1|userID[s_757]                                    0.039  0.032  -0.025
# 1|userID[s_760]                                   -0.116  0.031  -0.172
# 1|userID[s_781]                                   -0.070  0.032  -0.131
# 1|userID[s_819]                                    0.084  0.031   0.026
# 1|userID[s_829]                                   -0.040  0.031  -0.098
# 1|userID[s_868]                                    0.031  0.031  -0.024
# 1|userID[s_874]                                    0.014  0.031  -0.045
# 1|userID[s_88]                                     0.025  0.031  -0.031
# 1|userID[s_884]                                    0.001  0.031  -0.061
# 1|userID[s_897]                                    0.144  0.031   0.087
# 1|userID[s_930]                                   -0.177  0.031  -0.236
# 1|userID[s_931]                                   -0.148  0.032  -0.209
# 1|userID[s_934]                                   -0.039  0.031  -0.100
# 1|userID[s_937]                                    0.116  0.030   0.061
# 1|userID[s_945]                                   -0.145  0.031  -0.202
# 1|userID[s_948]                                   -0.051  0.031  -0.108
# 1|userID[s_961]                                    0.128  0.032   0.070
# 1|userID[s_989]                                   -0.046  0.031  -0.101
# 1|userID_sigma                                     0.095  0.008   0.081
# C(task, levels=base_lvl)[Matching]                 0.095  0.010   0.077
# C(task, levels=base_lvl)[Unfilled Delay]           0.005  0.010  -0.013
# C(task, levels=base_lvl)[Filled Delay - emotions] -0.052  0.010  -0.070
# Intercept                                          0.768  0.013   0.743
# difficulty[2]                                     -0.036  0.008  -0.051
# difficulty[3]                                     -0.084  0.008  -0.099
# sigma                                              0.108  0.003   0.103
#
#                                                    hdi_97%  mcse_mean  \
# 1|userID[s_719]                                      0.054      0.000
# 1|userID[s_731]                                      0.092      0.000
# 1|userID[s_736]                                      0.152      0.000
# 1|userID[s_754]                                      0.019      0.000
# 1|userID[s_757]                                      0.094      0.001
# 1|userID[s_760]                                     -0.058      0.000
# 1|userID[s_781]                                     -0.011      0.000
# 1|userID[s_819]                                      0.141      0.000
# 1|userID[s_829]                                      0.019      0.000
# 1|userID[s_868]                                      0.093      0.001
# 1|userID[s_874]                                      0.070      0.001
# 1|userID[s_88]                                       0.084      0.000
# 1|userID[s_884]                                      0.056      0.001
# 1|userID[s_897]                                      0.203      0.000
# 1|userID[s_930]                                     -0.122      0.001
# 1|userID[s_931]                                     -0.091      0.001
# 1|userID[s_934]                                      0.018      0.001
# 1|userID[s_937]                                      0.173      0.000
# 1|userID[s_945]                                     -0.086      0.000
# 1|userID[s_948]                                      0.006      0.000
# 1|userID[s_961]                                      0.190      0.000
# 1|userID[s_989]                                      0.014      0.001
# 1|userID_sigma                                       0.111      0.000
# C(task, levels=base_lvl)[Matching]                   0.113      0.000
# C(task, levels=base_lvl)[Unfilled Delay]             0.024      0.000
# C(task, levels=base_lvl)[Filled Delay - emotions]   -0.034      0.000
# Intercept                                            0.794      0.000
# difficulty[2]                                       -0.019      0.000
# difficulty[3]                                       -0.068      0.000
# sigma                                                0.112      0.000
#
#                                                    mcse_sd  ess_bulk  \
# 1|userID[s_719]                                      0.001    3951.0
# 1|userID[s_731]                                      0.000    4174.0
# 1|userID[s_736]                                      0.000    4217.0
# 1|userID[s_754]                                      0.000    3997.0
# 1|userID[s_757]                                      0.000    3871.0
# 1|userID[s_760]                                      0.000    4020.0
# 1|userID[s_781]                                      0.000    4979.0
# 1|userID[s_819]                                      0.000    4070.0
# 1|userID[s_829]                                      0.000    4317.0
# 1|userID[s_868]                                      0.000    3825.0
# 1|userID[s_874]                                      0.001    3704.0
# 1|userID[s_88]                                       0.000    3977.0
# 1|userID[s_884]                                      0.001    3477.0
# 1|userID[s_897]                                      0.000    4347.0
# 1|userID[s_930]                                      0.000    3603.0
# 1|userID[s_931]                                      0.000    3742.0
# 1|userID[s_934]                                      0.000    3452.0
# 1|userID[s_937]                                      0.000    4178.0
# 1|userID[s_945]                                      0.000    3964.0
# 1|userID[s_948]                                      0.000    4433.0
# 1|userID[s_961]                                      0.000    4411.0
# 1|userID[s_989]                                      0.000    3717.0
# 1|userID_sigma                                       0.000     965.0
# C(task, levels=base_lvl)[Matching]                   0.000    4646.0
# C(task, levels=base_lvl)[Unfilled Delay]             0.000    4573.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    0.000    5044.0
# Intercept                                            0.000    1295.0
# difficulty[2]                                        0.000    5809.0
# difficulty[3]                                        0.000    5858.0
# sigma                                                0.000    5156.0
#
#                                                    ess_tail  r_hat
# 1|userID[s_719]                                      2425.0   1.00
# 1|userID[s_731]                                      2607.0   1.00
# 1|userID[s_736]                                      2780.0   1.00
# 1|userID[s_754]                                      2741.0   1.00
# 1|userID[s_757]                                      2897.0   1.00
# 1|userID[s_760]                                      2867.0   1.00
# 1|userID[s_781]                                      2778.0   1.00
# 1|userID[s_819]                                      2955.0   1.00
# 1|userID[s_829]                                      2917.0   1.00
# 1|userID[s_868]                                      2721.0   1.00
# 1|userID[s_874]                                      2615.0   1.00
# 1|userID[s_88]                                       3053.0   1.00
# 1|userID[s_884]                                      2664.0   1.00
# 1|userID[s_897]                                      2995.0   1.00
# 1|userID[s_930]                                      2970.0   1.00
# 1|userID[s_931]                                      2734.0   1.00
# 1|userID[s_934]                                      2483.0   1.00
# 1|userID[s_937]                                      3101.0   1.00
# 1|userID[s_945]                                      3088.0   1.00
# 1|userID[s_948]                                      3074.0   1.00
# 1|userID[s_961]                                      2971.0   1.00
# 1|userID[s_989]                                      2761.0   1.00
# 1|userID_sigma                                       1111.0   1.01
# C(task, levels=base_lvl)[Matching]                   3082.0   1.00
# C(task, levels=base_lvl)[Unfilled Delay]             2984.0   1.00
# C(task, levels=base_lvl)[Filled Delay - emotions]    3250.0   1.00
# Intercept                                            2071.0   1.00
# difficulty[2]                                        2799.0   1.00
# difficulty[3]                                        3368.0   1.00
# sigma                                                2906.0   1.00

# %% [markdown]
# ### Compare all data
# [top](#top)

# %%
df_compare_formulas_bernoulli = {}
for f in result_dic_bernoulli.keys():
    print(f, '\n')
    df_compare_formulas_bernoulli[f] = az.compare(result_dic_bernoulli[f])
    
    print(df_compare_formulas_bernoulli[f])
    
    az.plot_compare(df_compare_formulas_bernoulli[f], insample_dev=False);

    
    print()
# df_compare_formulas_bernoulli[f]
# Out:
# dataset_5
#
#                                                     rank    elpd_loo  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...     0  765.529932
# correct_flt ~ C(task, levels=base_lvl) * diffic...     1  764.396368
#
#                                                         p_loo  elpd_diff  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  78.399439   0.000000
# correct_flt ~ C(task, levels=base_lvl) * diffic...  83.831716   1.133565
#
#                                                       weight         se  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.604326  24.645546
# correct_flt ~ C(task, levels=base_lvl) * diffic...  0.395674  24.720973
#
#                                                          dse  warning scale
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.000000    False   log
# correct_flt ~ C(task, levels=base_lvl) * diffic...  3.274412    False   log

# %%
fig, ax = plt.subplots(figsize=(8, 4))
az.plot_forest(
    result_dic_bernoulli['dataset_5']['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'],
#     model_names=['Dataset 4'],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
az.plot_forest(
    list(result_dic_bernoulli['dataset_5'].values()),
    model_names=[f'{f}\n{formula}' for f in result_dic_bernoulli.keys() for formula in formulas2run],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.69, .42), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
az.plot_forest(
    (list(result_dic_bernoulli['dataset_5'].values())
    )[::2],
#     model_names=[f'{f}' for f in result_dic_bernoulli.keys()],
    var_names=["C(task, levels=base_lvl):difficulty"],
    combined=True,
#     figsize=(12, 10)
    ax=ax
);

ax.axvline(0, c='k')

# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
# # plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
# plt.show()


# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.6, 1))
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %% [markdown]
# ### Run some predictions
# [top](#top)

# %%
interactions = ['Matching, 2', 'Matching, 3', 'Unfilled Delay, 2', 'Unfilled Delay, 3', 'Filled Delay - emotions, 2', 'Filled Delay - emotions, 3']
fm2, fm3, d2, d3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]

# %%
_, ax = plt.subplots()
for idx, x in enumerate([fm2, fm3, d2, d3, i2, i3]):
    az.plot_dist(x, label=x["C(task, levels=base_lvl):difficulty_dim"].item(), plot_kwargs={"color": f"C{idx}"}, ax=ax)
ax.legend(loc="upper left");

# %%
# Probability that the FM slope is less than 0

print(f"""
Probability that the UD slope is less than 0:
level 2: {(d2 < 0).mean().item()}
level 3: {(d3 < 0).mean().item()}
""")
# Out:
# Probability that the UD slope is less than 0:
# level 2: 0.87225
# level 3: 0.69675

# %% [markdown]
# ---

# %%
for f in result_dic_bernoulli.keys():

    fm2, fm3, d2, d3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]
    print(f"""
Experiment {f}:    
  Probability that the Matching slope is less than 0:
    level 2: {(fm2 < 0).mean().item()}
    level 3: {(fm3 < 0).mean().item()}

  Probability that the UD slope is less than 0:
    level 2: {(d2 < 0).mean().item()}
    level 3: {(d3 < 0).mean().item()}
    
  Probability that the FD-e slope is less than 0:
    level 2: {(i2 < 0).mean().item()}
    level 3: {(i3 < 0).mean().item()}
    
    """)
# Out:
# Experiment dataset_5:
#   Probability that the Matching slope is less than 0:
#     level 2: 0.7605
#     level 3: 0.41225
#
#   Probability that the UD slope is less than 0:
#     level 2: 0.87225
#     level 3: 0.69675
#
#   Probability that the FD-e slope is less than 0:
#     level 2: 0.52175
#     level 3: 0.01625

# %% [markdown]
# ### Save the inference
# [top](#top)
#
# It could be possible to use this:
# ```
# result_dic_bernoulli['dataset_5']['correct_flt ~ task * difficulty + (1|userID)'].to_netcdf()
# ```
#
# but it doesn't preserve the dictionary, so I use pickle.

# %%
# save the dictionary to a pickle file
with open(opj(path_inference_data,'FMP_vege_baselineVeg_inference_data_dict.pkl'), 'wb') as f:
    pickle.dump(result_dic_bernoulli['dataset_5'], f)

# %%
# # Load the dictionary from the pickle file
# with open(opj(path_inference_data,'FMP_math_baselineMath_inference_data_dict.pkl'), 'rb') as f:
#     loaded_inference_data_dict = pickle.load(f)

# %%
# %load_ext watermark

# %watermark -a 'Jan Kadlec' -nmvu -iv -iv -w -p pytensor
# Out:
# Author: Jan Kadlec
#
# Last updated: Sun Jun 08 2025
#
# Python implementation: CPython
# Python version       : 3.12.5
# IPython version      : 8.25.0
#
# pytensor: 2.23.0
#
# Compiler    : GCC 12.4.0
# OS          : Linux
# Release     : 5.14.0-427.42.1.el9_4.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 96
# Architecture: 64bit
#
# numpy     : 1.26.4
# pandas    : 2.2.2
# arviz     : 0.19.0
# sys       : 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:36:51) [GCC 12.4.0]
# bambi     : 0.14.0
# matplotlib: 3.9.2
#
# Watermark: 2.4.3

# %% [markdown]
# [top](#top)
