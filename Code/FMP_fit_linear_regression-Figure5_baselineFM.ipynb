# %% [markdown]
# ##### top

# %% [markdown]
# # FMP modelling for Figure 5 (Vegetarian)
#
# This notebook runs Bayesian models on Dataset 5 (dataset with Vegetarian condition) that is described in the article to assess interaction between perception and memory difficulty levels in the FMP. We fit the following formulas to mean score within the condition. Throughout the notebook, I use `task` as a term for memory difficulty levels (M, UD, FD-e, FD-v), `difficulty` as a term for perceptual difficulty levels (1, 2, 3), and `userID` as a variable denoting individual participants. It is the exact same principle and code as the `FMP_fit_linear_regression-Figure5.ipynb` but it sets the FM as a reference level instead of UD.
#
#
# * Model task and difficulty interaction with user as a random effect. Equation:
#     * _correct_flt ~ task * difficulty + (1|userID)_
# * Model task and difficulty as main effects without interaction with user as a random effect. Equation:
#     * _correct_flt ~ task + difficulty + (1|userID)_
#
#
#
# We model mean accuracy per participant per condition.
#
#
# * [Models](#Models)
# * [Plot results](#Plot-results)
# * [Compare all data](#Compare-all-data)
# * [Save the inference](#Save-the-inference)

# %%
import os, sys
import pickle
from os.path import join as opj
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

az.style.use("arviz-darkgrid")
SEED = 7355608


# Importing module for functions
functions_modul =  "./functions"
sys.path.insert(0, functions_modul)

# import all processing and plotting functions
from bayesian_modelling_functions import fit_model, print_model

path_general = "../"
path_data = opj(path_general, "Data", "datasets")
path_inference_data = opj(path_general, "Data", "model_inference_data")


# set the numer of CPU
num_cpu = min(4, os.cpu_count()-1)
print(f'We will have {num_cpu} cores.\n')

path_dic = {
#     'dataset_1' : opj(path_data, 'FMP_dataset_1.csv'),
#     'dataset_2': opj(path_data, 'FMP_dataset_2.csv'),
#     'dataset_3': opj(path_data, 'FMP_dataset_3.csv'),
#     'concat_datasets_123': opj(path_data, 'FMP_concat_datasets_123.csv'),
#     'dataset_4': opj(path_data, 'FMP_dataset_4.csv'),
    'dataset_5': opj(path_data, 'FMP_dataset_5.csv'),
}


# load all dataframes
df_dic = {}

# only selected cols
select_cols = ['stim1', 'stim2', 'target', 'RT', 'userID', 'difficulty', 'levels', 'task', 'correct_flt', 'order']


for f in path_dic.keys():   
    if f=="first_pilot":
        df_dic[f] = pd.read_csv(path_dic[f], usecols=(set(['correct_check'])|set(select_cols))-set(['correct_flt']))
        # convert boolean answers to floats to be able to do mean
        df_dic[f]['correct_flt'] = df_dic[f].correct_check.astype(float)
    elif 'longitudinal_' in f:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols+['target_loc', 'target_loc_simple'])
    else:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols)
    
    df_dic[f]["Experiment"] = f
        

    # clean
    df_dic[f].reset_index(drop=True, inplace=True)
    
    if 'Unnamed: 0' in df_dic[f].columns:
        df_dic[f].drop('Unnamed: 0', inplace=True, axis=1)
        
    
    # find low performing participants
    tt = df_dic[f].loc[df_dic[f]['task'].isin(['face matching', 'perc', 'perception'])].groupby(['userID', 'difficulty']).correct_flt.mean()

    drop_ptc = tt[tt<=0.5].reset_index().userID.values
    print(f'\nIn {f} dropping {len(drop_ptc)} participants for low accuracy in FM.')
    print(tt[tt<=0.5])

    # and remove them
    df_dic[f] = df_dic[f].loc[~df_dic[f]['userID'].isin(drop_ptc)]
    # clean up
    drop_ptc, tt = None, None
    
    print(f"\nThere is now N={df_dic[f]['userID'].unique().size} participants in {f}.")



#####
# rename the levels
rename_tasks_dic = {'perception':'Matching', 'perc':'Matching', 'blank':'Unfilled Delay', 'faces':'Filled Delay - emotions', 
                    'math':'Filled Delay - math', 'vege':'Filled Delay - vis'}

# define orders
hue_order = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions']
hue_order_math = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - math']
hue_order_veg = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - vis']



# rename the memory task labels in the df
for f in df_dic.keys():
    if f=='noise':
        continue
    df_dic[f]['task'] = df_dic[f]['task'].map(rename_tasks_dic).fillna(df_dic[f]['task'])
# Out:
# We will have 4 cores.
#
#
# In dataset_5 dropping 0 participants for low accuracy in FM.
# Series([], Name: correct_flt, dtype: float64)
#
# There is now N=83 participants in dataset_5.

# %%
# select only specific datasets and prepare them
datasets2fit = ['dataset_5']

df_dic_fit = {}


for f in datasets2fit:
    data=None
    
    # groupby and make means for ptc and condition
    data = df_dic[f].groupby(['userID', 'task', 'difficulty'], observed=False).correct_flt.mean().reset_index()

    # convert all variables to categories
    # categorical_cols = data.columns[data.dtypes == object].tolist() + ['difficulty']
    categorical_cols = ['userID', 'task', 'difficulty']
    for col in categorical_cols:
        if col == 'task':
            # specify the order that we want
            data[col] = pd.Categorical(data[col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - vis'], ordered=True)
            #['Unfilled Delay', 'Matching', 'Filled Delay - emotions']
            
            # also do it for the original datasets
            df_dic[f][col] = pd.Categorical(df_dic[f][col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - vis'], ordered=True)
        else:
            data[col] = data[col].astype("category")
            df_dic[f][col] = df_dic[f][col].astype("category")

    # check
    print('\n',f)
    df_dic[f].info()
        
    # save
    df_dic_fit[f] = data.copy()

# # drop them for now
# data[data.correct_flt.isna()]
# Out:
#  dataset_5
# <class 'pandas.core.frame.DataFrame'>
# Index: 19920 entries, 0 to 19919
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userID       19920 non-null  category
#  1   target       19920 non-null  object
#  2   stim1        19920 non-null  object
#  3   stim2        19920 non-null  object
#  4   correct_flt  19534 non-null  float64
#  5   RT           19534 non-null  float64
#  6   task         19920 non-null  category
#  7   order        19920 non-null  int64
#  8   difficulty   19920 non-null  category
#  9   levels       19920 non-null  int64
#  10  Experiment   19920 non-null  object
# dtypes: category(3), float64(2), int64(2), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Models
# [top](#top)

# %%
model_assumptions = {
    "correct_flt ~ task * difficulty + (1|userID)": "Each user has their own baseline performance, but the effect of task and difficulty is assumed to be the same across all users.",
    "correct_flt ~ task + difficulty + (1|userID)": "Assumes that each user has their own baseline performance, but the effects of task and difficulty are consistent across all users without any interaction between task and difficulty.",
}

# define what we want to run
base_lvl = ['Matching', 'Unfilled Delay', 'Filled Delay - vis', 'Filled Delay - emotions']
formulas2run = [
    "correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)",
    "correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)",
]

# %%
# define where we will store the results
model_dic_bernoulli = {}
result_dic_bernoulli = {}

for f in df_dic_fit.keys():
    print(f'\nFitting dataset {f}\n')
    # create datasets
    if f not in model_dic_bernoulli.keys():
        model_dic_bernoulli[f] = {}
    if f not in result_dic_bernoulli.keys():
        result_dic_bernoulli[f] = {}
    
    for formula in formulas2run:
        print(f'\nFitting formula {formula}\n')
    
        model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula] = fit_model(formula, df_dic_fit[f], categorical_cols, base_lvl=base_lvl,
                                                                                      num_cpu=num_cpu, check_priors=False, sample_priors=False)
# Out:
# Sampling 4 chains, 0 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:19
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 19 seconds.

# %%
model_dic_bernoulli[f][formulas2run[0]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 996
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7405, sigma: 0.7299)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8952 0.8952 0.8952])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8223 0.8223])
#             C(task, levels=base_lvl):difficulty ~ Normal(mu: [0. 0. 0. 0. 0. 0.], sigma: [1.4025 1.4025
#                 1.4025 1.4025 1.4025 1.4025])
#
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.7299))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.155)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
model_dic_bernoulli[f][formulas2run[1]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 996
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7405, sigma: 0.6714)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8952 0.8952 0.8952])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8223 0.8223])
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.6714))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.155)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# ### check priors

# %%
model_dic_bernoulli[f][formulas2run[0]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), C(task, levels=base_lvl):difficulty, Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - vis'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - vis, 2'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - vis, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
model_dic_bernoulli[f][formulas2run[1]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - vis'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>]], dtype=object)

# %% [markdown]
# ### check posterior

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[0]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - vis'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[1]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - vis'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %% [markdown]
# ---
# ## Plot results

# %% [markdown]
# ## FMP dataset 5 -- with Vege condition
# [top](#top)

# %%
f = 'dataset_5'
# print(f'Dataset: {f}')
# print_model(model_dic_bernoulli[f], result_dic_bernoulli[f])

print(f'Dataset: {f}')
for formula in formulas2run:
    print(f'\nFitting formula {formula}\n')
    print_model(model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula])
# Out:
# Dataset: dataset_5
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1008]  0.166  0.031   0.107    0.225      0.000    0.000    4425.0
# 1|userID[s_1062]  0.128  0.032   0.070    0.190      0.000    0.000    4417.0
# 1|userID[s_1067]  0.001  0.031  -0.055    0.060      0.000    0.001    4753.0
# 1|userID[s_1076] -0.145  0.031  -0.202   -0.086      0.001    0.000    3506.0
# 1|userID[s_1094]  0.107  0.032   0.049    0.168      0.000    0.000    4280.0
# 1|userID[s_1100] -0.138  0.032  -0.197   -0.077      0.000    0.000    4568.0
# 1|userID[s_1122]  0.144  0.032   0.087    0.206      0.000    0.000    4784.0
# 1|userID[s_1125] -0.116  0.031  -0.170   -0.052      0.000    0.000    4162.0
# 1|userID[s_118]  -0.049  0.032  -0.111    0.008      0.000    0.000    4127.0
# 1|userID[s_1209]  0.174  0.031   0.118    0.235      0.000    0.000    4380.0
# 1|userID[s_1216]  0.022  0.031  -0.035    0.080      0.000    0.000    4456.0
# 1|userID[s_125]   0.057  0.031  -0.004    0.115      0.000    0.000    4465.0
# 1|userID[s_128]   0.088  0.031   0.025    0.143      0.000    0.000    4069.0
# 1|userID[s_129]   0.144  0.031   0.083    0.198      0.000    0.000    4046.0
# 1|userID[s_1295] -0.081  0.030  -0.136   -0.024      0.000    0.000    3841.0
# 1|userID[s_1332] -0.039  0.031  -0.098    0.017      0.000    0.000    4170.0
# 1|userID[s_1336]  0.014  0.031  -0.042    0.075      0.000    0.001    4606.0
# 1|userID[s_1339] -0.060  0.031  -0.120   -0.002      0.000    0.000    4722.0
# 1|userID[s_1348] -0.124  0.031  -0.184   -0.068      0.000    0.000    3934.0
# 1|userID[s_1352] -0.156  0.031  -0.215   -0.098      0.000    0.000    4308.0
# 1|userID[s_1354] -0.081  0.031  -0.135   -0.022      0.000    0.000    4165.0
# 1|userID[s_1361]  0.028  0.030  -0.026    0.085      0.000    0.000    3762.0
# 1|userID[s_1373] -0.025  0.032  -0.081    0.037      0.000    0.000    4631.0
# 1|userID[s_142]  -0.177  0.031  -0.235   -0.119      0.000    0.000    3968.0
# 1|userID[s_1464]  0.075  0.031   0.019    0.134      0.000    0.000    3929.0
# 1|userID[s_165]   0.061  0.031   0.005    0.119      0.000    0.000    3962.0
# 1|userID[s_20]   -0.017  0.031  -0.078    0.040      0.000    0.000    4603.0
# 1|userID[s_299]   0.031  0.031  -0.025    0.093      0.000    0.000    4253.0
# 1|userID[s_323]   0.095  0.031   0.037    0.153      0.000    0.000    4473.0
# 1|userID[s_327]   0.140  0.031   0.081    0.199      0.001    0.000    3730.0
#
#                   ess_tail  r_hat
# 1|userID[s_1008]    2640.0    1.0
# 1|userID[s_1062]    3141.0    1.0
# 1|userID[s_1067]    2432.0    1.0
# 1|userID[s_1076]    2675.0    1.0
# 1|userID[s_1094]    2754.0    1.0
# 1|userID[s_1100]    2941.0    1.0
# 1|userID[s_1122]    2934.0    1.0
# 1|userID[s_1125]    2922.0    1.0
# 1|userID[s_118]     2917.0    1.0
# 1|userID[s_1209]    2893.0    1.0
# 1|userID[s_1216]    2949.0    1.0
# 1|userID[s_125]     2241.0    1.0
# 1|userID[s_128]     2814.0    1.0
# 1|userID[s_129]     2616.0    1.0
# 1|userID[s_1295]    3137.0    1.0
# 1|userID[s_1332]    2448.0    1.0
# 1|userID[s_1336]    2654.0    1.0
# 1|userID[s_1339]    2641.0    1.0
# 1|userID[s_1348]    2709.0    1.0
# 1|userID[s_1352]    2848.0    1.0
# 1|userID[s_1354]    2824.0    1.0
# 1|userID[s_1361]    2842.0    1.0
# 1|userID[s_1373]    2732.0    1.0
# 1|userID[s_142]     2788.0    1.0
# 1|userID[s_1464]    2370.0    1.0
# 1|userID[s_165]     2552.0    1.0
# 1|userID[s_20]      2758.0    1.0
# 1|userID[s_299]     2870.0    1.0
# 1|userID[s_323]     3266.0    1.0
# 1|userID[s_327]     2629.0    1.0
# ...
#
#                                                      mean     sd  hdi_3%  \
# 1|userID[s_812]                                    -0.094  0.031  -0.149
# 1|userID[s_82]                                     -0.048  0.032  -0.106
# 1|userID[s_831]                                     0.061  0.031   0.001
# 1|userID[s_834]                                     0.084  0.031   0.027
# 1|userID[s_840]                                    -0.038  0.032  -0.098
# 1|userID[s_862]                                     0.135  0.033   0.072
# 1|userID[s_878]                                    -0.095  0.032  -0.154
# 1|userID[s_879]                                    -0.079  0.031  -0.135
# 1|userID[s_904]                                    -0.146  0.031  -0.203
# 1|userID[s_908]                                     0.049  0.032  -0.011
# 1|userID[s_912]                                    -0.056  0.030  -0.112
# 1|userID[s_925]                                     0.151  0.032   0.087
# 1|userID[s_939]                                    -0.060  0.029  -0.115
# 1|userID[s_944]                                    -0.059  0.031  -0.117
# 1|userID[s_959]                                    -0.083  0.031  -0.137
# 1|userID[s_988]                                     0.086  0.031   0.026
# 1|userID_sigma                                      0.095  0.008   0.079
# C(task, levels=base_lvl)[Unfilled Delay]           -0.080  0.017  -0.110
# C(task, levels=base_lvl)[Filled Delay - vis]       -0.098  0.017  -0.129
# C(task, levels=base_lvl)[Filled Delay - emotions]  -0.166  0.017  -0.198
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.010  0.024  -0.052
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.018  0.024  -0.061
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.016  0.023  -0.029
# C(task, levels=base_lvl):difficulty[Filled Dela... -0.006  0.024  -0.052
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.014  0.024  -0.030
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.044  0.024  -0.000
# Intercept                                           0.866  0.016   0.836
# difficulty[2]                                      -0.041  0.017  -0.072
# difficulty[3]                                      -0.089  0.017  -0.119
# sigma                                               0.107  0.003   0.103
#
#                                                     hdi_97%  mcse_mean  \
# 1|userID[s_812]                                      -0.035      0.000
# 1|userID[s_82]                                        0.011      0.000
# 1|userID[s_831]                                       0.119      0.001
# 1|userID[s_834]                                       0.144      0.000
# 1|userID[s_840]                                       0.022      0.000
# 1|userID[s_862]                                       0.196      0.000
# 1|userID[s_878]                                      -0.036      0.000
# 1|userID[s_879]                                      -0.020      0.000
# 1|userID[s_904]                                      -0.090      0.000
# 1|userID[s_908]                                       0.110      0.000
# 1|userID[s_912]                                       0.001      0.000
# 1|userID[s_925]                                       0.206      0.000
# 1|userID[s_939]                                      -0.006      0.000
# 1|userID[s_944]                                      -0.001      0.000
# 1|userID[s_959]                                      -0.022      0.000
# 1|userID[s_988]                                       0.143      0.000
# 1|userID_sigma                                        0.110      0.000
# C(task, levels=base_lvl)[Unfilled Delay]             -0.047      0.000
# C(task, levels=base_lvl)[Filled Delay - vis]         -0.066      0.000
# C(task, levels=base_lvl)[Filled Delay - emotions]    -0.133      0.000
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.037      0.000
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.027      0.000
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.058      0.001
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.039      0.001
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.057      0.001
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.089      0.001
# Intercept                                             0.896      0.000
# difficulty[2]                                        -0.009      0.000
# difficulty[3]                                        -0.057      0.000
# sigma                                                 0.112      0.000
#
#                                                     mcse_sd  ess_bulk  \
# 1|userID[s_812]                                         0.0    4245.0
# 1|userID[s_82]                                          0.0    4027.0
# 1|userID[s_831]                                         0.0    3778.0
# 1|userID[s_834]                                         0.0    4277.0
# 1|userID[s_840]                                         0.0    4150.0
# 1|userID[s_862]                                         0.0    4653.0
# 1|userID[s_878]                                         0.0    4240.0
# 1|userID[s_879]                                         0.0    4400.0
# 1|userID[s_904]                                         0.0    4024.0
# 1|userID[s_908]                                         0.0    4483.0
# 1|userID[s_912]                                         0.0    4302.0
# 1|userID[s_925]                                         0.0    4348.0
# 1|userID[s_939]                                         0.0    3845.0
# 1|userID[s_944]                                         0.0    4135.0
# 1|userID[s_959]                                         0.0    3795.0
# 1|userID[s_988]                                         0.0    4402.0
# 1|userID_sigma                                          0.0    1163.0
# C(task, levels=base_lvl)[Unfilled Delay]                0.0    2114.0
# C(task, levels=base_lvl)[Filled Delay - vis]            0.0    1901.0
# C(task, levels=base_lvl)[Filled Delay - emotions]       0.0    2067.0
# C(task, levels=base_lvl):difficulty[Unfilled De...      0.0    2464.0
# C(task, levels=base_lvl):difficulty[Unfilled De...      0.0    2306.0
# C(task, levels=base_lvl):difficulty[Filled Dela...      0.0    2073.0
# C(task, levels=base_lvl):difficulty[Filled Dela...      0.0    2062.0
# C(task, levels=base_lvl):difficulty[Filled Dela...      0.0    2199.0
# C(task, levels=base_lvl):difficulty[Filled Dela...      0.0    2179.0
# Intercept                                               0.0    1096.0
# difficulty[2]                                           0.0    1957.0
# difficulty[3]                                           0.0    1941.0
# sigma                                                   0.0    6241.0
#
#                                                     ess_tail  r_hat
# 1|userID[s_812]                                       2806.0    1.0
# 1|userID[s_82]                                        2617.0    1.0
# 1|userID[s_831]                                       2659.0    1.0
# 1|userID[s_834]                                       2982.0    1.0
# 1|userID[s_840]                                       2872.0    1.0
# 1|userID[s_862]                                       2977.0    1.0
# 1|userID[s_878]                                       2452.0    1.0
# 1|userID[s_879]                                       2985.0    1.0
# 1|userID[s_904]                                       2912.0    1.0
# 1|userID[s_908]                                       2775.0    1.0
# 1|userID[s_912]                                       2578.0    1.0
# 1|userID[s_925]                                       2782.0    1.0
# 1|userID[s_939]                                       2781.0    1.0
# 1|userID[s_944]                                       2754.0    1.0
# 1|userID[s_959]                                       2952.0    1.0
# 1|userID[s_988]                                       2701.0    1.0
# 1|userID_sigma                                        1841.0    1.0
# C(task, levels=base_lvl)[Unfilled Delay]              2647.0    1.0
# C(task, levels=base_lvl)[Filled Delay - vis]          2673.0    1.0
# C(task, levels=base_lvl)[Filled Delay - emotions]     2484.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    2612.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    2971.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2808.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2722.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    3015.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2840.0    1.0
# Intercept                                             1760.0    1.0
# difficulty[2]                                         2776.0    1.0
# difficulty[3]                                         2729.0    1.0
# sigma                                                 3106.0    1.0
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1008]  0.166  0.031   0.106    0.222      0.001    0.000    3651.0
# 1|userID[s_1062]  0.126  0.031   0.068    0.184      0.000    0.000    3939.0
# 1|userID[s_1067]  0.001  0.032  -0.058    0.059      0.001    0.001    3689.0
# 1|userID[s_1076] -0.145  0.032  -0.202   -0.084      0.000    0.000    4375.0
# 1|userID[s_1094]  0.106  0.031   0.052    0.166      0.001    0.000    3671.0
# 1|userID[s_1100] -0.138  0.032  -0.199   -0.082      0.001    0.000    3544.0
# 1|userID[s_1122]  0.143  0.031   0.083    0.198      0.001    0.000    3399.0
# 1|userID[s_1125] -0.116  0.032  -0.176   -0.057      0.001    0.000    3618.0
# 1|userID[s_118]  -0.050  0.032  -0.108    0.009      0.001    0.000    3720.0
# 1|userID[s_1209]  0.174  0.031   0.119    0.236      0.001    0.000    3836.0
# 1|userID[s_1216]  0.020  0.031  -0.037    0.080      0.000    0.000    4170.0
# 1|userID[s_125]   0.056  0.031  -0.001    0.115      0.001    0.000    3661.0
# 1|userID[s_128]   0.087  0.031   0.030    0.145      0.001    0.000    3721.0
# 1|userID[s_129]   0.143  0.031   0.085    0.201      0.000    0.000    4474.0
# 1|userID[s_1295] -0.082  0.031  -0.143   -0.028      0.001    0.000    3430.0
# 1|userID[s_1332] -0.039  0.031  -0.098    0.019      0.001    0.000    3748.0
# 1|userID[s_1336]  0.013  0.031  -0.047    0.069      0.000    0.000    4150.0
# 1|userID[s_1339] -0.061  0.031  -0.119   -0.002      0.001    0.000    3809.0
# 1|userID[s_1348] -0.125  0.031  -0.183   -0.067      0.001    0.000    3392.0
# 1|userID[s_1352] -0.157  0.031  -0.218   -0.102      0.001    0.000    3772.0
# 1|userID[s_1354] -0.081  0.031  -0.138   -0.024      0.001    0.000    3347.0
# 1|userID[s_1361]  0.027  0.031  -0.029    0.083      0.000    0.000    4242.0
# 1|userID[s_1373] -0.025  0.030  -0.080    0.035      0.000    0.000    3848.0
# 1|userID[s_142]  -0.179  0.031  -0.240   -0.122      0.001    0.000    3825.0
# 1|userID[s_1464]  0.075  0.032   0.012    0.133      0.001    0.000    3630.0
# 1|userID[s_165]   0.060  0.032  -0.001    0.117      0.000    0.000    4057.0
# 1|userID[s_20]   -0.017  0.031  -0.074    0.041      0.001    0.000    3494.0
# 1|userID[s_299]   0.031  0.031  -0.026    0.088      0.001    0.000    3367.0
# 1|userID[s_323]   0.095  0.032   0.035    0.154      0.001    0.000    3690.0
# 1|userID[s_327]   0.139  0.031   0.079    0.196      0.000    0.000    4217.0
#
#                   ess_tail  r_hat
# 1|userID[s_1008]    2757.0    1.0
# 1|userID[s_1062]    2845.0    1.0
# 1|userID[s_1067]    2449.0    1.0
# 1|userID[s_1076]    2875.0    1.0
# 1|userID[s_1094]    2894.0    1.0
# 1|userID[s_1100]    2753.0    1.0
# 1|userID[s_1122]    2850.0    1.0
# 1|userID[s_1125]    2958.0    1.0
# 1|userID[s_118]     2922.0    1.0
# 1|userID[s_1209]    3025.0    1.0
# 1|userID[s_1216]    2830.0    1.0
# 1|userID[s_125]     3277.0    1.0
# 1|userID[s_128]     2667.0    1.0
# 1|userID[s_129]     2731.0    1.0
# 1|userID[s_1295]    2734.0    1.0
# 1|userID[s_1332]    2766.0    1.0
# 1|userID[s_1336]    3010.0    1.0
# 1|userID[s_1339]    2767.0    1.0
# 1|userID[s_1348]    2686.0    1.0
# 1|userID[s_1352]    2698.0    1.0
# 1|userID[s_1354]    2731.0    1.0
# 1|userID[s_1361]    2806.0    1.0
# 1|userID[s_1373]    2741.0    1.0
# 1|userID[s_142]     2719.0    1.0
# 1|userID[s_1464]    2606.0    1.0
# 1|userID[s_165]     2774.0    1.0
# 1|userID[s_20]      2969.0    1.0
# 1|userID[s_299]     2646.0    1.0
# 1|userID[s_323]     2707.0    1.0
# 1|userID[s_327]     2525.0    1.0
# ...
#
#                                                     mean     sd  hdi_3%  \
# 1|userID[s_737]                                   -0.059  0.032  -0.120
# 1|userID[s_742]                                    0.018  0.030  -0.035
# 1|userID[s_785]                                    0.030  0.032  -0.027
# 1|userID[s_8]                                      0.039  0.030  -0.018
# 1|userID[s_805]                                   -0.004  0.031  -0.057
# 1|userID[s_807]                                    0.024  0.031  -0.040
# 1|userID[s_812]                                   -0.095  0.031  -0.151
# 1|userID[s_82]                                    -0.049  0.031  -0.104
# 1|userID[s_831]                                    0.061  0.031   0.002
# 1|userID[s_834]                                    0.083  0.031   0.025
# 1|userID[s_840]                                   -0.039  0.030  -0.098
# 1|userID[s_862]                                    0.134  0.032   0.072
# 1|userID[s_878]                                   -0.096  0.031  -0.155
# 1|userID[s_879]                                   -0.080  0.031  -0.134
# 1|userID[s_904]                                   -0.146  0.031  -0.202
# 1|userID[s_908]                                    0.049  0.031  -0.011
# 1|userID[s_912]                                   -0.057  0.030  -0.112
# 1|userID[s_925]                                    0.151  0.031   0.094
# 1|userID[s_939]                                   -0.061  0.030  -0.118
# 1|userID[s_944]                                   -0.059  0.031  -0.117
# 1|userID[s_959]                                   -0.084  0.031  -0.140
# 1|userID[s_988]                                    0.085  0.031   0.028
# 1|userID_sigma                                     0.095  0.008   0.080
# C(task, levels=base_lvl)[Unfilled Delay]          -0.089  0.010  -0.108
# C(task, levels=base_lvl)[Filled Delay - vis]      -0.095  0.010  -0.113
# C(task, levels=base_lvl)[Filled Delay - emotions] -0.147  0.010  -0.164
# Intercept                                          0.864  0.013   0.839
# difficulty[2]                                     -0.036  0.008  -0.052
# difficulty[3]                                     -0.084  0.009  -0.099
# sigma                                              0.108  0.002   0.103
#
#                                                    hdi_97%  mcse_mean  \
# 1|userID[s_737]                                     -0.001      0.001
# 1|userID[s_742]                                      0.081      0.001
# 1|userID[s_785]                                      0.091      0.001
# 1|userID[s_8]                                        0.096      0.001
# 1|userID[s_805]                                      0.060      0.000
# 1|userID[s_807]                                      0.077      0.000
# 1|userID[s_812]                                     -0.036      0.000
# 1|userID[s_82]                                       0.012      0.001
# 1|userID[s_831]                                      0.119      0.000
# 1|userID[s_834]                                      0.140      0.001
# 1|userID[s_840]                                      0.016      0.000
# 1|userID[s_862]                                      0.192      0.001
# 1|userID[s_878]                                     -0.038      0.001
# 1|userID[s_879]                                     -0.020      0.000
# 1|userID[s_904]                                     -0.086      0.000
# 1|userID[s_908]                                      0.105      0.000
# 1|userID[s_912]                                      0.002      0.001
# 1|userID[s_925]                                      0.211      0.000
# 1|userID[s_939]                                     -0.005      0.000
# 1|userID[s_944]                                     -0.002      0.000
# 1|userID[s_959]                                     -0.026      0.000
# 1|userID[s_988]                                      0.145      0.000
# 1|userID_sigma                                       0.111      0.000
# C(task, levels=base_lvl)[Unfilled Delay]            -0.071      0.000
# C(task, levels=base_lvl)[Filled Delay - vis]        -0.077      0.000
# C(task, levels=base_lvl)[Filled Delay - emotions]   -0.128      0.000
# Intercept                                            0.889      0.000
# difficulty[2]                                       -0.020      0.000
# difficulty[3]                                       -0.066      0.000
# sigma                                                0.113      0.000
#
#                                                    mcse_sd  ess_bulk  \
# 1|userID[s_737]                                      0.000    3784.0
# 1|userID[s_742]                                      0.000    3669.0
# 1|userID[s_785]                                      0.000    3748.0
# 1|userID[s_8]                                        0.000    3149.0
# 1|userID[s_805]                                      0.001    4308.0
# 1|userID[s_807]                                      0.000    3744.0
# 1|userID[s_812]                                      0.000    4230.0
# 1|userID[s_82]                                       0.000    3773.0
# 1|userID[s_831]                                      0.000    3956.0
# 1|userID[s_834]                                      0.000    3782.0
# 1|userID[s_840]                                      0.000    3796.0
# 1|userID[s_862]                                      0.000    3796.0
# 1|userID[s_878]                                      0.000    3383.0
# 1|userID[s_879]                                      0.000    3953.0
# 1|userID[s_904]                                      0.000    4175.0
# 1|userID[s_908]                                      0.000    4268.0
# 1|userID[s_912]                                      0.000    3261.0
# 1|userID[s_925]                                      0.000    3929.0
# 1|userID[s_939]                                      0.000    3683.0
# 1|userID[s_944]                                      0.000    3860.0
# 1|userID[s_959]                                      0.000    4110.0
# 1|userID[s_988]                                      0.000    4258.0
# 1|userID_sigma                                       0.000     879.0
# C(task, levels=base_lvl)[Unfilled Delay]             0.000    4263.0
# C(task, levels=base_lvl)[Filled Delay - vis]         0.000    3879.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    0.000    3816.0
# Intercept                                            0.000    1196.0
# difficulty[2]                                        0.000    5229.0
# difficulty[3]                                        0.000    4763.0
# sigma                                                0.000    5277.0
#
#                                                    ess_tail  r_hat
# 1|userID[s_737]                                      2595.0   1.00
# 1|userID[s_742]                                      2995.0   1.00
# 1|userID[s_785]                                      2760.0   1.00
# 1|userID[s_8]                                        2922.0   1.00
# 1|userID[s_805]                                      2715.0   1.00
# 1|userID[s_807]                                      2375.0   1.00
# 1|userID[s_812]                                      3092.0   1.00
# 1|userID[s_82]                                       2685.0   1.00
# 1|userID[s_831]                                      2808.0   1.00
# 1|userID[s_834]                                      2920.0   1.00
# 1|userID[s_840]                                      3177.0   1.00
# 1|userID[s_862]                                      2542.0   1.00
# 1|userID[s_878]                                      2245.0   1.00
# 1|userID[s_879]                                      2935.0   1.00
# 1|userID[s_904]                                      3081.0   1.00
# 1|userID[s_908]                                      2907.0   1.00
# 1|userID[s_912]                                      2835.0   1.00
# 1|userID[s_925]                                      2808.0   1.00
# 1|userID[s_939]                                      2935.0   1.00
# 1|userID[s_944]                                      2895.0   1.00
# 1|userID[s_959]                                      3060.0   1.00
# 1|userID[s_988]                                      3160.0   1.00
# 1|userID_sigma                                       1183.0   1.01
# C(task, levels=base_lvl)[Unfilled Delay]             3133.0   1.00
# C(task, levels=base_lvl)[Filled Delay - vis]         3111.0   1.00
# C(task, levels=base_lvl)[Filled Delay - emotions]    3136.0   1.00
# Intercept                                            1510.0   1.00
# difficulty[2]                                        2964.0   1.00
# difficulty[3]                                        2933.0   1.00
# sigma                                                3056.0   1.00

# %% [markdown]
# ### Compare all data
# [top](#top)

# %%
df_compare_formulas_bernoulli = {}
for f in result_dic_bernoulli.keys():
    print(f, '\n')
    df_compare_formulas_bernoulli[f] = az.compare(result_dic_bernoulli[f])
    
    print(df_compare_formulas_bernoulli[f])
    
    az.plot_compare(df_compare_formulas_bernoulli[f], insample_dev=False);

    
    print()
# df_compare_formulas_bernoulli[f]
# Out:
# dataset_5
#
#                                                     rank    elpd_loo  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...     0  765.361076
# correct_flt ~ C(task, levels=base_lvl) * diffic...     1  763.791242
#
#                                                         p_loo  elpd_diff  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  78.178218   0.000000
# correct_flt ~ C(task, levels=base_lvl) * diffic...  84.498699   1.569834
#
#                                                      weight         se  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.63978  24.600149
# correct_flt ~ C(task, levels=base_lvl) * diffic...  0.36022  24.762995
#
#                                                          dse  warning scale
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.000000    False   log
# correct_flt ~ C(task, levels=base_lvl) * diffic...  3.332248    False   log

# %%
fig, ax = plt.subplots(figsize=(8, 4))
az.plot_forest(
    result_dic_bernoulli['dataset_5']['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'],
#     model_names=['Dataset 4'],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
az.plot_forest(
    list(result_dic_bernoulli['dataset_5'].values()),
    model_names=[f'{f}\n{formula}' for f in result_dic_bernoulli.keys() for formula in formulas2run],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
az.plot_forest(
    (list(result_dic_bernoulli['dataset_5'].values())
    )[::2],
#     model_names=[f'{f}' for f in result_dic_bernoulli.keys()],
    var_names=["C(task, levels=base_lvl):difficulty"],
    combined=True,
#     figsize=(12, 10)
    ax=ax
);

ax.axvline(0, c='k')

# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
# # plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
# plt.show()


# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.6, 1))
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
az.plot_forest(result_dic_bernoulli['dataset_5']['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'], 
               var_names=["C(task, levels=base_lvl):difficulty"], combined=True, figsize=(8, 4))
plt.axvline(0, c='k');

# %% [markdown]
# ### Run some predictions
# [top](#top)

# %%
interactions = ['Unfilled Delay, 2', 'Unfilled Delay, 3', 'Filled Delay - vis, 2', 'Filled Delay - vis, 3', 'Filled Delay - emotions, 2', 'Filled Delay - emotions, 3']
d2, d3, v2, v3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]

# %%
_, ax = plt.subplots()
for idx, x in enumerate([d2, d3, v2, v3, i2, i3]):
    az.plot_dist(x, label=x["C(task, levels=base_lvl):difficulty_dim"].item(), plot_kwargs={"color": f"C{idx}"}, ax=ax)
ax.legend(loc="upper left");

# %%
# Probability that the FM slope is less than 0

print(f"""
Probability that the UD slope is less than 0:
level 2: {(d2 < 0).mean().item()}
level 3: {(d3 < 0).mean().item()}
""")
# Out:
# Probability that the UD slope is less than 0:
# level 2: 0.65675
# level 3: 0.7705

# %% [markdown]
# ---

# %%
for f in result_dic_bernoulli.keys():

    d2, d3, m2, m3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]
    print(f"""
Experiment {f}:
  Probability that the UD slope is less than 0:
    level 2: {(d2 < 0).mean().item()}
    level 3: {(d3 < 0).mean().item()}
    
  Probability that the FD-v (Visual with vegetarian iterference) slope is less than 0:
    level 2: {(v2 < 0).mean().item()}
    level 3: {(v3 < 0).mean().item()}
    
  Probability that the FD-e slope is less than 0:
    level 2: {(i2 < 0).mean().item()}
    level 3: {(i3 < 0).mean().item()}
    
    """)
# Out:
# Experiment dataset_5:
#   Probability that the UD slope is less than 0:
#     level 2: 0.65675
#     level 3: 0.7705
#
#   Probability that the FD-v (Visual with vegetarian iterference) slope is less than 0:
#     level 2: 0.25275
#     level 3: 0.5995
#
#   Probability that the FD-e slope is less than 0:
#     level 2: 0.274
#     level 3: 0.0325

# %% [markdown]
# ### Save the inference
# [top](#top)
#
# It could be possible to use this:
# ```
# result_dic_bernoulli['dataset_5']['correct_flt ~ task * difficulty + (1|userID)'].to_netcdf()
# ```
#
# but it doesn't preserve the dictionary, so I use pickle.

# %%
# save the dictionary to a pickle file
with open(opj(path_inference_data,'FMP_vege_baselineFM_inference_data_dict.pkl'), 'wb') as f:
    pickle.dump(result_dic_bernoulli['dataset_5'], f)

# %%
# # Load the dictionary from the pickle file
# with open(opj(path_inference_data,'FMP_math_baselineFM_inference_data_dict.pkl'), 'rb') as f:
#     loaded_inference_data_dict = pickle.load(f)

# %%
# %load_ext watermark

# %watermark -a 'Jan Kadlec' -nmvu -iv -iv -w -p pytensor
# Out:
# Author: Jan Kadlec
#
# Last updated: Tue Jul 01 2025
#
# Python implementation: CPython
# Python version       : 3.12.5
# IPython version      : 8.25.0
#
# pytensor: 2.23.0
#
# Compiler    : GCC 12.4.0
# OS          : Linux
# Release     : 5.14.0-427.42.1.el9_4.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 96
# Architecture: 64bit
#
# sys       : 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:36:51) [GCC 12.4.0]
# matplotlib: 3.9.2
# numpy     : 1.26.4
# pandas    : 2.2.2
# bambi     : 0.14.0
# arviz     : 0.19.0
#
# Watermark: 2.4.3

# %% [markdown]
# [top](#top)
