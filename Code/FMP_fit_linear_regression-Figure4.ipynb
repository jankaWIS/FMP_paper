# %% [markdown]
# ##### top

# %% [markdown]
# # FMP modelling for Figure 4 (Math)
#
# This notebook runs Bayesian models on Datasets 4 (dataset with Math condition) that is described in the article to assess interaction between perception and memory difficulty levels in the FMP. We fit the following formulas to mean score within the condition. Throughout the notebook, I use `task` as a term for memory difficulty levels (M, UD, FD-e, FD-m), `difficulty` as a term for perceptual difficulty levels (1, 2, 3), and `userID` as a variable denoting individual participants.
#
#
# * Model task and difficulty interaction with user as a random effect. Equation:
#     * _correct_flt ~ task * difficulty + (1|userID)_
# * Model task and difficulty as main effects without interaction with user as a random effect. Equation:
#     * _correct_flt ~ task + difficulty + (1|userID)_
#
#
#
# We model mean accuracy per participant per condition.
#
#
# * [Models](#Models)
# * [Plot results](#Plot-results)
# * [Compare all data](#Compare-all-data)
# * [Save the inference](#Save-the-inference)

# %%
import os, sys
import pickle
from os.path import join as opj
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

az.style.use("arviz-darkgrid")
SEED = 7355608


# Importing module for functions
functions_modul =  "./functions"
sys.path.insert(0, functions_modul)

# import all processing and plotting functions
from bayesian_modelling_functions import fit_model, print_model

path_general = "../"
path_data = opj(path_general, "Data", "datasets")
path_inference_data = opj(path_general, "Data", "model_inference_data")


# set the numer of CPU
num_cpu = min(4, os.cpu_count()-1)
print(f'We will have {num_cpu} cores.\n')

path_dic = {
#     'dataset_1' : opj(path_data, 'FMP_dataset_1.csv'),
#     'dataset_2': opj(path_data, 'FMP_dataset_2.csv'),
#     'dataset_3': opj(path_data, 'FMP_dataset_3.csv'),
#     'concat_datasets_123': opj(path_data, 'FMP_concat_datasets_123.csv'),
    'dataset_4': opj(path_data, 'FMP_dataset_4.csv'),
}


# load all dataframes
df_dic = {}

# only selected cols
select_cols = ['stim1', 'stim2', 'target', 'RT', 'userID', 'difficulty', 'levels', 'task', 'correct_flt', 'order']


for f in path_dic.keys():   
    if f=="first_pilot":
        df_dic[f] = pd.read_csv(path_dic[f], usecols=(set(['correct_check'])|set(select_cols))-set(['correct_flt']))
        # convert boolean answers to floats to be able to do mean
        df_dic[f]['correct_flt'] = df_dic[f].correct_check.astype(float)
    elif 'longitudinal_' in f:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols+['target_loc', 'target_loc_simple'])
    else:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols)
    
    df_dic[f]["Experiment"] = f
        

    # clean
    df_dic[f].reset_index(drop=True, inplace=True)
    
    if 'Unnamed: 0' in df_dic[f].columns:
        df_dic[f].drop('Unnamed: 0', inplace=True, axis=1)
        
    
    # find low performing participants
    tt = df_dic[f].loc[df_dic[f]['task'].isin(['face matching', 'perc', 'perception'])].groupby(['userID', 'difficulty']).correct_flt.mean()

    drop_ptc = tt[tt<=0.5].reset_index().userID.values
    print(f'\nIn {f} dropping {len(drop_ptc)} participants for low accuracy in FM.')
    print(tt[tt<=0.5])

    # and remove them
    df_dic[f] = df_dic[f].loc[~df_dic[f]['userID'].isin(drop_ptc)]
    # clean up
    drop_ptc, tt = None, None
    
    print(f"\nThere is now N={df_dic[f]['userID'].unique().size} participants in {f}.")



#####
# rename the levels
rename_tasks_dic = {'perception':'Matching', 'perc':'Matching', 'blank':'Unfilled Delay', 'faces':'Filled Delay - emotions', 'math':'Filled Delay - math'}

# define orders
hue_order = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions']
hue_order_math = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - math']



# rename the memory task labels in the df
for f in df_dic.keys():
    if f=='noise':
        continue
    df_dic[f]['task'] = df_dic[f]['task'].map(rename_tasks_dic).fillna(df_dic[f]['task'])
# Out:
# We will have 4 cores.
#
#
# In dataset_4 dropping 0 participants for low accuracy in FM.
# Series([], Name: correct_flt, dtype: float64)
#
# There is now N=150 participants in dataset_4.

# %%
# select only specific datasets and prepare them
datasets2fit = ['dataset_4']

df_dic_fit = {}


for f in datasets2fit:
    data=None
    
    # groupby and make means for ptc and condition
    data = df_dic[f].groupby(['userID', 'task', 'difficulty'], observed=False).correct_flt.mean().reset_index()

    # convert all variables to categories
    # categorical_cols = data.columns[data.dtypes == object].tolist() + ['difficulty']
    categorical_cols = ['userID', 'task', 'difficulty']
    for col in categorical_cols:
        if col == 'task':
            # specify the order that we want
            data[col] = pd.Categorical(data[col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
            #['Unfilled Delay', 'Matching', 'Filled Delay - emotions']
            
            # also do it for the original datasets
            df_dic[f][col] = pd.Categorical(df_dic[f][col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
        else:
            data[col] = data[col].astype("category")
            df_dic[f][col] = df_dic[f][col].astype("category")

    # check
    print('\n',f)
    df_dic[f].info()
        
    # save
    df_dic_fit[f] = data.copy()

# # drop them for now
# data[data.correct_flt.isna()]
# Out:
#  dataset_4
# <class 'pandas.core.frame.DataFrame'>
# Index: 36000 entries, 0 to 35999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userID       36000 non-null  category
#  1   target       36000 non-null  object
#  2   stim1        36000 non-null  object
#  3   stim2        36000 non-null  object
#  4   correct_flt  35298 non-null  float64
#  5   RT           35298 non-null  float64
#  6   task         36000 non-null  category
#  7   order        36000 non-null  int64
#  8   difficulty   36000 non-null  category
#  9   levels       36000 non-null  int64
#  10  Experiment   36000 non-null  object
# dtypes: category(3), float64(2), int64(2), object(4)
# memory usage: 2.6+ MB

# %% [markdown]
# ## Model as means
# [top](#top)

# %%
model_assumptions = {
    "correct_flt ~ task * difficulty + (1|userID)": "Each user has their own baseline performance, but the effect of task and difficulty is assumed to be the same across all users.",
    "correct_flt ~ task + difficulty + (1|userID)": "Assumes that each user has their own baseline performance, but the effects of task and difficulty are consistent across all users without any interaction between task and difficulty.",
}

# define what we want to run
formulas2run = [
    "correct_flt ~ task * difficulty + (1|userID)",
    "correct_flt ~ task + difficulty + (1|userID)",
]

# %%
# define where we will store the results
model_dic_bernoulli = {}
result_dic_bernoulli = {}

for f in df_dic_fit.keys():
    print(f'\nFitting dataset {f}\n')
    # create datasets
    if f not in model_dic_bernoulli.keys():
        model_dic_bernoulli[f] = {}
    if f not in result_dic_bernoulli.keys():
        result_dic_bernoulli[f] = {}
    
    for formula in formulas2run:
        print(f'\nFitting formula {formula}\n')
    
        model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula] = fit_model(formula, df_dic_fit[f], categorical_cols,
                                                                                      num_cpu=num_cpu, check_priors=False, sample_priors=False)
# Out:
# Sampling 4 chains, 0 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:18
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 19 seconds.

# %%
model_dic_bernoulli[f][formulas2run[0]]
# Out:
#        Formula: correct_flt ~ task * difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.7247)
#             task ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#             task:difficulty ~ Normal(mu: [0. 0. 0. 0. 0. 0.], sigma: [1.3926 1.3926 1.3926 1.3926 1.3926
#                 1.3926])
#
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.7247))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
model_dic_bernoulli[f][formulas2run[1]]
# Out:
#        Formula: correct_flt ~ task + difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.6667)
#             task ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.6667))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# ### check priors

# %%
model_dic_bernoulli[f][formulas2run[0]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, Intercept, difficulty, sigma, task, task:difficulty]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'task\nMatching'}>,
#         <Axes: title={'center': 'task\nFilled Delay - emotions'}>],
#        [<Axes: title={'center': 'task\nFilled Delay - math'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': 'task:difficulty\nMatching, 2'}>],
#        [<Axes: title={'center': 'task:difficulty\nMatching, 3'}>,
#         <Axes: title={'center': 'task:difficulty\nFilled Delay - emotions, 2'}>,
#         <Axes: title={'center': 'task:difficulty\nFilled Delay - emotions, 3'}>,
#         <Axes: title={'center': 'task:difficulty\nFilled Delay - math, 2'}>],
#        [<Axes: title={'center': 'task:difficulty\nFilled Delay - math, 3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
model_dic_bernoulli[f][formulas2run[1]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, Intercept, difficulty, sigma, task]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'task\nMatching'}>,
#         <Axes: title={'center': 'task\nFilled Delay - emotions'}>],
#        [<Axes: title={'center': 'task\nFilled Delay - math'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>]], dtype=object)

# %% [markdown]
# ### check posterior

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[0]], 
                  var_names=['Intercept', 'difficulty', 'task'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'task\nMatching'}>,
#         <Axes: title={'center': 'task\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'task\nFilled Delay - math'}>]],
#       dtype=object)

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[1]], 
                  var_names=['Intercept', 'difficulty', 'task'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'task\nMatching'}>,
#         <Axes: title={'center': 'task\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'task\nFilled Delay - math'}>]],
#       dtype=object)

# %% [markdown]
# ---
# ## Plot results

# %% [markdown]
# ## FMP dataset 4 -- with Math condition
# [top](#top)

# %%
f = 'dataset_4'

print(f'Dataset: {f}')
for formula in formulas2run:
    print(f'\nFitting formula {formula}\n')
    print_model(model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula])
# Out:
# Dataset: dataset_4
#
# Fitting formula correct_flt ~ task * difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_100]  -0.161  0.030  -0.219   -0.105        0.0    0.000    5115.0
# 1|userID[s_1011] -0.012  0.030  -0.069    0.043        0.0    0.001    6017.0
# 1|userID[s_1015] -0.116  0.030  -0.177   -0.062        0.0    0.000    6661.0
# 1|userID[s_1016] -0.027  0.029  -0.082    0.028        0.0    0.000    5148.0
# 1|userID[s_1022] -0.081  0.031  -0.137   -0.023        0.0    0.000    6072.0
# 1|userID[s_1024]  0.035  0.030  -0.025    0.088        0.0    0.000    7925.0
# 1|userID[s_1032] -0.010  0.030  -0.066    0.044        0.0    0.000    5388.0
# 1|userID[s_107]   0.048  0.030  -0.006    0.108        0.0    0.000    6117.0
# 1|userID[s_108]   0.014  0.030  -0.044    0.070        0.0    0.001    6631.0
# 1|userID[s_1080] -0.124  0.031  -0.177   -0.063        0.0    0.000    5807.0
# 1|userID[s_1089]  0.068  0.030   0.015    0.128        0.0    0.000    6429.0
# 1|userID[s_1094] -0.049  0.031  -0.102    0.014        0.0    0.000    6028.0
# 1|userID[s_1103]  0.128  0.030   0.068    0.182        0.0    0.000    5663.0
# 1|userID[s_1110]  0.105  0.031   0.046    0.162        0.0    0.000    6776.0
# 1|userID[s_1112] -0.016  0.031  -0.072    0.043        0.0    0.000    6540.0
# 1|userID[s_1116]  0.025  0.031  -0.032    0.086        0.0    0.000    6621.0
# 1|userID[s_1126] -0.011  0.030  -0.071    0.042        0.0    0.001    6060.0
# 1|userID[s_1128] -0.045  0.030  -0.100    0.012        0.0    0.000    6397.0
# 1|userID[s_133]   0.028  0.030  -0.032    0.081        0.0    0.000    6052.0
# 1|userID[s_135]   0.071  0.031   0.013    0.131        0.0    0.000    5451.0
# 1|userID[s_157]  -0.060  0.030  -0.115   -0.003        0.0    0.000    6589.0
# 1|userID[s_160]  -0.091  0.031  -0.152   -0.034        0.0    0.000    6405.0
# 1|userID[s_166]  -0.041  0.030  -0.097    0.018        0.0    0.000    6881.0
# 1|userID[s_168]  -0.070  0.031  -0.129   -0.013        0.0    0.000    6140.0
# 1|userID[s_189]  -0.038  0.031  -0.095    0.020        0.0    0.000    7237.0
# 1|userID[s_190]  -0.147  0.029  -0.199   -0.091        0.0    0.000    6080.0
# 1|userID[s_205]   0.016  0.030  -0.041    0.071        0.0    0.000    5836.0
# 1|userID[s_23]   -0.007  0.030  -0.063    0.050        0.0    0.001    6720.0
# 1|userID[s_263]   0.037  0.030  -0.021    0.092        0.0    0.000    7493.0
# 1|userID[s_265]   0.002  0.031  -0.053    0.063        0.0    0.001    6785.0
#
#                   ess_tail  r_hat
# 1|userID[s_100]     2774.0    1.0
# 1|userID[s_1011]    2922.0    1.0
# 1|userID[s_1015]    2915.0    1.0
# 1|userID[s_1016]    2427.0    1.0
# 1|userID[s_1022]    2862.0    1.0
# 1|userID[s_1024]    3013.0    1.0
# 1|userID[s_1032]    2674.0    1.0
# 1|userID[s_107]     2489.0    1.0
# 1|userID[s_108]     2849.0    1.0
# 1|userID[s_1080]    2882.0    1.0
# 1|userID[s_1089]    2622.0    1.0
# 1|userID[s_1094]    3001.0    1.0
# 1|userID[s_1103]    2756.0    1.0
# 1|userID[s_1110]    2568.0    1.0
# 1|userID[s_1112]    3132.0    1.0
# 1|userID[s_1116]    2551.0    1.0
# 1|userID[s_1126]    2853.0    1.0
# 1|userID[s_1128]    2656.0    1.0
# 1|userID[s_133]     2475.0    1.0
# 1|userID[s_135]     2587.0    1.0
# 1|userID[s_157]     2892.0    1.0
# 1|userID[s_160]     3068.0    1.0
# 1|userID[s_166]     2297.0    1.0
# 1|userID[s_168]     2003.0    1.0
# 1|userID[s_189]     2670.0    1.0
# 1|userID[s_190]     2655.0    1.0
# 1|userID[s_205]     2447.0    1.0
# 1|userID[s_23]      2874.0    1.0
# 1|userID[s_263]     2647.0    1.0
# 1|userID[s_265]     2793.0    1.0
# ...
#
#                                               mean     sd  hdi_3%  hdi_97%  \
# 1|userID[s_882]                              0.080  0.031   0.025    0.142
# 1|userID[s_923]                             -0.080  0.031  -0.142   -0.026
# 1|userID[s_93]                               0.084  0.030   0.030    0.142
# 1|userID[s_931]                             -0.004  0.029  -0.059    0.050
# 1|userID[s_936]                              0.082  0.030   0.028    0.141
# 1|userID[s_937]                              0.111  0.031   0.049    0.167
# 1|userID[s_939]                             -0.110  0.030  -0.168   -0.055
# 1|userID[s_940]                              0.011  0.031  -0.042    0.074
# 1|userID[s_945]                              0.067  0.031   0.008    0.123
# 1|userID[s_958]                             -0.119  0.031  -0.177   -0.059
# 1|userID[s_960]                             -0.083  0.030  -0.142   -0.027
# 1|userID[s_966]                             -0.062  0.030  -0.117   -0.004
# 1|userID[s_975]                              0.039  0.029  -0.014    0.096
# 1|userID[s_976]                              0.113  0.030   0.057    0.169
# 1|userID[s_993]                              0.012  0.031  -0.045    0.070
# 1|userID[s_996]                              0.041  0.030  -0.018    0.096
# 1|userID_sigma                               0.084  0.005   0.074    0.095
# Intercept                                    0.795  0.011   0.775    0.816
# difficulty[2]                               -0.028  0.013  -0.051   -0.003
# difficulty[3]                               -0.098  0.012  -0.121   -0.075
# sigma                                        0.110  0.002   0.106    0.113
# task[Matching]                               0.098  0.013   0.075    0.123
# task[Filled Delay - emotions]               -0.094  0.013  -0.117   -0.070
# task[Filled Delay - math]                   -0.009  0.013  -0.033    0.015
# task:difficulty[Matching, 2]                -0.007  0.018  -0.043    0.026
# task:difficulty[Matching, 3]                 0.004  0.018  -0.030    0.037
# task:difficulty[Filled Delay - emotions, 2]  0.016  0.018  -0.018    0.049
# task:difficulty[Filled Delay - emotions, 3]  0.039  0.017   0.008    0.072
# task:difficulty[Filled Delay - math, 2]      0.002  0.018  -0.031    0.036
# task:difficulty[Filled Delay - math, 3]      0.021  0.018  -0.013    0.053
#
#                                              mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_882]                                    0.0    0.000    6276.0
# 1|userID[s_923]                                    0.0    0.000    6465.0
# 1|userID[s_93]                                     0.0    0.000    6986.0
# 1|userID[s_931]                                    0.0    0.000    6114.0
# 1|userID[s_936]                                    0.0    0.000    6079.0
# 1|userID[s_937]                                    0.0    0.000    6907.0
# 1|userID[s_939]                                    0.0    0.000    6282.0
# 1|userID[s_940]                                    0.0    0.001    6217.0
# 1|userID[s_945]                                    0.0    0.000    6951.0
# 1|userID[s_958]                                    0.0    0.000    5612.0
# 1|userID[s_960]                                    0.0    0.000    6660.0
# 1|userID[s_966]                                    0.0    0.000    6267.0
# 1|userID[s_975]                                    0.0    0.000    5907.0
# 1|userID[s_976]                                    0.0    0.000    5427.0
# 1|userID[s_993]                                    0.0    0.001    6247.0
# 1|userID[s_996]                                    0.0    0.000    6758.0
# 1|userID_sigma                                     0.0    0.000    1355.0
# Intercept                                          0.0    0.000    1180.0
# difficulty[2]                                      0.0    0.000    1864.0
# difficulty[3]                                      0.0    0.000    1889.0
# sigma                                              0.0    0.000    6623.0
# task[Matching]                                     0.0    0.000    2130.0
# task[Filled Delay - emotions]                      0.0    0.000    2138.0
# task[Filled Delay - math]                          0.0    0.000    2175.0
# task:difficulty[Matching, 2]                       0.0    0.000    2478.0
# task:difficulty[Matching, 3]                       0.0    0.000    2249.0
# task:difficulty[Filled Delay - emotions, 2]        0.0    0.000    2402.0
# task:difficulty[Filled Delay - emotions, 3]        0.0    0.000    2164.0
# task:difficulty[Filled Delay - math, 2]            0.0    0.000    2279.0
# task:difficulty[Filled Delay - math, 3]            0.0    0.000    2280.0
#
#                                              ess_tail  r_hat
# 1|userID[s_882]                                2474.0    1.0
# 1|userID[s_923]                                2542.0    1.0
# 1|userID[s_93]                                 3010.0    1.0
# 1|userID[s_931]                                2994.0    1.0
# 1|userID[s_936]                                2903.0    1.0
# 1|userID[s_937]                                2761.0    1.0
# 1|userID[s_939]                                2969.0    1.0
# 1|userID[s_940]                                2532.0    1.0
# 1|userID[s_945]                                2725.0    1.0
# 1|userID[s_958]                                2756.0    1.0
# 1|userID[s_960]                                2560.0    1.0
# 1|userID[s_966]                                3008.0    1.0
# 1|userID[s_975]                                2712.0    1.0
# 1|userID[s_976]                                2639.0    1.0
# 1|userID[s_993]                                2535.0    1.0
# 1|userID[s_996]                                2599.0    1.0
# 1|userID_sigma                                 2146.0    1.0
# Intercept                                      2320.0    1.0
# difficulty[2]                                  2598.0    1.0
# difficulty[3]                                  2596.0    1.0
# sigma                                          2775.0    1.0
# task[Matching]                                 2888.0    1.0
# task[Filled Delay - emotions]                  2721.0    1.0
# task[Filled Delay - math]                      2689.0    1.0
# task:difficulty[Matching, 2]                   2676.0    1.0
# task:difficulty[Matching, 3]                   3079.0    1.0
# task:difficulty[Filled Delay - emotions, 2]    2874.0    1.0
# task:difficulty[Filled Delay - emotions, 3]    2837.0    1.0
# task:difficulty[Filled Delay - math, 2]        2833.0    1.0
# task:difficulty[Filled Delay - math, 3]        2878.0    1.0
#
# Fitting formula correct_flt ~ task + difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_100]  -0.162  0.030  -0.218   -0.105        0.0    0.000    5633.0
# 1|userID[s_1011] -0.011  0.031  -0.069    0.045        0.0    0.001    6511.0
# 1|userID[s_1015] -0.116  0.030  -0.173   -0.060        0.0    0.000    6013.0
# 1|userID[s_1016] -0.027  0.029  -0.081    0.027        0.0    0.000    6375.0
# 1|userID[s_1022] -0.082  0.030  -0.141   -0.028        0.0    0.000    5928.0
# 1|userID[s_1024]  0.035  0.030  -0.021    0.093        0.0    0.000    5843.0
# 1|userID[s_1032] -0.010  0.031  -0.067    0.046        0.0    0.000    6292.0
# 1|userID[s_107]   0.047  0.031  -0.012    0.105        0.0    0.000    5839.0
# 1|userID[s_108]   0.013  0.030  -0.046    0.068        0.0    0.001    7093.0
# 1|userID[s_1080] -0.123  0.031  -0.182   -0.066        0.0    0.000    6123.0
# 1|userID[s_1089]  0.069  0.031   0.010    0.126        0.0    0.000    5860.0
# 1|userID[s_1094] -0.049  0.030  -0.107    0.006        0.0    0.000    5988.0
# 1|userID[s_1103]  0.127  0.029   0.073    0.182        0.0    0.000    5442.0
# 1|userID[s_1110]  0.105  0.030   0.050    0.164        0.0    0.000    5491.0
# 1|userID[s_1112] -0.016  0.030  -0.077    0.036        0.0    0.000    5279.0
# 1|userID[s_1116]  0.025  0.030  -0.033    0.080        0.0    0.000    5950.0
# 1|userID[s_1126] -0.011  0.030  -0.070    0.044        0.0    0.000    5578.0
# 1|userID[s_1128] -0.045  0.029  -0.097    0.012        0.0    0.000    6420.0
# 1|userID[s_133]   0.027  0.030  -0.030    0.084        0.0    0.000    6878.0
# 1|userID[s_135]   0.072  0.031   0.015    0.134        0.0    0.000    6537.0
# 1|userID[s_157]  -0.060  0.030  -0.117   -0.005        0.0    0.000    5441.0
# 1|userID[s_160]  -0.091  0.030  -0.146   -0.033        0.0    0.000    5849.0
# 1|userID[s_166]  -0.041  0.029  -0.096    0.014        0.0    0.000    6879.0
# 1|userID[s_168]  -0.071  0.030  -0.128   -0.016        0.0    0.000    5890.0
# 1|userID[s_189]  -0.038  0.029  -0.092    0.018        0.0    0.000    6506.0
# 1|userID[s_190]  -0.148  0.030  -0.206   -0.095        0.0    0.000    5093.0
# 1|userID[s_205]   0.016  0.031  -0.039    0.074        0.0    0.000    6292.0
# 1|userID[s_23]   -0.007  0.030  -0.065    0.048        0.0    0.001    6600.0
# 1|userID[s_263]   0.037  0.030  -0.017    0.094        0.0    0.000    6641.0
# 1|userID[s_265]   0.002  0.030  -0.051    0.063        0.0    0.001    6272.0
#
#                   ess_tail  r_hat
# 1|userID[s_100]     2878.0    1.0
# 1|userID[s_1011]    2396.0    1.0
# 1|userID[s_1015]    2493.0    1.0
# 1|userID[s_1016]    2927.0    1.0
# 1|userID[s_1022]    2451.0    1.0
# 1|userID[s_1024]    2796.0    1.0
# 1|userID[s_1032]    2776.0    1.0
# 1|userID[s_107]     2397.0    1.0
# 1|userID[s_108]     2661.0    1.0
# 1|userID[s_1080]    2851.0    1.0
# 1|userID[s_1089]    2416.0    1.0
# 1|userID[s_1094]    2798.0    1.0
# 1|userID[s_1103]    2681.0    1.0
# 1|userID[s_1110]    2611.0    1.0
# 1|userID[s_1112]    2721.0    1.0
# 1|userID[s_1116]    2952.0    1.0
# 1|userID[s_1126]    3086.0    1.0
# 1|userID[s_1128]    2933.0    1.0
# 1|userID[s_133]     2374.0    1.0
# 1|userID[s_135]     2924.0    1.0
# 1|userID[s_157]     2836.0    1.0
# 1|userID[s_160]     2826.0    1.0
# 1|userID[s_166]     2599.0    1.0
# 1|userID[s_168]     2689.0    1.0
# 1|userID[s_189]     3053.0    1.0
# 1|userID[s_190]     2846.0    1.0
# 1|userID[s_205]     2796.0    1.0
# 1|userID[s_23]      2400.0    1.0
# 1|userID[s_263]     2941.0    1.0
# 1|userID[s_265]     2681.0    1.0
# ...
#
#                                 mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# 1|userID[s_858]                0.006  0.030  -0.052    0.061        0.0
# 1|userID[s_860]               -0.047  0.031  -0.108    0.010        0.0
# 1|userID[s_865]               -0.084  0.030  -0.141   -0.027        0.0
# 1|userID[s_870]               -0.008  0.030  -0.060    0.052        0.0
# 1|userID[s_874]                0.007  0.030  -0.052    0.062        0.0
# 1|userID[s_875]                0.073  0.030   0.017    0.130        0.0
# 1|userID[s_882]                0.079  0.030   0.023    0.135        0.0
# 1|userID[s_923]               -0.081  0.030  -0.137   -0.026        0.0
# 1|userID[s_93]                 0.084  0.031   0.032    0.145        0.0
# 1|userID[s_931]               -0.004  0.031  -0.060    0.053        0.0
# 1|userID[s_936]                0.082  0.031   0.025    0.141        0.0
# 1|userID[s_937]                0.111  0.029   0.055    0.162        0.0
# 1|userID[s_939]               -0.111  0.031  -0.171   -0.056        0.0
# 1|userID[s_940]                0.011  0.031  -0.046    0.069        0.0
# 1|userID[s_945]                0.067  0.031   0.008    0.122        0.0
# 1|userID[s_958]               -0.120  0.031  -0.176   -0.062        0.0
# 1|userID[s_960]               -0.083  0.030  -0.141   -0.030        0.0
# 1|userID[s_966]               -0.061  0.030  -0.114    0.000        0.0
# 1|userID[s_975]                0.039  0.030  -0.016    0.096        0.0
# 1|userID[s_976]                0.112  0.031   0.052    0.168        0.0
# 1|userID[s_993]                0.011  0.030  -0.046    0.066        0.0
# 1|userID[s_996]                0.041  0.030  -0.012    0.099        0.0
# 1|userID_sigma                 0.084  0.006   0.074    0.095        0.0
# Intercept                      0.789  0.009   0.772    0.806        0.0
# difficulty[2]                 -0.025  0.006  -0.036   -0.012        0.0
# difficulty[3]                 -0.082  0.006  -0.094   -0.070        0.0
# sigma                          0.110  0.002   0.106    0.113        0.0
# task[Matching]                 0.096  0.007   0.083    0.109        0.0
# task[Filled Delay - emotions] -0.075  0.007  -0.089   -0.062        0.0
# task[Filled Delay - math]     -0.002  0.007  -0.015    0.013        0.0
#
#                                mcse_sd  ess_bulk  ess_tail  r_hat
# 1|userID[s_858]                  0.001    5878.0    2419.0    1.0
# 1|userID[s_860]                  0.000    6823.0    2809.0    1.0
# 1|userID[s_865]                  0.000    5897.0    2714.0    1.0
# 1|userID[s_870]                  0.001    6166.0    2720.0    1.0
# 1|userID[s_874]                  0.001    6989.0    2591.0    1.0
# 1|userID[s_875]                  0.000    5880.0    2735.0    1.0
# 1|userID[s_882]                  0.000    5139.0    2135.0    1.0
# 1|userID[s_923]                  0.000    6266.0    2847.0    1.0
# 1|userID[s_93]                   0.000    5082.0    2447.0    1.0
# 1|userID[s_931]                  0.001    5836.0    2881.0    1.0
# 1|userID[s_936]                  0.000    6385.0    2711.0    1.0
# 1|userID[s_937]                  0.000    5572.0    3008.0    1.0
# 1|userID[s_939]                  0.000    6815.0    2848.0    1.0
# 1|userID[s_940]                  0.000    6611.0    2947.0    1.0
# 1|userID[s_945]                  0.000    5214.0    2628.0    1.0
# 1|userID[s_958]                  0.000    5630.0    2828.0    1.0
# 1|userID[s_960]                  0.000    5436.0    2638.0    1.0
# 1|userID[s_966]                  0.000    7252.0    2265.0    1.0
# 1|userID[s_975]                  0.000    7306.0    2860.0    1.0
# 1|userID[s_976]                  0.000    6229.0    2858.0    1.0
# 1|userID[s_993]                  0.001    6881.0    2525.0    1.0
# 1|userID[s_996]                  0.000    5131.0    2879.0    1.0
# 1|userID_sigma                   0.000    1320.0    1617.0    1.0
# Intercept                        0.000    1747.0    2151.0    1.0
# difficulty[2]                    0.000    5861.0    3108.0    1.0
# difficulty[3]                    0.000    5898.0    3066.0    1.0
# sigma                            0.000    5520.0    3266.0    1.0
# task[Matching]                   0.000    5329.0    3048.0    1.0
# task[Filled Delay - emotions]    0.000    5150.0    3218.0    1.0
# task[Filled Delay - math]        0.000    5739.0    3072.0    1.0

# %% [markdown]
# ### Compare all data
# [top](#top)

# %%
df_compare_formulas_bernoulli = {}
for f in result_dic_bernoulli.keys():
    print(f, '\n')
    df_compare_formulas_bernoulli[f] = az.compare(result_dic_bernoulli[f])
    
    print(df_compare_formulas_bernoulli[f])
    
    az.plot_compare(df_compare_formulas_bernoulli[f], insample_dev=False);

    
    print()
# df_compare_formulas_bernoulli[f]
# Out:
# dataset_4
#
#                                               rank     elpd_loo       p_loo  \
# correct_flt ~ task + difficulty + (1|userID)     0  1354.453077  133.303402
# correct_flt ~ task * difficulty + (1|userID)     1  1351.252858  139.070257
#
#                                               elpd_diff    weight         se  \
# correct_flt ~ task + difficulty + (1|userID)   0.000000  0.954843  30.649723
# correct_flt ~ task * difficulty + (1|userID)   3.200219  0.045157  30.894541
#
#                                                    dse  warning scale
# correct_flt ~ task + difficulty + (1|userID)  0.000000    False   log
# correct_flt ~ task * difficulty + (1|userID)  2.655897    False   log

# %%
fig, ax = plt.subplots(figsize=(8, 4))
az.plot_forest(
    result_dic_bernoulli['dataset_4']['correct_flt ~ task * difficulty + (1|userID)'],
#     model_names=['Dataset 4'],
    var_names=["Intercept", "difficulty", "task"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
az.plot_forest(
    list(result_dic_bernoulli['dataset_4'].values()),
    model_names=[f'{f}\n{formula}' for f in result_dic_bernoulli.keys() for formula in formulas2run],
    var_names=["Intercept", "difficulty", "task"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
az.plot_forest(
    (list(result_dic_bernoulli['dataset_4'].values())
    )[::2],
#     model_names=[f'{f}' for f in result_dic_bernoulli.keys()],
    var_names=["task:difficulty"],
    combined=True,
#     figsize=(12, 10)
    ax=ax
);

ax.axvline(0, c='k')

# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
# # plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
# plt.show()


# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.6, 1))
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %% [markdown]
# ### Run some predictions
# [top](#top)

# %%
# interactions = ['face matching, 2', 'face matching, 3', 'math, 2', 'math, 3', 'interference, 2', 'interference, 3']
interactions = ['Matching, 2', 'Matching, 3', 'Filled Delay - math, 2', 'Filled Delay - math, 3', 'Filled Delay - emotions, 2', 'Filled Delay - emotions, 3']
fm2, fm3, m2, m3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ task * difficulty + (1|userID)'].posterior["task:difficulty"].sel({"task:difficulty_dim":tsk}) for tsk in interactions]

# %%
_, ax = plt.subplots()
for idx, x in enumerate([fm2, fm3, m2, m3, i2, i3]):
    az.plot_dist(x, label=x["task:difficulty_dim"].item(), plot_kwargs={"color": f"C{idx}"}, ax=ax)
ax.legend(loc="upper left");

# %%
# Probability that the FM slope is less than 0

print(f"""
Probability that the M slope is less than 0:
level 2: {(fm2 < 0).mean().item()}
level 3: {(fm3 < 0).mean().item()}
""")
# Out:
# Probability that the M slope is less than 0:
# level 2: 0.652
# level 3: 0.41375

# %% [markdown]
# ---

# %%
for f in result_dic_bernoulli.keys():

    fm2, fm3, m2, m3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ task * difficulty + (1|userID)'].posterior["task:difficulty"].sel({"task:difficulty_dim":tsk}) for tsk in interactions]
    print(f"""
Experiment {f}:
  Probability that the M slope is less than 0:
    level 2: {(fm2 < 0).mean().item()}
    level 3: {(fm3 < 0).mean().item()}
    
  Probability that the FD-m (Math) slope is less than 0:
    level 2: {(m2 < 0).mean().item()}
    level 3: {(m3 < 0).mean().item()}
    
  Probability that the FD-e slope is less than 0:
    level 2: {(i2 < 0).mean().item()}
    level 3: {(i3 < 0).mean().item()}
    
    """)
# Out:
# Experiment dataset_4:
#   Probability that the M slope is less than 0:
#     level 2: 0.652
#     level 3: 0.41375
#
#   Probability that the FD-m (Math) slope is less than 0:
#     level 2: 0.4635
#     level 3: 0.12025
#
#   Probability that the FD-e slope is less than 0:
#     level 2: 0.19475
#     level 3: 0.01275

# %% [markdown]
# ### Save the inference
# [top](#top)
#
# It could be possible to use this:
# ```
# result_dic_bernoulli['randomised_postpilot_with_math']['correct_flt ~ task * difficulty + (1|userID)'].to_netcdf()
# ```
#
# but it doesn't preserve the dictionary, so I use pickle.

# %%
# save the dictionary to a pickle file
with open(opj(path_inference_data,'FMP_math_inference_data_dict.pkl'), 'wb') as f:
    pickle.dump(result_dic_bernoulli['dataset_4'], f)

# %%
# # Load the dictionary from the pickle file
# with open(opj(path_inference_data,'FMP_math_inference_data_dict.pkl'), 'rb') as f:
#     loaded_inference_data_dict = pickle.load(f)

# %%
# %load_ext watermark

# %watermark -a 'Jan Kadlec' -nmvu -iv -iv -w -p pytensor
# Out:
# Author: Jan Kadlec
#
# Last updated: Wed Feb 05 2025
#
# Python implementation: CPython
# Python version       : 3.12.5
# IPython version      : 8.25.0
#
# pytensor: 2.23.0
#
# Compiler    : GCC 12.4.0
# OS          : Linux
# Release     : 5.14.0-427.42.1.el9_4.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 96
# Architecture: 64bit
#
# matplotlib: 3.9.2
# pandas    : 2.2.2
# bambi     : 0.14.0
# arviz     : 0.19.0
# sys       : 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:36:51) [GCC 12.4.0]
# numpy     : 1.26.4
#
# Watermark: 2.4.3

# %% [markdown]
# [top](#top)
