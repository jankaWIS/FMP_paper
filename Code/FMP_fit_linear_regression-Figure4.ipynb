# %% [markdown]
# ##### top

# %% [markdown]
# # FMP modelling for Figure 4 (Math)
#
# This notebook runs Bayesian models on Datasets 4 (dataset with Math condition) that is described in the article to assess interaction between perception and memory difficulty levels in the FMP. We fit the following formulas to mean score within the condition. Throughout the notebook, I use `task` as a term for memory difficulty levels (M, UD, FD-e, FD-m), `difficulty` as a term for perceptual difficulty levels (1, 2, 3), and `userID` as a variable denoting individual participants.
#
#
# * Model task and difficulty interaction with user as a random effect. Equation:
#     * _correct_flt ~ task * difficulty + (1|userID)_
# * Model task and difficulty as main effects without interaction with user as a random effect. Equation:
#     * _correct_flt ~ task + difficulty + (1|userID)_
#
#
#
# We model mean accuracy per participant per condition.
#
#
# * [Models](#Models)
# * [Plot results](#Plot-results)
# * [Compare all data](#Compare-all-data)
# * [Save the inference](#Save-the-inference)

# %%
import os, sys
import pickle
from os.path import join as opj
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

az.style.use("arviz-darkgrid")
SEED = 7355608


# Importing module for functions
functions_modul =  "./functions"
sys.path.insert(0, functions_modul)

# import all processing and plotting functions
from bayesian_modelling_functions import fit_model, print_model

path_general = "../"
path_data = opj(path_general, "Data", "datasets")
path_inference_data = opj(path_general, "Data", "model_inference_data")


# set the numer of CPU
num_cpu = min(4, os.cpu_count()-1)
print(f'We will have {num_cpu} cores.\n')

path_dic = {
#     'dataset_1' : opj(path_data, 'FMP_dataset_1.csv'),
#     'dataset_2': opj(path_data, 'FMP_dataset_2.csv'),
#     'dataset_3': opj(path_data, 'FMP_dataset_3.csv'),
#     'concat_datasets_123': opj(path_data, 'FMP_concat_datasets_123.csv'),
    'dataset_4': opj(path_data, 'FMP_dataset_4.csv'),
}


# load all dataframes
df_dic = {}

# only selected cols
select_cols = ['stim1', 'stim2', 'target', 'RT', 'userID', 'difficulty', 'levels', 'task', 'correct_flt', 'order']


for f in path_dic.keys():   
    if f=="first_pilot":
        df_dic[f] = pd.read_csv(path_dic[f], usecols=(set(['correct_check'])|set(select_cols))-set(['correct_flt']))
        # convert boolean answers to floats to be able to do mean
        df_dic[f]['correct_flt'] = df_dic[f].correct_check.astype(float)
    elif 'longitudinal_' in f:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols+['target_loc', 'target_loc_simple'])
    else:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols)
    
    df_dic[f]["Experiment"] = f
        

    # clean
    df_dic[f].reset_index(drop=True, inplace=True)
    
    if 'Unnamed: 0' in df_dic[f].columns:
        df_dic[f].drop('Unnamed: 0', inplace=True, axis=1)
        
    
    # find low performing participants
    tt = df_dic[f].loc[df_dic[f]['task'].isin(['face matching', 'perc', 'perception'])].groupby(['userID', 'difficulty']).correct_flt.mean()

    drop_ptc = tt[tt<=0.5].reset_index().userID.values
    print(f'\nIn {f} dropping {len(drop_ptc)} participants for low accuracy in FM.')
    print(tt[tt<=0.5])

    # and remove them
    df_dic[f] = df_dic[f].loc[~df_dic[f]['userID'].isin(drop_ptc)]
    # clean up
    drop_ptc, tt = None, None
    
    print(f"\nThere is now N={df_dic[f]['userID'].unique().size} participants in {f}.")



#####
# rename the levels
rename_tasks_dic = {'perception':'Matching', 'perc':'Matching', 'blank':'Unfilled Delay', 'faces':'Filled Delay - emotions', 'math':'Filled Delay - math'}

# define orders
hue_order = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions']
hue_order_math = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - math']



# rename the memory task labels in the df
for f in df_dic.keys():
    if f=='noise':
        continue
    df_dic[f]['task'] = df_dic[f]['task'].map(rename_tasks_dic).fillna(df_dic[f]['task'])
# Out:
# We will have 4 cores.
#
#
# In dataset_4 dropping 0 participants for low accuracy in FM.
# Series([], Name: correct_flt, dtype: float64)
#
# There is now N=150 participants in dataset_4.

# %%
# select only specific datasets and prepare them
datasets2fit = ['dataset_4']

df_dic_fit = {}


for f in datasets2fit:
    data=None
    
    # groupby and make means for ptc and condition
    data = df_dic[f].groupby(['userID', 'task', 'difficulty'], observed=False).correct_flt.mean().reset_index()

    # convert all variables to categories
    # categorical_cols = data.columns[data.dtypes == object].tolist() + ['difficulty']
    categorical_cols = ['userID', 'task', 'difficulty']
    for col in categorical_cols:
        if col == 'task':
            # specify the order that we want
            data[col] = pd.Categorical(data[col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
            #['Unfilled Delay', 'Matching', 'Filled Delay - emotions']
            
            # also do it for the original datasets
            df_dic[f][col] = pd.Categorical(df_dic[f][col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
        else:
            data[col] = data[col].astype("category")
            df_dic[f][col] = df_dic[f][col].astype("category")

    # check
    print('\n',f)
    df_dic[f].info()
        
    # save
    df_dic_fit[f] = data.copy()

# # drop them for now
# data[data.correct_flt.isna()]
# Out:
#  dataset_4
# <class 'pandas.core.frame.DataFrame'>
# Index: 36000 entries, 0 to 35999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userID       36000 non-null  category
#  1   target       36000 non-null  object
#  2   stim1        36000 non-null  object
#  3   stim2        36000 non-null  object
#  4   correct_flt  35298 non-null  float64
#  5   RT           35298 non-null  float64
#  6   task         36000 non-null  category
#  7   order        36000 non-null  int64
#  8   difficulty   36000 non-null  category
#  9   levels       36000 non-null  int64
#  10  Experiment   36000 non-null  object
# dtypes: category(3), float64(2), int64(2), object(4)
# memory usage: 2.6+ MB

# %% [markdown]
# ## Model as means
# [top](#top)

# %%
model_assumptions = {
    "correct_flt ~ task * difficulty + (1|userID)": "Each user has their own baseline performance, but the effect of task and difficulty is assumed to be the same across all users.",
    "correct_flt ~ task + difficulty + (1|userID)": "Assumes that each user has their own baseline performance, but the effects of task and difficulty are consistent across all users without any interaction between task and difficulty.",
}

# define what we want to run
formulas2run = [
    "correct_flt ~ task * difficulty + (1|userID)",
    "correct_flt ~ task + difficulty + (1|userID)",
]

# %%
# define where we will store the results
model_dic_bernoulli = {}
result_dic_bernoulli = {}

for f in df_dic_fit.keys():
    print(f'\nFitting dataset {f}\n')
    # create datasets
    if f not in model_dic_bernoulli.keys():
        model_dic_bernoulli[f] = {}
    if f not in result_dic_bernoulli.keys():
        result_dic_bernoulli[f] = {}
    
    for formula in formulas2run:
        print(f'\nFitting formula {formula}\n')
    
        model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula] = fit_model(formula, df_dic_fit[f], categorical_cols,
                                                                                      num_cpu=num_cpu, check_priors=False, sample_priors=False)
# Out:
# Sampling 4 chains, 0 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:21
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 21 seconds.

# %%
model_dic_bernoulli[f][formulas2run[0]]
# Out:
#        Formula: correct_flt ~ task * difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.7247)
#             task ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#             task:difficulty ~ Normal(mu: [0. 0. 0. 0. 0. 0.], sigma: [1.3926 1.3926 1.3926 1.3926 1.3926
#                 1.3926])
#
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.7247))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
model_dic_bernoulli[f][formulas2run[1]]
# Out:
#        Formula: correct_flt ~ task + difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.6667)
#             task ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.6667))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# ### check priors

# %%
model_dic_bernoulli[f][formulas2run[0]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, Intercept, difficulty, sigma, task, task:difficulty]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'task\nMatching'}>,
#         <Axes: title={'center': 'task\nFilled Delay - emotions'}>],
#        [<Axes: title={'center': 'task\nFilled Delay - math'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': 'task:difficulty\nMatching, 2'}>],
#        [<Axes: title={'center': 'task:difficulty\nMatching, 3'}>,
#         <Axes: title={'center': 'task:difficulty\nFilled Delay - emotions, 2'}>,
#         <Axes: title={'center': 'task:difficulty\nFilled Delay - emotions, 3'}>,
#         <Axes: title={'center': 'task:difficulty\nFilled Delay - math, 2'}>],
#        [<Axes: title={'center': 'task:difficulty\nFilled Delay - math, 3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
model_dic_bernoulli[f][formulas2run[1]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, Intercept, difficulty, sigma, task]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'task\nMatching'}>,
#         <Axes: title={'center': 'task\nFilled Delay - emotions'}>],
#        [<Axes: title={'center': 'task\nFilled Delay - math'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>]], dtype=object)

# %% [markdown]
# ### check posterior

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[0]], 
                  var_names=['Intercept', 'difficulty', 'task'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'task\nMatching'}>,
#         <Axes: title={'center': 'task\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'task\nFilled Delay - math'}>]],
#       dtype=object)

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[1]], 
                  var_names=['Intercept', 'difficulty', 'task'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'task\nMatching'}>,
#         <Axes: title={'center': 'task\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'task\nFilled Delay - math'}>]],
#       dtype=object)

# %% [markdown]
# ---
# ## Plot results

# %% [markdown]
# ## FMP dataset 4 -- with Math condition
# [top](#top)

# %%
f = 'dataset_4'

print(f'Dataset: {f}')
for formula in formulas2run:
    print(f'\nFitting formula {formula}\n')
    print_model(model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula])
# Out:
# Dataset: dataset_4
#
# Fitting formula correct_flt ~ task * difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1010] -0.052  0.030  -0.110    0.004        0.0    0.000    6184.0
# 1|userID[s_1018] -0.041  0.031  -0.098    0.016        0.0    0.000    6966.0
# 1|userID[s_1024]  0.041  0.031  -0.014    0.103        0.0    0.000    6984.0
# 1|userID[s_1029]  0.027  0.030  -0.028    0.084        0.0    0.000    6329.0
# 1|userID[s_1031]  0.013  0.031  -0.044    0.070        0.0    0.000    6585.0
# 1|userID[s_1035]  0.067  0.031   0.007    0.123        0.0    0.000    7080.0
# 1|userID[s_1037] -0.084  0.031  -0.143   -0.027        0.0    0.000    5969.0
# 1|userID[s_1041]  0.031  0.030  -0.026    0.086        0.0    0.000    6107.0
# 1|userID[s_1054]  0.007  0.031  -0.049    0.066        0.0    0.001    6663.0
# 1|userID[s_1059]  0.069  0.031   0.011    0.128        0.0    0.000    6461.0
# 1|userID[s_1066] -0.037  0.030  -0.094    0.019        0.0    0.000    6719.0
# 1|userID[s_1075]  0.063  0.030   0.010    0.122        0.0    0.000    5939.0
# 1|userID[s_1089]  0.113  0.030   0.056    0.169        0.0    0.000    7614.0
# 1|userID[s_1090] -0.059  0.031  -0.116   -0.002        0.0    0.000    5902.0
# 1|userID[s_1094] -0.007  0.031  -0.065    0.051        0.0    0.001    7445.0
# 1|userID[s_1099]  0.067  0.030   0.008    0.119        0.0    0.000    6053.0
# 1|userID[s_1117]  0.035  0.031  -0.023    0.091        0.0    0.000    7739.0
# 1|userID[s_112]  -0.004  0.031  -0.058    0.059        0.0    0.001    7225.0
# 1|userID[s_1121]  0.072  0.030   0.019    0.128        0.0    0.000    5968.0
# 1|userID[s_1124] -0.018  0.030  -0.072    0.038        0.0    0.000    6184.0
# 1|userID[s_128]  -0.091  0.030  -0.147   -0.037        0.0    0.000    7333.0
# 1|userID[s_139]  -0.127  0.030  -0.187   -0.076        0.0    0.000    6795.0
# 1|userID[s_168]   0.145  0.030   0.086    0.199        0.0    0.000    6143.0
# 1|userID[s_184]  -0.157  0.030  -0.215   -0.099        0.0    0.000    6347.0
# 1|userID[s_189]   0.080  0.030   0.023    0.135        0.0    0.000    5936.0
# 1|userID[s_200]  -0.039  0.031  -0.097    0.020        0.0    0.000    7317.0
# 1|userID[s_204]  -0.087  0.029  -0.143   -0.032        0.0    0.000    6356.0
# 1|userID[s_218]   0.088  0.031   0.030    0.143        0.0    0.000    6874.0
# 1|userID[s_222]  -0.060  0.030  -0.116   -0.004        0.0    0.000    7107.0
# 1|userID[s_225]   0.097  0.031   0.041    0.157        0.0    0.000    5345.0
#
#                   ess_tail  r_hat
# 1|userID[s_1010]    2724.0    1.0
# 1|userID[s_1018]    2657.0    1.0
# 1|userID[s_1024]    2809.0    1.0
# 1|userID[s_1029]    2810.0    1.0
# 1|userID[s_1031]    2990.0    1.0
# 1|userID[s_1035]    3110.0    1.0
# 1|userID[s_1037]    2884.0    1.0
# 1|userID[s_1041]    2907.0    1.0
# 1|userID[s_1054]    2284.0    1.0
# 1|userID[s_1059]    2654.0    1.0
# 1|userID[s_1066]    2801.0    1.0
# 1|userID[s_1075]    2988.0    1.0
# 1|userID[s_1089]    2620.0    1.0
# 1|userID[s_1090]    2960.0    1.0
# 1|userID[s_1094]    2742.0    1.0
# 1|userID[s_1099]    3053.0    1.0
# 1|userID[s_1117]    2517.0    1.0
# 1|userID[s_112]     2787.0    1.0
# 1|userID[s_1121]    2516.0    1.0
# 1|userID[s_1124]    3021.0    1.0
# 1|userID[s_128]     2833.0    1.0
# 1|userID[s_139]     2820.0    1.0
# 1|userID[s_168]     2971.0    1.0
# 1|userID[s_184]     2851.0    1.0
# 1|userID[s_189]     2870.0    1.0
# 1|userID[s_200]     3051.0    1.0
# 1|userID[s_204]     3162.0    1.0
# 1|userID[s_218]     2933.0    1.0
# 1|userID[s_222]     3007.0    1.0
# 1|userID[s_225]     2965.0    1.0
# ...
#
#                                               mean     sd  hdi_3%  hdi_97%  \
# 1|userID[s_880]                             -0.151  0.030  -0.208   -0.096
# 1|userID[s_881]                              0.040  0.031  -0.016    0.100
# 1|userID[s_888]                             -0.081  0.030  -0.137   -0.023
# 1|userID[s_902]                              0.011  0.030  -0.045    0.068
# 1|userID[s_907]                             -0.080  0.029  -0.136   -0.026
# 1|userID[s_908]                              0.029  0.031  -0.027    0.089
# 1|userID[s_916]                              0.088  0.030   0.033    0.143
# 1|userID[s_920]                             -0.072  0.030  -0.130   -0.015
# 1|userID[s_926]                              0.106  0.031   0.045    0.160
# 1|userID[s_928]                              0.047  0.031  -0.009    0.106
# 1|userID[s_933]                             -0.010  0.030  -0.068    0.043
# 1|userID[s_967]                              0.131  0.030   0.074    0.186
# 1|userID[s_973]                             -0.041  0.030  -0.097    0.015
# 1|userID[s_981]                              0.041  0.030  -0.014    0.098
# 1|userID[s_986]                             -0.011  0.030  -0.068    0.043
# 1|userID[s_990]                              0.055  0.031  -0.002    0.111
# 1|userID_sigma                               0.084  0.006   0.073    0.094
# Intercept                                    0.795  0.011   0.774    0.816
# difficulty[2]                               -0.028  0.013  -0.051   -0.003
# difficulty[3]                               -0.098  0.013  -0.121   -0.073
# sigma                                        0.110  0.002   0.106    0.113
# task[Matching]                               0.098  0.013   0.075    0.122
# task[Filled Delay - emotions]               -0.094  0.013  -0.118   -0.070
# task[Filled Delay - math]                   -0.009  0.013  -0.033    0.013
# task:difficulty[Matching, 2]                -0.007  0.018  -0.038    0.029
# task:difficulty[Matching, 3]                 0.003  0.018  -0.029    0.039
# task:difficulty[Filled Delay - emotions, 2]  0.017  0.018  -0.017    0.051
# task:difficulty[Filled Delay - emotions, 3]  0.039  0.018   0.005    0.073
# task:difficulty[Filled Delay - math, 2]      0.002  0.018  -0.033    0.034
# task:difficulty[Filled Delay - math, 3]      0.021  0.018  -0.010    0.056
#
#                                              mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_880]                                    0.0    0.000    6067.0
# 1|userID[s_881]                                    0.0    0.000    5959.0
# 1|userID[s_888]                                    0.0    0.000    6124.0
# 1|userID[s_902]                                    0.0    0.000    5938.0
# 1|userID[s_907]                                    0.0    0.000    5525.0
# 1|userID[s_908]                                    0.0    0.000    7153.0
# 1|userID[s_916]                                    0.0    0.000    6842.0
# 1|userID[s_920]                                    0.0    0.000    6352.0
# 1|userID[s_926]                                    0.0    0.000    5921.0
# 1|userID[s_928]                                    0.0    0.000    6924.0
# 1|userID[s_933]                                    0.0    0.001    6031.0
# 1|userID[s_967]                                    0.0    0.000    6997.0
# 1|userID[s_973]                                    0.0    0.000    6791.0
# 1|userID[s_981]                                    0.0    0.000    6118.0
# 1|userID[s_986]                                    0.0    0.000    7693.0
# 1|userID[s_990]                                    0.0    0.000    6948.0
# 1|userID_sigma                                     0.0    0.000    1028.0
# Intercept                                          0.0    0.000    1285.0
# difficulty[2]                                      0.0    0.000    2147.0
# difficulty[3]                                      0.0    0.000    2209.0
# sigma                                              0.0    0.000    6706.0
# task[Matching]                                     0.0    0.000    2290.0
# task[Filled Delay - emotions]                      0.0    0.000    2322.0
# task[Filled Delay - math]                          0.0    0.000    2144.0
# task:difficulty[Matching, 2]                       0.0    0.000    2402.0
# task:difficulty[Matching, 3]                       0.0    0.000    2669.0
# task:difficulty[Filled Delay - emotions, 2]        0.0    0.000    2445.0
# task:difficulty[Filled Delay - emotions, 3]        0.0    0.000    2688.0
# task:difficulty[Filled Delay - math, 2]            0.0    0.000    2585.0
# task:difficulty[Filled Delay - math, 3]            0.0    0.000    2534.0
#
#                                              ess_tail  r_hat
# 1|userID[s_880]                                2834.0    1.0
# 1|userID[s_881]                                2466.0    1.0
# 1|userID[s_888]                                2834.0    1.0
# 1|userID[s_902]                                2709.0    1.0
# 1|userID[s_907]                                2795.0    1.0
# 1|userID[s_908]                                2522.0    1.0
# 1|userID[s_916]                                2602.0    1.0
# 1|userID[s_920]                                2905.0    1.0
# 1|userID[s_926]                                2488.0    1.0
# 1|userID[s_928]                                2725.0    1.0
# 1|userID[s_933]                                2693.0    1.0
# 1|userID[s_967]                                2813.0    1.0
# 1|userID[s_973]                                2737.0    1.0
# 1|userID[s_981]                                2919.0    1.0
# 1|userID[s_986]                                3138.0    1.0
# 1|userID[s_990]                                3053.0    1.0
# 1|userID_sigma                                 1863.0    1.0
# Intercept                                      1988.0    1.0
# difficulty[2]                                  2749.0    1.0
# difficulty[3]                                  2862.0    1.0
# sigma                                          2896.0    1.0
# task[Matching]                                 2728.0    1.0
# task[Filled Delay - emotions]                  3001.0    1.0
# task[Filled Delay - math]                      2857.0    1.0
# task:difficulty[Matching, 2]                   2807.0    1.0
# task:difficulty[Matching, 3]                   3140.0    1.0
# task:difficulty[Filled Delay - emotions, 2]    2584.0    1.0
# task:difficulty[Filled Delay - emotions, 3]    3014.0    1.0
# task:difficulty[Filled Delay - math, 2]        3151.0    1.0
# task:difficulty[Filled Delay - math, 3]        3052.0    1.0
#
# Fitting formula correct_flt ~ task + difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1010] -0.052  0.030  -0.107    0.004        0.0    0.000    5808.0
# 1|userID[s_1018] -0.041  0.030  -0.099    0.013        0.0    0.000    5761.0
# 1|userID[s_1024]  0.041  0.030  -0.014    0.096        0.0    0.000    5807.0
# 1|userID[s_1029]  0.027  0.030  -0.028    0.085        0.0    0.000    5326.0
# 1|userID[s_1031]  0.012  0.031  -0.047    0.068        0.0    0.001    5920.0
# 1|userID[s_1035]  0.067  0.030   0.011    0.127        0.0    0.000    6030.0
# 1|userID[s_1037] -0.085  0.030  -0.140   -0.026        0.0    0.000    5109.0
# 1|userID[s_1041]  0.032  0.030  -0.028    0.086        0.0    0.000    6780.0
# 1|userID[s_1054]  0.008  0.030  -0.049    0.065        0.0    0.000    5580.0
# 1|userID[s_1059]  0.069  0.030   0.010    0.123        0.0    0.000    5537.0
# 1|userID[s_1066] -0.038  0.030  -0.095    0.019        0.0    0.000    5100.0
# 1|userID[s_1075]  0.064  0.030   0.006    0.118        0.0    0.000    6466.0
# 1|userID[s_1089]  0.113  0.030   0.056    0.170        0.0    0.000    5276.0
# 1|userID[s_1090] -0.058  0.031  -0.116   -0.001        0.0    0.000    5968.0
# 1|userID[s_1094] -0.008  0.030  -0.065    0.048        0.0    0.000    5487.0
# 1|userID[s_1099]  0.067  0.030   0.006    0.120        0.0    0.000    5844.0
# 1|userID[s_1117]  0.034  0.031  -0.022    0.094        0.0    0.000    5561.0
# 1|userID[s_112]  -0.004  0.030  -0.060    0.050        0.0    0.001    5422.0
# 1|userID[s_1121]  0.073  0.030   0.015    0.129        0.0    0.000    5790.0
# 1|userID[s_1124] -0.018  0.030  -0.076    0.037        0.0    0.000    5324.0
# 1|userID[s_128]  -0.091  0.029  -0.149   -0.040        0.0    0.000    5307.0
# 1|userID[s_139]  -0.128  0.030  -0.184   -0.073        0.0    0.000    5442.0
# 1|userID[s_168]   0.145  0.031   0.086    0.202        0.0    0.000    5492.0
# 1|userID[s_184]  -0.157  0.030  -0.212   -0.099        0.0    0.000    4880.0
# 1|userID[s_189]   0.079  0.031   0.022    0.136        0.0    0.000    6186.0
# 1|userID[s_200]  -0.039  0.031  -0.096    0.020        0.0    0.000    5033.0
# 1|userID[s_204]  -0.088  0.031  -0.144   -0.026        0.0    0.000    5587.0
# 1|userID[s_218]   0.088  0.031   0.032    0.148        0.0    0.000    5918.0
# 1|userID[s_222]  -0.061  0.030  -0.116   -0.006        0.0    0.000    4824.0
# 1|userID[s_225]   0.097  0.030   0.042    0.153        0.0    0.000    5871.0
#
#                   ess_tail  r_hat
# 1|userID[s_1010]    2649.0    1.0
# 1|userID[s_1018]    2624.0    1.0
# 1|userID[s_1024]    2756.0    1.0
# 1|userID[s_1029]    2945.0    1.0
# 1|userID[s_1031]    2663.0    1.0
# 1|userID[s_1035]    2708.0    1.0
# 1|userID[s_1037]    2623.0    1.0
# 1|userID[s_1041]    2961.0    1.0
# 1|userID[s_1054]    3136.0    1.0
# 1|userID[s_1059]    2882.0    1.0
# 1|userID[s_1066]    2759.0    1.0
# 1|userID[s_1075]    2771.0    1.0
# 1|userID[s_1089]    2692.0    1.0
# 1|userID[s_1090]    2754.0    1.0
# 1|userID[s_1094]    2931.0    1.0
# 1|userID[s_1099]    2911.0    1.0
# 1|userID[s_1117]    2566.0    1.0
# 1|userID[s_112]     2678.0    1.0
# 1|userID[s_1121]    2945.0    1.0
# 1|userID[s_1124]    2941.0    1.0
# 1|userID[s_128]     2835.0    1.0
# 1|userID[s_139]     2558.0    1.0
# 1|userID[s_168]     3018.0    1.0
# 1|userID[s_184]     2739.0    1.0
# 1|userID[s_189]     2962.0    1.0
# 1|userID[s_200]     2634.0    1.0
# 1|userID[s_204]     2803.0    1.0
# 1|userID[s_218]     2821.0    1.0
# 1|userID[s_222]     2705.0    1.0
# 1|userID[s_225]     2808.0    1.0
# ...
#
#                                 mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# 1|userID[s_841]                0.149  0.030   0.093    0.204        0.0
# 1|userID[s_850]                0.062  0.030   0.005    0.119        0.0
# 1|userID[s_856]               -0.016  0.030  -0.074    0.038        0.0
# 1|userID[s_857]               -0.018  0.031  -0.076    0.038        0.0
# 1|userID[s_866]               -0.016  0.030  -0.072    0.042        0.0
# 1|userID[s_88]                 0.048  0.030  -0.009    0.105        0.0
# 1|userID[s_880]               -0.151  0.030  -0.205   -0.093        0.0
# 1|userID[s_881]                0.040  0.031  -0.019    0.098        0.0
# 1|userID[s_888]               -0.081  0.030  -0.137   -0.028        0.0
# 1|userID[s_902]                0.012  0.029  -0.045    0.066        0.0
# 1|userID[s_907]               -0.080  0.030  -0.134   -0.021        0.0
# 1|userID[s_908]                0.029  0.031  -0.031    0.084        0.0
# 1|userID[s_916]                0.087  0.030   0.031    0.145        0.0
# 1|userID[s_920]               -0.072  0.031  -0.132   -0.016        0.0
# 1|userID[s_926]                0.106  0.029   0.052    0.163        0.0
# 1|userID[s_928]                0.047  0.030  -0.005    0.106        0.0
# 1|userID[s_933]               -0.010  0.030  -0.068    0.044        0.0
# 1|userID[s_967]                0.131  0.031   0.073    0.189        0.0
# 1|userID[s_973]               -0.041  0.031  -0.102    0.015        0.0
# 1|userID[s_981]                0.041  0.029  -0.013    0.096        0.0
# 1|userID[s_986]               -0.011  0.029  -0.066    0.044        0.0
# 1|userID[s_990]                0.055  0.030  -0.000    0.111        0.0
# 1|userID_sigma                 0.084  0.006   0.074    0.095        0.0
# Intercept                      0.789  0.009   0.772    0.806        0.0
# difficulty[2]                 -0.025  0.006  -0.036   -0.012        0.0
# difficulty[3]                 -0.082  0.006  -0.094   -0.071        0.0
# sigma                          0.110  0.002   0.106    0.113        0.0
# task[Matching]                 0.097  0.007   0.083    0.110        0.0
# task[Filled Delay - emotions] -0.075  0.007  -0.089   -0.061        0.0
# task[Filled Delay - math]     -0.002  0.007  -0.015    0.013        0.0
#
#                                mcse_sd  ess_bulk  ess_tail  r_hat
# 1|userID[s_841]                    0.0    5506.0    2649.0    1.0
# 1|userID[s_850]                    0.0    5353.0    2814.0    1.0
# 1|userID[s_856]                    0.0    5132.0    2694.0    1.0
# 1|userID[s_857]                    0.0    5781.0    3063.0    1.0
# 1|userID[s_866]                    0.0    5666.0    2871.0    1.0
# 1|userID[s_88]                     0.0    6215.0    2615.0    1.0
# 1|userID[s_880]                    0.0    5970.0    2755.0    1.0
# 1|userID[s_881]                    0.0    5273.0    2621.0    1.0
# 1|userID[s_888]                    0.0    5314.0    3034.0    1.0
# 1|userID[s_902]                    0.0    5667.0    2885.0    1.0
# 1|userID[s_907]                    0.0    5767.0    2915.0    1.0
# 1|userID[s_908]                    0.0    6458.0    2571.0    1.0
# 1|userID[s_916]                    0.0    5779.0    2513.0    1.0
# 1|userID[s_920]                    0.0    5047.0    2929.0    1.0
# 1|userID[s_926]                    0.0    4996.0    2809.0    1.0
# 1|userID[s_928]                    0.0    5415.0    2557.0    1.0
# 1|userID[s_933]                    0.0    5186.0    2767.0    1.0
# 1|userID[s_967]                    0.0    6080.0    2388.0    1.0
# 1|userID[s_973]                    0.0    5921.0    2641.0    1.0
# 1|userID[s_981]                    0.0    5422.0    2901.0    1.0
# 1|userID[s_986]                    0.0    6073.0    3006.0    1.0
# 1|userID[s_990]                    0.0    6154.0    2840.0    1.0
# 1|userID_sigma                     0.0    1310.0    1710.0    1.0
# Intercept                          0.0    1812.0    2374.0    1.0
# difficulty[2]                      0.0    5457.0    2672.0    1.0
# difficulty[3]                      0.0    4886.0    2856.0    1.0
# sigma                              0.0    5804.0    2506.0    1.0
# task[Matching]                     0.0    5171.0    3485.0    1.0
# task[Filled Delay - emotions]      0.0    5593.0    3423.0    1.0
# task[Filled Delay - math]          0.0    4854.0    3225.0    1.0

# %% [markdown]
# ### Compare all data
# [top](#top)

# %%
df_compare_formulas_bernoulli = {}
for f in result_dic_bernoulli.keys():
    print(f, '\n')
    df_compare_formulas_bernoulli[f] = az.compare(result_dic_bernoulli[f])
    
    print(df_compare_formulas_bernoulli[f])
    
    az.plot_compare(df_compare_formulas_bernoulli[f], insample_dev=False);

    
    print()
# df_compare_formulas_bernoulli[f]
# Out:
# dataset_4
#
#                                               rank     elpd_loo       p_loo  \
# correct_flt ~ task + difficulty + (1|userID)     0  1355.197884  132.580711
# correct_flt ~ task * difficulty + (1|userID)     1  1351.550631  138.653361
#
#                                               elpd_diff        weight  \
# correct_flt ~ task + difficulty + (1|userID)   0.000000  1.000000e+00
# correct_flt ~ task * difficulty + (1|userID)   3.647252  1.110223e-14
#
#                                                      se       dse  warning  \
# correct_flt ~ task + difficulty + (1|userID)  30.604177  0.000000    False
# correct_flt ~ task * difficulty + (1|userID)  30.852211  2.683291    False
#
#                                              scale
# correct_flt ~ task + difficulty + (1|userID)   log
# correct_flt ~ task * difficulty + (1|userID)   log

# %%
fig, ax = plt.subplots(figsize=(8, 4))
az.plot_forest(
    result_dic_bernoulli['dataset_4']['correct_flt ~ task * difficulty + (1|userID)'],
#     model_names=['Dataset 4'],
    var_names=["Intercept", "difficulty", "task"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
az.plot_forest(
    list(result_dic_bernoulli['dataset_4'].values()),
    model_names=[f'{f}\n{formula}' for f in result_dic_bernoulli.keys() for formula in formulas2run],
    var_names=["Intercept", "difficulty", "task"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
az.plot_forest(
    (list(result_dic_bernoulli['dataset_4'].values())
    )[::2],
#     model_names=[f'{f}' for f in result_dic_bernoulli.keys()],
    var_names=["task:difficulty"],
    combined=True,
#     figsize=(12, 10)
    ax=ax
);

ax.axvline(0, c='k')

# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
# # plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
# plt.show()


# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.6, 1))
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %% [markdown]
# ### Run some predictions
# [top](#top)

# %%
# interactions = ['face matching, 2', 'face matching, 3', 'math, 2', 'math, 3', 'interference, 2', 'interference, 3']
interactions = ['Matching, 2', 'Matching, 3', 'Filled Delay - math, 2', 'Filled Delay - math, 3', 'Filled Delay - emotions, 2', 'Filled Delay - emotions, 3']
fm2, fm3, m2, m3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ task * difficulty + (1|userID)'].posterior["task:difficulty"].sel({"task:difficulty_dim":tsk}) for tsk in interactions]

# %%
_, ax = plt.subplots()
for idx, x in enumerate([fm2, fm3, m2, m3, i2, i3]):
    az.plot_dist(x, label=x["task:difficulty_dim"].item(), plot_kwargs={"color": f"C{idx}"}, ax=ax)
ax.legend(loc="upper left");

# %%
# Probability that the FM slope is less than 0

print(f"""
Probability that the M slope is less than 0:
level 2: {(fm2 < 0).mean().item()}
level 3: {(fm3 < 0).mean().item()}
""")
# Out:
# Probability that the M slope is less than 0:
# level 2: 0.666
# level 3: 0.43525

# %% [markdown]
# ---

# %%
for f in result_dic_bernoulli.keys():

    fm2, fm3, m2, m3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ task * difficulty + (1|userID)'].posterior["task:difficulty"].sel({"task:difficulty_dim":tsk}) for tsk in interactions]
    print(f"""
Experiment {f}:
  Probability that the M slope is less than 0:
    level 2: {(fm2 < 0).mean().item()}
    level 3: {(fm3 < 0).mean().item()}
    
  Probability that the FD-m (Math) slope is less than 0:
    level 2: {(m2 < 0).mean().item()}
    level 3: {(m3 < 0).mean().item()}
    
  Probability that the FD-e slope is less than 0:
    level 2: {(i2 < 0).mean().item()}
    level 3: {(i3 < 0).mean().item()}
    
    """)
# Out:
# Experiment dataset_4:
#   Probability that the M slope is less than 0:
#     level 2: 0.666
#     level 3: 0.43525
#
#   Probability that the FD-m (Math) slope is less than 0:
#     level 2: 0.455
#     level 3: 0.1205
#
#   Probability that the FD-e slope is less than 0:
#     level 2: 0.17475
#     level 3: 0.0125

# %% [markdown]
# ### Save the inference
# [top](#top)
#
# It could be possible to use this:
# ```
# result_dic_bernoulli['randomised_postpilot_with_math']['correct_flt ~ task * difficulty + (1|userID)'].to_netcdf()
# ```
#
# but it doesn't preserve the dictionary, so I use pickle.

# %%
# save the dictionary to a pickle file
with open(opj(path_inference_data,'FMP_math_inference_data_dict.pkl'), 'wb') as f:
    pickle.dump(result_dic_bernoulli['dataset_4'], f)

# %%
# # Load the dictionary from the pickle file
# with open(opj(path_inference_data,'FMP_math_inference_data_dict.pkl'), 'rb') as f:
#     loaded_inference_data_dict = pickle.load(f)

# %%
# %load_ext watermark

# %watermark -a 'Jan Kadlec' -nmvu -iv -iv -w -p pytensor
# Out:
# Author: Jan Kadlec
#
# Last updated: Fri May 16 2025
#
# Python implementation: CPython
# Python version       : 3.12.5
# IPython version      : 8.25.0
#
# pytensor: 2.23.0
#
# Compiler    : GCC 12.4.0
# OS          : Linux
# Release     : 5.14.0-427.42.1.el9_4.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 96
# Architecture: 64bit
#
# arviz     : 0.19.0
# bambi     : 0.14.0
# pandas    : 2.2.2
# matplotlib: 3.9.2
# numpy     : 1.26.4
# sys       : 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:36:51) [GCC 12.4.0]
#
# Watermark: 2.4.3

# %% [markdown]
# [top](#top)
