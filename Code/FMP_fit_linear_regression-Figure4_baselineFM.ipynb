# %% [markdown]
# ##### top

# %% [markdown]
# # FMP modelling for Figure 4 (Math)
#
# This notebook runs Bayesian models on Datasets 4 (dataset with Math condition) that is described in the article to assess interaction between perception and memory difficulty levels in the FMP. We fit the following formulas to mean score within the condition. Throughout the notebook, I use `task` as a term for memory difficulty levels (M, UD, FD-e, FD-m), `difficulty` as a term for perceptual difficulty levels (1, 2, 3), and `userID` as a variable denoting individual participants. It is the exact same principle and code as the `FMP_fit_linear_regression-Figure4.ipynb` but it sets the FM as a reference level instead of UD.
#
#
# * Model task and difficulty interaction with user as a random effect. Equation:
#     * _correct_flt ~ task * difficulty + (1|userID)_
# * Model task and difficulty as main effects without interaction with user as a random effect. Equation:
#     * _correct_flt ~ task + difficulty + (1|userID)_
#
#
#
# We model mean accuracy per participant per condition.
#
#
# * [Models](#Models)
# * [Plot results](#Plot-results)
# * [Compare all data](#Compare-all-data)
# * [Save the inference](#Save-the-inference)

# %%
import os, sys
import pickle
from os.path import join as opj
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

az.style.use("arviz-darkgrid")
SEED = 7355608


# Importing module for functions
functions_modul =  "./functions"
sys.path.insert(0, functions_modul)

# import all processing and plotting functions
from bayesian_modelling_functions import fit_model, print_model

path_general = "../"
path_data = opj(path_general, "Data", "datasets")
path_inference_data = opj(path_general, "Data", "model_inference_data")


# set the numer of CPU
num_cpu = min(4, os.cpu_count()-1)
print(f'We will have {num_cpu} cores.\n')

path_dic = {
#     'dataset_1' : opj(path_data, 'FMP_dataset_1.csv'),
#     'dataset_2': opj(path_data, 'FMP_dataset_2.csv'),
#     'dataset_3': opj(path_data, 'FMP_dataset_3.csv'),
#     'concat_datasets_123': opj(path_data, 'FMP_concat_datasets_123.csv'),
    'dataset_4': opj(path_data, 'FMP_dataset_4.csv'),
}


# load all dataframes
df_dic = {}

# only selected cols
select_cols = ['stim1', 'stim2', 'target', 'RT', 'userID', 'difficulty', 'levels', 'task', 'correct_flt', 'order']


for f in path_dic.keys():   
    if f=="first_pilot":
        df_dic[f] = pd.read_csv(path_dic[f], usecols=(set(['correct_check'])|set(select_cols))-set(['correct_flt']))
        # convert boolean answers to floats to be able to do mean
        df_dic[f]['correct_flt'] = df_dic[f].correct_check.astype(float)
    elif 'longitudinal_' in f:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols+['target_loc', 'target_loc_simple'])
    else:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols)
    
    df_dic[f]["Experiment"] = f
        

    # clean
    df_dic[f].reset_index(drop=True, inplace=True)
    
    if 'Unnamed: 0' in df_dic[f].columns:
        df_dic[f].drop('Unnamed: 0', inplace=True, axis=1)
        
    
    # find low performing participants
    tt = df_dic[f].loc[df_dic[f]['task'].isin(['face matching', 'perc', 'perception'])].groupby(['userID', 'difficulty']).correct_flt.mean()

    drop_ptc = tt[tt<=0.5].reset_index().userID.values
    print(f'\nIn {f} dropping {len(drop_ptc)} participants for low accuracy in FM.')
    print(tt[tt<=0.5])

    # and remove them
    df_dic[f] = df_dic[f].loc[~df_dic[f]['userID'].isin(drop_ptc)]
    # clean up
    drop_ptc, tt = None, None
    
    print(f"\nThere is now N={df_dic[f]['userID'].unique().size} participants in {f}.")



#####
# rename the levels
rename_tasks_dic = {'perception':'Matching', 'perc':'Matching', 'blank':'Unfilled Delay', 'faces':'Filled Delay - emotions', 'math':'Filled Delay - math'}

# define orders
hue_order = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions']
hue_order_math = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - math']



# rename the memory task labels in the df
for f in df_dic.keys():
    if f=='noise':
        continue
    df_dic[f]['task'] = df_dic[f]['task'].map(rename_tasks_dic).fillna(df_dic[f]['task'])
# Out:
# We will have 4 cores.
#
#
# In dataset_4 dropping 0 participants for low accuracy in FM.
# Series([], Name: correct_flt, dtype: float64)
#
# There is now N=150 participants in dataset_4.

# %%
# select only specific datasets and prepare them
datasets2fit = ['dataset_4']

df_dic_fit = {}


for f in datasets2fit:
    data=None
    
    # groupby and make means for ptc and condition
    data = df_dic[f].groupby(['userID', 'task', 'difficulty'], observed=False).correct_flt.mean().reset_index()

    # convert all variables to categories
    # categorical_cols = data.columns[data.dtypes == object].tolist() + ['difficulty']
    categorical_cols = ['userID', 'task', 'difficulty']
    for col in categorical_cols:
        if col == 'task':
            # specify the order that we want
            data[col] = pd.Categorical(data[col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
            #['Unfilled Delay', 'Matching', 'Filled Delay - emotions']
            
            # also do it for the original datasets
            df_dic[f][col] = pd.Categorical(df_dic[f][col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
        else:
            data[col] = data[col].astype("category")
            df_dic[f][col] = df_dic[f][col].astype("category")

    # check
    print('\n',f)
    df_dic[f].info()
        
    # save
    df_dic_fit[f] = data.copy()

# # drop them for now
# data[data.correct_flt.isna()]
# Out:
#  dataset_4
# <class 'pandas.core.frame.DataFrame'>
# Index: 36000 entries, 0 to 35999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userID       36000 non-null  category
#  1   target       36000 non-null  object
#  2   stim1        36000 non-null  object
#  3   stim2        36000 non-null  object
#  4   correct_flt  35298 non-null  float64
#  5   RT           35298 non-null  float64
#  6   task         36000 non-null  category
#  7   order        36000 non-null  int64
#  8   difficulty   36000 non-null  category
#  9   levels       36000 non-null  int64
#  10  Experiment   36000 non-null  object
# dtypes: category(3), float64(2), int64(2), object(4)
# memory usage: 2.6+ MB

# %% [markdown]
# ## Models
# [top](#top)

# %%
model_assumptions = {
    "correct_flt ~ task * difficulty + (1|userID)": "Each user has their own baseline performance, but the effect of task and difficulty is assumed to be the same across all users.",
    "correct_flt ~ task + difficulty + (1|userID)": "Assumes that each user has their own baseline performance, but the effects of task and difficulty are consistent across all users without any interaction between task and difficulty.",
}

# define what we want to run
base_lvl = ['Matching', 'Unfilled Delay', 'Filled Delay - math', 'Filled Delay - emotions']
formulas2run = [
    "correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)",
    "correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)",
]

# %%
# define where we will store the results
model_dic_bernoulli = {}
result_dic_bernoulli = {}

for f in df_dic_fit.keys():
    print(f'\nFitting dataset {f}\n')
    # create datasets
    if f not in model_dic_bernoulli.keys():
        model_dic_bernoulli[f] = {}
    if f not in result_dic_bernoulli.keys():
        result_dic_bernoulli[f] = {}
    
    for formula in formulas2run:
        print(f'\nFitting formula {formula}\n')
    
        model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula] = fit_model(formula, df_dic_fit[f], categorical_cols, base_lvl=base_lvl,
                                                                                      num_cpu=num_cpu, check_priors=False, sample_priors=False)
# Out:
# Sampling 4 chains, 0 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:19
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 19 seconds.

# %%
model_dic_bernoulli[f][formulas2run[0]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.7247)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#             C(task, levels=base_lvl):difficulty ~ Normal(mu: [0. 0. 0. 0. 0. 0.], sigma: [1.3926 1.3926
#                 1.3926 1.3926 1.3926 1.3926])
#
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.7247))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
model_dic_bernoulli[f][formulas2run[1]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.6667)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.6667))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# ### check priors

# %%
model_dic_bernoulli[f][formulas2run[0]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), C(task, levels=base_lvl):difficulty, Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - math'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - math, 2'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - math, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
model_dic_bernoulli[f][formulas2run[1]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - math'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>]], dtype=object)

# %% [markdown]
# ### check posterior

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[0]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - math'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[1]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - math'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %% [markdown]
# ---
# ## Plot results

# %% [markdown]
# ## FMP dataset 4 -- with Math condition
# [top](#top)

# %%
f = 'dataset_4'
# print(f'Dataset: {f}')
# print_model(model_dic_bernoulli[f], result_dic_bernoulli[f])

print(f'Dataset: {f}')
for formula in formulas2run:
    print(f'\nFitting formula {formula}\n')
    print_model(model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula])
# Out:
# Dataset: dataset_4
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_100]  -0.161  0.030  -0.218   -0.106        0.0    0.000    6459.0
# 1|userID[s_1011] -0.011  0.030  -0.070    0.043        0.0    0.001    5916.0
# 1|userID[s_1015] -0.115  0.030  -0.171   -0.058        0.0    0.000    5472.0
# 1|userID[s_1016] -0.027  0.030  -0.081    0.030        0.0    0.000    5686.0
# 1|userID[s_1022] -0.080  0.030  -0.134   -0.021        0.0    0.000    6314.0
# 1|userID[s_1024]  0.035  0.031  -0.026    0.090        0.0    0.000    6749.0
# 1|userID[s_1032] -0.010  0.031  -0.067    0.048        0.0    0.000    5963.0
# 1|userID[s_107]   0.047  0.030  -0.011    0.104        0.0    0.000    7074.0
# 1|userID[s_108]   0.014  0.031  -0.046    0.069        0.0    0.001    6455.0
# 1|userID[s_1080] -0.124  0.030  -0.182   -0.068        0.0    0.000    5952.0
# 1|userID[s_1089]  0.068  0.030   0.012    0.125        0.0    0.000    6599.0
# 1|userID[s_1094] -0.049  0.030  -0.103    0.008        0.0    0.000    5823.0
# 1|userID[s_1103]  0.128  0.031   0.070    0.184        0.0    0.000    5731.0
# 1|userID[s_1110]  0.105  0.030   0.051    0.164        0.0    0.000    6470.0
# 1|userID[s_1112] -0.016  0.030  -0.070    0.042        0.0    0.000    6110.0
# 1|userID[s_1116]  0.025  0.030  -0.031    0.081        0.0    0.000    6293.0
# 1|userID[s_1126] -0.011  0.030  -0.066    0.045        0.0    0.001    6569.0
# 1|userID[s_1128] -0.045  0.030  -0.102    0.009        0.0    0.000    6224.0
# 1|userID[s_133]   0.028  0.031  -0.027    0.088        0.0    0.000    5924.0
# 1|userID[s_135]   0.072  0.030   0.017    0.130        0.0    0.000    5913.0
# 1|userID[s_157]  -0.059  0.029  -0.111   -0.004        0.0    0.000    5285.0
# 1|userID[s_160]  -0.090  0.030  -0.148   -0.036        0.0    0.000    6866.0
# 1|userID[s_166]  -0.041  0.029  -0.099    0.012        0.0    0.000    6027.0
# 1|userID[s_168]  -0.069  0.030  -0.128   -0.014        0.0    0.000    6135.0
# 1|userID[s_189]  -0.038  0.030  -0.096    0.018        0.0    0.000    5988.0
# 1|userID[s_190]  -0.147  0.030  -0.204   -0.092        0.0    0.000    5637.0
# 1|userID[s_205]   0.016  0.029  -0.040    0.071        0.0    0.000    6588.0
# 1|userID[s_23]   -0.007  0.030  -0.069    0.047        0.0    0.001    8196.0
# 1|userID[s_263]   0.036  0.030  -0.018    0.096        0.0    0.000    5765.0
# 1|userID[s_265]   0.002  0.030  -0.054    0.059        0.0    0.001    6551.0
#
#                   ess_tail  r_hat
# 1|userID[s_100]     2819.0   1.00
# 1|userID[s_1011]    2708.0   1.00
# 1|userID[s_1015]    2887.0   1.00
# 1|userID[s_1016]    3200.0   1.00
# 1|userID[s_1022]    2950.0   1.00
# 1|userID[s_1024]    2271.0   1.00
# 1|userID[s_1032]    2889.0   1.00
# 1|userID[s_107]     2591.0   1.00
# 1|userID[s_108]     2763.0   1.00
# 1|userID[s_1080]    2740.0   1.00
# 1|userID[s_1089]    2599.0   1.00
# 1|userID[s_1094]    2630.0   1.00
# 1|userID[s_1103]    2662.0   1.00
# 1|userID[s_1110]    3067.0   1.00
# 1|userID[s_1112]    2486.0   1.00
# 1|userID[s_1116]    2597.0   1.00
# 1|userID[s_1126]    2743.0   1.00
# 1|userID[s_1128]    2976.0   1.00
# 1|userID[s_133]     2669.0   1.00
# 1|userID[s_135]     2783.0   1.00
# 1|userID[s_157]     2726.0   1.00
# 1|userID[s_160]     3044.0   1.00
# 1|userID[s_166]     2686.0   1.00
# 1|userID[s_168]     2677.0   1.01
# 1|userID[s_189]     2399.0   1.00
# 1|userID[s_190]     2814.0   1.01
# 1|userID[s_205]     3109.0   1.00
# 1|userID[s_23]      3050.0   1.00
# 1|userID[s_263]     2684.0   1.00
# 1|userID[s_265]     2761.0   1.00
# ...
#
#                                                      mean     sd  hdi_3%  \
# 1|userID[s_882]                                     0.079  0.031   0.022
# 1|userID[s_923]                                    -0.081  0.030  -0.136
# 1|userID[s_93]                                      0.084  0.030   0.027
# 1|userID[s_931]                                    -0.004  0.030  -0.059
# 1|userID[s_936]                                     0.082  0.030   0.023
# 1|userID[s_937]                                     0.112  0.030   0.053
# 1|userID[s_939]                                    -0.111  0.030  -0.164
# 1|userID[s_940]                                     0.012  0.031  -0.044
# 1|userID[s_945]                                     0.067  0.030   0.011
# 1|userID[s_958]                                    -0.120  0.031  -0.175
# 1|userID[s_960]                                    -0.083  0.031  -0.137
# 1|userID[s_966]                                    -0.060  0.030  -0.113
# 1|userID[s_975]                                     0.039  0.031  -0.017
# 1|userID[s_976]                                     0.113  0.031   0.052
# 1|userID[s_993]                                     0.012  0.029  -0.040
# 1|userID[s_996]                                     0.041  0.031  -0.015
# 1|userID_sigma                                      0.084  0.006   0.073
# C(task, levels=base_lvl)[Unfilled Delay]           -0.098  0.013  -0.121
# C(task, levels=base_lvl)[Filled Delay - math]      -0.107  0.013  -0.130
# C(task, levels=base_lvl)[Filled Delay - emotions]  -0.192  0.013  -0.216
# C(task, levels=base_lvl):difficulty[Unfilled De...  0.008  0.018  -0.027
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.003  0.018  -0.037
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.010  0.018  -0.027
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.018  0.018  -0.017
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.024  0.018  -0.008
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.036  0.018   0.003
# Intercept                                           0.893  0.012   0.872
# difficulty[2]                                      -0.036  0.012  -0.058
# difficulty[3]                                      -0.095  0.012  -0.119
# sigma                                               0.110  0.002   0.106
#
#                                                     hdi_97%  mcse_mean  \
# 1|userID[s_882]                                       0.136        0.0
# 1|userID[s_923]                                      -0.027        0.0
# 1|userID[s_93]                                        0.141        0.0
# 1|userID[s_931]                                       0.053        0.0
# 1|userID[s_936]                                       0.137        0.0
# 1|userID[s_937]                                       0.166        0.0
# 1|userID[s_939]                                      -0.055        0.0
# 1|userID[s_940]                                       0.072        0.0
# 1|userID[s_945]                                       0.122        0.0
# 1|userID[s_958]                                      -0.062        0.0
# 1|userID[s_960]                                      -0.022        0.0
# 1|userID[s_966]                                       0.001        0.0
# 1|userID[s_975]                                       0.098        0.0
# 1|userID[s_976]                                       0.170        0.0
# 1|userID[s_993]                                       0.069        0.0
# 1|userID[s_996]                                       0.101        0.0
# 1|userID_sigma                                        0.094        0.0
# C(task, levels=base_lvl)[Unfilled Delay]             -0.074        0.0
# C(task, levels=base_lvl)[Filled Delay - math]        -0.083        0.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    -0.168        0.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.039        0.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.029        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.041        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.051        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.057        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.070        0.0
# Intercept                                             0.915        0.0
# difficulty[2]                                        -0.012        0.0
# difficulty[3]                                        -0.072        0.0
# sigma                                                 0.113        0.0
#
#                                                     mcse_sd  ess_bulk  \
# 1|userID[s_882]                                       0.000    6832.0
# 1|userID[s_923]                                       0.000    6483.0
# 1|userID[s_93]                                        0.000    6618.0
# 1|userID[s_931]                                       0.001    6556.0
# 1|userID[s_936]                                       0.000    6264.0
# 1|userID[s_937]                                       0.000    6363.0
# 1|userID[s_939]                                       0.000    6512.0
# 1|userID[s_940]                                       0.001    6294.0
# 1|userID[s_945]                                       0.000    5448.0
# 1|userID[s_958]                                       0.000    6378.0
# 1|userID[s_960]                                       0.000    5785.0
# 1|userID[s_966]                                       0.000    7185.0
# 1|userID[s_975]                                       0.000    6079.0
# 1|userID[s_976]                                       0.000    7395.0
# 1|userID[s_993]                                       0.001    6764.0
# 1|userID[s_996]                                       0.000    7855.0
# 1|userID_sigma                                        0.000    1324.0
# C(task, levels=base_lvl)[Unfilled Delay]              0.000    2132.0
# C(task, levels=base_lvl)[Filled Delay - math]         0.000    2128.0
# C(task, levels=base_lvl)[Filled Delay - emotions]     0.000    2122.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.000    2291.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.000    2292.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2043.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2057.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2133.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2223.0
# Intercept                                             0.000    1252.0
# difficulty[2]                                         0.000    1610.0
# difficulty[3]                                         0.000    1678.0
# sigma                                                 0.000    5924.0
#
#                                                     ess_tail  r_hat
# 1|userID[s_882]                                       2786.0    1.0
# 1|userID[s_923]                                       2992.0    1.0
# 1|userID[s_93]                                        2668.0    1.0
# 1|userID[s_931]                                       2552.0    1.0
# 1|userID[s_936]                                       2882.0    1.0
# 1|userID[s_937]                                       2840.0    1.0
# 1|userID[s_939]                                       2874.0    1.0
# 1|userID[s_940]                                       2577.0    1.0
# 1|userID[s_945]                                       2476.0    1.0
# 1|userID[s_958]                                       3098.0    1.0
# 1|userID[s_960]                                       2662.0    1.0
# 1|userID[s_966]                                       2445.0    1.0
# 1|userID[s_975]                                       2839.0    1.0
# 1|userID[s_976]                                       3130.0    1.0
# 1|userID[s_993]                                       2495.0    1.0
# 1|userID[s_996]                                       2757.0    1.0
# 1|userID_sigma                                        2248.0    1.0
# C(task, levels=base_lvl)[Unfilled Delay]              2598.0    1.0
# C(task, levels=base_lvl)[Filled Delay - math]         2663.0    1.0
# C(task, levels=base_lvl)[Filled Delay - emotions]     2565.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    2978.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    2951.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2867.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2298.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2694.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2836.0    1.0
# Intercept                                             1903.0    1.0
# difficulty[2]                                         2344.0    1.0
# difficulty[3]                                         2663.0    1.0
# sigma                                                 2710.0    1.0
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_100]  -0.161  0.031  -0.220   -0.104        0.0    0.000    6567.0
# 1|userID[s_1011] -0.012  0.030  -0.068    0.045        0.0    0.000    6784.0
# 1|userID[s_1015] -0.116  0.031  -0.173   -0.057        0.0    0.000    6247.0
# 1|userID[s_1016] -0.027  0.030  -0.084    0.028        0.0    0.000    7665.0
# 1|userID[s_1022] -0.081  0.031  -0.141   -0.025        0.0    0.000    7404.0
# 1|userID[s_1024]  0.034  0.029  -0.019    0.091        0.0    0.000    6329.0
# 1|userID[s_1032] -0.010  0.031  -0.065    0.050        0.0    0.001    6159.0
# 1|userID[s_107]   0.047  0.030  -0.011    0.101        0.0    0.000    6943.0
# 1|userID[s_108]   0.013  0.030  -0.040    0.069        0.0    0.000    7101.0
# 1|userID[s_1080] -0.123  0.031  -0.179   -0.064        0.0    0.000    6120.0
# 1|userID[s_1089]  0.069  0.031   0.014    0.129        0.0    0.000    6704.0
# 1|userID[s_1094] -0.049  0.031  -0.107    0.009        0.0    0.000    7498.0
# 1|userID[s_1103]  0.127  0.030   0.070    0.182        0.0    0.000    6483.0
# 1|userID[s_1110]  0.105  0.031   0.044    0.161        0.0    0.000    6110.0
# 1|userID[s_1112] -0.016  0.029  -0.073    0.038        0.0    0.000    6730.0
# 1|userID[s_1116]  0.026  0.030  -0.035    0.079        0.0    0.000    6732.0
# 1|userID[s_1126] -0.012  0.030  -0.069    0.043        0.0    0.000    6927.0
# 1|userID[s_1128] -0.046  0.030  -0.102    0.010        0.0    0.000    7284.0
# 1|userID[s_133]   0.027  0.030  -0.031    0.086        0.0    0.000    6412.0
# 1|userID[s_135]   0.072  0.031   0.013    0.128        0.0    0.000    5994.0
# 1|userID[s_157]  -0.059  0.031  -0.117   -0.002        0.0    0.000    6337.0
# 1|userID[s_160]  -0.091  0.030  -0.149   -0.037        0.0    0.000    6386.0
# 1|userID[s_166]  -0.041  0.030  -0.095    0.016        0.0    0.000    7445.0
# 1|userID[s_168]  -0.070  0.030  -0.126   -0.014        0.0    0.000    6649.0
# 1|userID[s_189]  -0.038  0.030  -0.095    0.018        0.0    0.000    5927.0
# 1|userID[s_190]  -0.148  0.030  -0.201   -0.087        0.0    0.000    5921.0
# 1|userID[s_205]   0.016  0.030  -0.039    0.076        0.0    0.000    6996.0
# 1|userID[s_23]   -0.008  0.031  -0.068    0.047        0.0    0.001    6686.0
# 1|userID[s_263]   0.037  0.030  -0.021    0.092        0.0    0.000    6314.0
# 1|userID[s_265]   0.001  0.030  -0.055    0.056        0.0    0.001    6701.0
#
#                   ess_tail  r_hat
# 1|userID[s_100]     3150.0    1.0
# 1|userID[s_1011]    3021.0    1.0
# 1|userID[s_1015]    2530.0    1.0
# 1|userID[s_1016]    2651.0    1.0
# 1|userID[s_1022]    3205.0    1.0
# 1|userID[s_1024]    3151.0    1.0
# 1|userID[s_1032]    2592.0    1.0
# 1|userID[s_107]     2791.0    1.0
# 1|userID[s_108]     2953.0    1.0
# 1|userID[s_1080]    2913.0    1.0
# 1|userID[s_1089]    2609.0    1.0
# 1|userID[s_1094]    2958.0    1.0
# 1|userID[s_1103]    2961.0    1.0
# 1|userID[s_1110]    2832.0    1.0
# 1|userID[s_1112]    2635.0    1.0
# 1|userID[s_1116]    2596.0    1.0
# 1|userID[s_1126]    2907.0    1.0
# 1|userID[s_1128]    2895.0    1.0
# 1|userID[s_133]     2621.0    1.0
# 1|userID[s_135]     2612.0    1.0
# 1|userID[s_157]     2393.0    1.0
# 1|userID[s_160]     2847.0    1.0
# 1|userID[s_166]     2952.0    1.0
# 1|userID[s_168]     2861.0    1.0
# 1|userID[s_189]     2804.0    1.0
# 1|userID[s_190]     2625.0    1.0
# 1|userID[s_205]     2975.0    1.0
# 1|userID[s_23]      2842.0    1.0
# 1|userID[s_263]     2996.0    1.0
# 1|userID[s_265]     2378.0    1.0
# ...
#
#                                                     mean     sd  hdi_3%  \
# 1|userID[s_858]                                    0.005  0.031  -0.049
# 1|userID[s_860]                                   -0.047  0.029  -0.101
# 1|userID[s_865]                                   -0.084  0.029  -0.140
# 1|userID[s_870]                                   -0.008  0.031  -0.066
# 1|userID[s_874]                                    0.007  0.031  -0.052
# 1|userID[s_875]                                    0.073  0.031   0.017
# 1|userID[s_882]                                    0.079  0.030   0.022
# 1|userID[s_923]                                   -0.081  0.031  -0.139
# 1|userID[s_93]                                     0.084  0.030   0.028
# 1|userID[s_931]                                   -0.004  0.030  -0.057
# 1|userID[s_936]                                    0.082  0.030   0.027
# 1|userID[s_937]                                    0.111  0.030   0.051
# 1|userID[s_939]                                   -0.111  0.031  -0.170
# 1|userID[s_940]                                    0.011  0.030  -0.043
# 1|userID[s_945]                                    0.068  0.031   0.008
# 1|userID[s_958]                                   -0.120  0.030  -0.178
# 1|userID[s_960]                                   -0.084  0.031  -0.142
# 1|userID[s_966]                                   -0.061  0.031  -0.119
# 1|userID[s_975]                                    0.039  0.029  -0.021
# 1|userID[s_976]                                    0.112  0.030   0.057
# 1|userID[s_993]                                    0.011  0.030  -0.043
# 1|userID[s_996]                                    0.041  0.030  -0.017
# 1|userID_sigma                                     0.084  0.005   0.074
# C(task, levels=base_lvl)[Unfilled Delay]          -0.097  0.007  -0.110
# C(task, levels=base_lvl)[Filled Delay - math]     -0.098  0.007  -0.111
# C(task, levels=base_lvl)[Filled Delay - emotions] -0.172  0.007  -0.185
# Intercept                                          0.886  0.009   0.868
# difficulty[2]                                     -0.025  0.006  -0.036
# difficulty[3]                                     -0.082  0.006  -0.095
# sigma                                              0.110  0.002   0.106
#
#                                                    hdi_97%  mcse_mean  \
# 1|userID[s_858]                                      0.063        0.0
# 1|userID[s_860]                                      0.009        0.0
# 1|userID[s_865]                                     -0.029        0.0
# 1|userID[s_870]                                      0.050        0.0
# 1|userID[s_874]                                      0.061        0.0
# 1|userID[s_875]                                      0.134        0.0
# 1|userID[s_882]                                      0.134        0.0
# 1|userID[s_923]                                     -0.025        0.0
# 1|userID[s_93]                                       0.142        0.0
# 1|userID[s_931]                                      0.055        0.0
# 1|userID[s_936]                                      0.140        0.0
# 1|userID[s_937]                                      0.164        0.0
# 1|userID[s_939]                                     -0.053        0.0
# 1|userID[s_940]                                      0.069        0.0
# 1|userID[s_945]                                      0.123        0.0
# 1|userID[s_958]                                     -0.067        0.0
# 1|userID[s_960]                                     -0.026        0.0
# 1|userID[s_966]                                     -0.003        0.0
# 1|userID[s_975]                                      0.090        0.0
# 1|userID[s_976]                                      0.171        0.0
# 1|userID[s_993]                                      0.070        0.0
# 1|userID[s_996]                                      0.095        0.0
# 1|userID_sigma                                       0.094        0.0
# C(task, levels=base_lvl)[Unfilled Delay]            -0.082        0.0
# C(task, levels=base_lvl)[Filled Delay - math]       -0.084        0.0
# C(task, levels=base_lvl)[Filled Delay - emotions]   -0.158        0.0
# Intercept                                            0.902        0.0
# difficulty[2]                                       -0.013        0.0
# difficulty[3]                                       -0.071        0.0
# sigma                                                0.113        0.0
#
#                                                    mcse_sd  ess_bulk  \
# 1|userID[s_858]                                      0.001    6222.0
# 1|userID[s_860]                                      0.000    6305.0
# 1|userID[s_865]                                      0.000    6319.0
# 1|userID[s_870]                                      0.001    5927.0
# 1|userID[s_874]                                      0.001    6678.0
# 1|userID[s_875]                                      0.000    6344.0
# 1|userID[s_882]                                      0.000    6722.0
# 1|userID[s_923]                                      0.000    6120.0
# 1|userID[s_93]                                       0.000    6771.0
# 1|userID[s_931]                                      0.000    6674.0
# 1|userID[s_936]                                      0.000    5970.0
# 1|userID[s_937]                                      0.000    7701.0
# 1|userID[s_939]                                      0.000    7025.0
# 1|userID[s_940]                                      0.001    7044.0
# 1|userID[s_945]                                      0.000    6809.0
# 1|userID[s_958]                                      0.000    6192.0
# 1|userID[s_960]                                      0.000    7125.0
# 1|userID[s_966]                                      0.000    6608.0
# 1|userID[s_975]                                      0.000    6281.0
# 1|userID[s_976]                                      0.000    5956.0
# 1|userID[s_993]                                      0.000    6976.0
# 1|userID[s_996]                                      0.000    7264.0
# 1|userID_sigma                                       0.000    1393.0
# C(task, levels=base_lvl)[Unfilled Delay]             0.000    5574.0
# C(task, levels=base_lvl)[Filled Delay - math]        0.000    5830.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    0.000    5432.0
# Intercept                                            0.000    2025.0
# difficulty[2]                                        0.000    7385.0
# difficulty[3]                                        0.000    7128.0
# sigma                                                0.000    6855.0
#
#                                                    ess_tail  r_hat
# 1|userID[s_858]                                      2887.0   1.00
# 1|userID[s_860]                                      2621.0   1.00
# 1|userID[s_865]                                      2876.0   1.01
# 1|userID[s_870]                                      2263.0   1.00
# 1|userID[s_874]                                      2745.0   1.00
# 1|userID[s_875]                                      2876.0   1.00
# 1|userID[s_882]                                      2511.0   1.00
# 1|userID[s_923]                                      2755.0   1.00
# 1|userID[s_93]                                       2753.0   1.00
# 1|userID[s_931]                                      2993.0   1.00
# 1|userID[s_936]                                      2998.0   1.00
# 1|userID[s_937]                                      2827.0   1.00
# 1|userID[s_939]                                      2783.0   1.00
# 1|userID[s_940]                                      2813.0   1.00
# 1|userID[s_945]                                      2590.0   1.00
# 1|userID[s_958]                                      2712.0   1.00
# 1|userID[s_960]                                      3048.0   1.00
# 1|userID[s_966]                                      2712.0   1.00
# 1|userID[s_975]                                      3042.0   1.00
# 1|userID[s_976]                                      2688.0   1.00
# 1|userID[s_993]                                      2940.0   1.00
# 1|userID[s_996]                                      2651.0   1.00
# 1|userID_sigma                                       2302.0   1.00
# C(task, levels=base_lvl)[Unfilled Delay]             3456.0   1.00
# C(task, levels=base_lvl)[Filled Delay - math]        3418.0   1.00
# C(task, levels=base_lvl)[Filled Delay - emotions]    3445.0   1.00
# Intercept                                            2573.0   1.00
# difficulty[2]                                        3181.0   1.00
# difficulty[3]                                        3202.0   1.00
# sigma                                                3056.0   1.00

# %% [markdown]
# ### Compare all data
# [top](#top)

# %%
df_compare_formulas_bernoulli = {}
for f in result_dic_bernoulli.keys():
    print(f, '\n')
    df_compare_formulas_bernoulli[f] = az.compare(result_dic_bernoulli[f])
    
    print(df_compare_formulas_bernoulli[f])
    
    az.plot_compare(df_compare_formulas_bernoulli[f], insample_dev=False);

    
    print()
# df_compare_formulas_bernoulli[f]
# Out:
# dataset_4
#
#                                                     rank     elpd_loo  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...     0  1355.236473
# correct_flt ~ C(task, levels=base_lvl) * diffic...     1  1351.790623
#
#                                                          p_loo  elpd_diff  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  132.306702    0.00000
# correct_flt ~ C(task, levels=base_lvl) * diffic...  138.542339    3.44585
#
#                                                       weight         se  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.974021  30.583499
# correct_flt ~ C(task, levels=base_lvl) * diffic...  0.025979  30.876694
#
#                                                          dse  warning scale
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.000000    False   log
# correct_flt ~ C(task, levels=base_lvl) * diffic...  2.703464    False   log

# %%
fig, ax = plt.subplots(figsize=(8, 4))
az.plot_forest(
    result_dic_bernoulli['dataset_4']['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'],
#     model_names=['Dataset 4'],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
az.plot_forest(
    list(result_dic_bernoulli['dataset_4'].values()),
    model_names=[f'{f}\n{formula}' for f in result_dic_bernoulli.keys() for formula in formulas2run],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
az.plot_forest(
    (list(result_dic_bernoulli['dataset_4'].values())
    )[::2],
#     model_names=[f'{f}' for f in result_dic_bernoulli.keys()],
    var_names=["C(task, levels=base_lvl):difficulty"],
    combined=True,
#     figsize=(12, 10)
    ax=ax
);

ax.axvline(0, c='k')

# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
# # plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
# plt.show()


# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.6, 1))
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
az.plot_forest(result_dic_bernoulli['dataset_4']['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'], 
               var_names=["C(task, levels=base_lvl):difficulty"], combined=True, figsize=(8, 4))
plt.axvline(0, c='k');

# %% [markdown]
# ### Run some predictions
# [top](#top)

# %%
interactions = ['Unfilled Delay, 2', 'Unfilled Delay, 3', 'Filled Delay - math, 2', 'Filled Delay - math, 3', 'Filled Delay - emotions, 2', 'Filled Delay - emotions, 3']
d2, d3, m2, m3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]

# %%
_, ax = plt.subplots()
for idx, x in enumerate([d2, d3, m2, m3, i2, i3]):
    az.plot_dist(x, label=x["C(task, levels=base_lvl):difficulty_dim"].item(), plot_kwargs={"color": f"C{idx}"}, ax=ax)
ax.legend(loc="upper left");

# %%
# Probability that the FM slope is less than 0

print(f"""
Probability that the UD slope is less than 0:
level 2: {(d2 < 0).mean().item()}
level 3: {(d3 < 0).mean().item()}
""")
# Out:
# Probability that the UD slope is less than 0:
# level 2: 0.3275
# level 3: 0.566

# %% [markdown]
# ---

# %%
for f in result_dic_bernoulli.keys():

    d2, d3, m2, m3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]
    print(f"""
Experiment {f}:
  Probability that the UD slope is less than 0:
    level 2: {(d2 < 0).mean().item()}
    level 3: {(d3 < 0).mean().item()}
    
  Probability that the FD-m (Math) slope is less than 0:
    level 2: {(m2 < 0).mean().item()}
    level 3: {(m3 < 0).mean().item()}
    
  Probability that the FD-e slope is less than 0:
    level 2: {(i2 < 0).mean().item()}
    level 3: {(i3 < 0).mean().item()}
    
    """)
# Out:
# Experiment dataset_4:
#   Probability that the UD slope is less than 0:
#     level 2: 0.3275
#     level 3: 0.566
#
#   Probability that the FD-m (Math) slope is less than 0:
#     level 2: 0.2955
#     level 3: 0.16725
#
#   Probability that the FD-e slope is less than 0:
#     level 2: 0.0905
#     level 3: 0.023

# %% [markdown]
# ### Save the inference
# [top](#top)
#
# It could be possible to use this:
# ```
# result_dic_bernoulli['dataset_4']['correct_flt ~ task * difficulty + (1|userID)'].to_netcdf()
# ```
#
# but it doesn't preserve the dictionary, so I use pickle.

# %%
# save the dictionary to a pickle file
with open(opj(path_inference_data,'FMP_math_baselineFM_inference_data_dict.pkl'), 'wb') as f:
    pickle.dump(result_dic_bernoulli['dataset_4'], f)

# %%
# # Load the dictionary from the pickle file
# with open(opj(path_inference_data,'FMP_math_baselineFM_inference_data_dict.pkl'), 'rb') as f:
#     loaded_inference_data_dict = pickle.load(f)

# %%
# %load_ext watermark

# %watermark -a 'Jan Kadlec' -nmvu -iv -iv -w -p pytensor
# Out:
# Author: Jan Kadlec
#
# Last updated: Wed Feb 05 2025
#
# Python implementation: CPython
# Python version       : 3.12.5
# IPython version      : 8.25.0
#
# pytensor: 2.23.0
#
# Compiler    : GCC 12.4.0
# OS          : Linux
# Release     : 5.14.0-427.42.1.el9_4.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 96
# Architecture: 64bit
#
# sys       : 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:36:51) [GCC 12.4.0]
# bambi     : 0.14.0
# arviz     : 0.19.0
# pandas    : 2.2.2
# numpy     : 1.26.4
# matplotlib: 3.9.2
#
# Watermark: 2.4.3

# %% [markdown]
# [top](#top)
