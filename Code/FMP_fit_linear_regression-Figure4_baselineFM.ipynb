# %% [markdown]
# ##### top

# %% [markdown]
# # FMP modelling for Figure 4 (Math)
#
# This notebook runs Bayesian models on Datasets 4 (dataset with Math condition) that is described in the article to assess interaction between perception and memory difficulty levels in the FMP. We fit the following formulas to mean score within the condition. Throughout the notebook, I use `task` as a term for memory difficulty levels (M, UD, FD-e, FD-m), `difficulty` as a term for perceptual difficulty levels (1, 2, 3), and `userID` as a variable denoting individual participants. It is the exact same principle and code as the `FMP_fit_linear_regression-Figure4.ipynb` but it sets the FM as a reference level instead of UD.
#
#
# * Model task and difficulty interaction with user as a random effect. Equation:
#     * _correct_flt ~ task * difficulty + (1|userID)_
# * Model task and difficulty as main effects without interaction with user as a random effect. Equation:
#     * _correct_flt ~ task + difficulty + (1|userID)_
#
#
#
# We model mean accuracy per participant per condition.
#
#
# * [Models](#Models)
# * [Plot results](#Plot-results)
# * [Compare all data](#Compare-all-data)
# * [Save the inference](#Save-the-inference)

# %%
import os, sys
import pickle
from os.path import join as opj
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

az.style.use("arviz-darkgrid")
SEED = 7355608


# Importing module for functions
functions_modul =  "./functions"
sys.path.insert(0, functions_modul)

# import all processing and plotting functions
from bayesian_modelling_functions import fit_model, print_model

path_general = "../"
path_data = opj(path_general, "Data", "datasets")
path_inference_data = opj(path_general, "Data", "model_inference_data")


# set the numer of CPU
num_cpu = min(4, os.cpu_count()-1)
print(f'We will have {num_cpu} cores.\n')

path_dic = {
#     'dataset_1' : opj(path_data, 'FMP_dataset_1.csv'),
#     'dataset_2': opj(path_data, 'FMP_dataset_2.csv'),
#     'dataset_3': opj(path_data, 'FMP_dataset_3.csv'),
#     'concat_datasets_123': opj(path_data, 'FMP_concat_datasets_123.csv'),
    'dataset_4': opj(path_data, 'FMP_dataset_4.csv'),
}


# load all dataframes
df_dic = {}

# only selected cols
select_cols = ['stim1', 'stim2', 'target', 'RT', 'userID', 'difficulty', 'levels', 'task', 'correct_flt', 'order']


for f in path_dic.keys():   
    if f=="first_pilot":
        df_dic[f] = pd.read_csv(path_dic[f], usecols=(set(['correct_check'])|set(select_cols))-set(['correct_flt']))
        # convert boolean answers to floats to be able to do mean
        df_dic[f]['correct_flt'] = df_dic[f].correct_check.astype(float)
    elif 'longitudinal_' in f:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols+['target_loc', 'target_loc_simple'])
    else:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols)
    
    df_dic[f]["Experiment"] = f
        

    # clean
    df_dic[f].reset_index(drop=True, inplace=True)
    
    if 'Unnamed: 0' in df_dic[f].columns:
        df_dic[f].drop('Unnamed: 0', inplace=True, axis=1)
        
    
    # find low performing participants
    tt = df_dic[f].loc[df_dic[f]['task'].isin(['face matching', 'perc', 'perception'])].groupby(['userID', 'difficulty']).correct_flt.mean()

    drop_ptc = tt[tt<=0.5].reset_index().userID.values
    print(f'\nIn {f} dropping {len(drop_ptc)} participants for low accuracy in FM.')
    print(tt[tt<=0.5])

    # and remove them
    df_dic[f] = df_dic[f].loc[~df_dic[f]['userID'].isin(drop_ptc)]
    # clean up
    drop_ptc, tt = None, None
    
    print(f"\nThere is now N={df_dic[f]['userID'].unique().size} participants in {f}.")



#####
# rename the levels
rename_tasks_dic = {'perception':'Matching', 'perc':'Matching', 'blank':'Unfilled Delay', 'faces':'Filled Delay - emotions', 'math':'Filled Delay - math'}

# define orders
hue_order = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions']
hue_order_math = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - math']



# rename the memory task labels in the df
for f in df_dic.keys():
    if f=='noise':
        continue
    df_dic[f]['task'] = df_dic[f]['task'].map(rename_tasks_dic).fillna(df_dic[f]['task'])
# Out:
# We will have 4 cores.
#
#
# In dataset_4 dropping 0 participants for low accuracy in FM.
# Series([], Name: correct_flt, dtype: float64)
#
# There is now N=150 participants in dataset_4.

# %%
# select only specific datasets and prepare them
datasets2fit = ['dataset_4']

df_dic_fit = {}


for f in datasets2fit:
    data=None
    
    # groupby and make means for ptc and condition
    data = df_dic[f].groupby(['userID', 'task', 'difficulty'], observed=False).correct_flt.mean().reset_index()

    # convert all variables to categories
    # categorical_cols = data.columns[data.dtypes == object].tolist() + ['difficulty']
    categorical_cols = ['userID', 'task', 'difficulty']
    for col in categorical_cols:
        if col == 'task':
            # specify the order that we want
            data[col] = pd.Categorical(data[col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
            #['Unfilled Delay', 'Matching', 'Filled Delay - emotions']
            
            # also do it for the original datasets
            df_dic[f][col] = pd.Categorical(df_dic[f][col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
        else:
            data[col] = data[col].astype("category")
            df_dic[f][col] = df_dic[f][col].astype("category")

    # check
    print('\n',f)
    df_dic[f].info()
        
    # save
    df_dic_fit[f] = data.copy()

# # drop them for now
# data[data.correct_flt.isna()]
# Out:
#  dataset_4
# <class 'pandas.core.frame.DataFrame'>
# Index: 36000 entries, 0 to 35999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userID       36000 non-null  category
#  1   target       36000 non-null  object
#  2   stim1        36000 non-null  object
#  3   stim2        36000 non-null  object
#  4   correct_flt  35298 non-null  float64
#  5   RT           35298 non-null  float64
#  6   task         36000 non-null  category
#  7   order        36000 non-null  int64
#  8   difficulty   36000 non-null  category
#  9   levels       36000 non-null  int64
#  10  Experiment   36000 non-null  object
# dtypes: category(3), float64(2), int64(2), object(4)
# memory usage: 2.6+ MB

# %% [markdown]
# ## Models
# [top](#top)

# %%
model_assumptions = {
    "correct_flt ~ task * difficulty + (1|userID)": "Each user has their own baseline performance, but the effect of task and difficulty is assumed to be the same across all users.",
    "correct_flt ~ task + difficulty + (1|userID)": "Assumes that each user has their own baseline performance, but the effects of task and difficulty are consistent across all users without any interaction between task and difficulty.",
}

# define what we want to run
base_lvl = ['Matching', 'Unfilled Delay', 'Filled Delay - math', 'Filled Delay - emotions']
formulas2run = [
    "correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)",
    "correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)",
]

# %%
# define where we will store the results
model_dic_bernoulli = {}
result_dic_bernoulli = {}

for f in df_dic_fit.keys():
    print(f'\nFitting dataset {f}\n')
    # create datasets
    if f not in model_dic_bernoulli.keys():
        model_dic_bernoulli[f] = {}
    if f not in result_dic_bernoulli.keys():
        result_dic_bernoulli[f] = {}
    
    for formula in formulas2run:
        print(f'\nFitting formula {formula}\n')
    
        model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula] = fit_model(formula, df_dic_fit[f], categorical_cols, base_lvl=base_lvl,
                                                                                      num_cpu=num_cpu, check_priors=False, sample_priors=False)
# Out:
# Sampling 4 chains, 0 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:29
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 30 seconds.

# %%
model_dic_bernoulli[f][formulas2run[0]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.7247)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#             C(task, levels=base_lvl):difficulty ~ Normal(mu: [0. 0. 0. 0. 0. 0.], sigma: [1.3926 1.3926
#                 1.3926 1.3926 1.3926 1.3926])
#
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.7247))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
model_dic_bernoulli[f][formulas2run[1]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.6667)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.6667))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# ### check priors

# %%
model_dic_bernoulli[f][formulas2run[0]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), C(task, levels=base_lvl):difficulty, Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - math'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - math, 2'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - math, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
model_dic_bernoulli[f][formulas2run[1]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - math'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>]], dtype=object)

# %% [markdown]
# ### check posterior

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[0]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - math'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[1]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - math'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %% [markdown]
# ---
# ## Plot results

# %% [markdown]
# ## FMP dataset 4 -- with Math condition
# [top](#top)

# %%
f = 'dataset_4'
# print(f'Dataset: {f}')
# print_model(model_dic_bernoulli[f], result_dic_bernoulli[f])

print(f'Dataset: {f}')
for formula in formulas2run:
    print(f'\nFitting formula {formula}\n')
    print_model(model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula])
# Out:
# Dataset: dataset_4
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1010] -0.051  0.031  -0.109    0.008        0.0    0.000    6269.0
# 1|userID[s_1018] -0.042  0.030  -0.097    0.015        0.0    0.000    7265.0
# 1|userID[s_1024]  0.042  0.032  -0.016    0.101        0.0    0.000    6292.0
# 1|userID[s_1029]  0.027  0.030  -0.031    0.082        0.0    0.000    6796.0
# 1|userID[s_1031]  0.013  0.030  -0.042    0.068        0.0    0.000    6378.0
# 1|userID[s_1035]  0.068  0.030   0.012    0.124        0.0    0.000    5497.0
# 1|userID[s_1037] -0.084  0.031  -0.143   -0.027        0.0    0.000    6208.0
# 1|userID[s_1041]  0.031  0.031  -0.026    0.090        0.0    0.000    6404.0
# 1|userID[s_1054]  0.007  0.031  -0.050    0.065        0.0    0.001    6306.0
# 1|userID[s_1059]  0.068  0.030   0.015    0.125        0.0    0.000    6164.0
# 1|userID[s_1066] -0.038  0.030  -0.100    0.015        0.0    0.000    6522.0
# 1|userID[s_1075]  0.063  0.031   0.005    0.123        0.0    0.000    6979.0
# 1|userID[s_1089]  0.113  0.031   0.057    0.175        0.0    0.000    6308.0
# 1|userID[s_1090] -0.059  0.031  -0.118   -0.003        0.0    0.000    4913.0
# 1|userID[s_1094] -0.007  0.030  -0.063    0.049        0.0    0.000    6010.0
# 1|userID[s_1099]  0.067  0.030   0.013    0.126        0.0    0.000    6647.0
# 1|userID[s_1117]  0.035  0.030  -0.025    0.088        0.0    0.000    6605.0
# 1|userID[s_112]  -0.004  0.030  -0.058    0.056        0.0    0.001    7134.0
# 1|userID[s_1121]  0.071  0.031   0.015    0.130        0.0    0.000    5957.0
# 1|userID[s_1124] -0.019  0.029  -0.071    0.038        0.0    0.000    5966.0
# 1|userID[s_128]  -0.091  0.029  -0.142   -0.031        0.0    0.000    5813.0
# 1|userID[s_139]  -0.128  0.030  -0.182   -0.070        0.0    0.000    6928.0
# 1|userID[s_168]   0.144  0.030   0.089    0.200        0.0    0.000    5379.0
# 1|userID[s_184]  -0.156  0.030  -0.210   -0.097        0.0    0.000    6476.0
# 1|userID[s_189]   0.080  0.031   0.022    0.138        0.0    0.000    5338.0
# 1|userID[s_200]  -0.040  0.030  -0.097    0.017        0.0    0.000    5841.0
# 1|userID[s_204]  -0.088  0.030  -0.144   -0.030        0.0    0.000    5584.0
# 1|userID[s_218]   0.088  0.030   0.034    0.145        0.0    0.000    6501.0
# 1|userID[s_222]  -0.061  0.030  -0.115   -0.001        0.0    0.000    6967.0
# 1|userID[s_225]   0.097  0.031   0.042    0.155        0.0    0.000    5946.0
#
#                   ess_tail  r_hat
# 1|userID[s_1010]    2521.0   1.00
# 1|userID[s_1018]    2753.0   1.00
# 1|userID[s_1024]    2490.0   1.01
# 1|userID[s_1029]    2797.0   1.00
# 1|userID[s_1031]    2922.0   1.00
# 1|userID[s_1035]    2798.0   1.00
# 1|userID[s_1037]    2943.0   1.00
# 1|userID[s_1041]    2645.0   1.00
# 1|userID[s_1054]    3147.0   1.00
# 1|userID[s_1059]    2839.0   1.00
# 1|userID[s_1066]    2604.0   1.00
# 1|userID[s_1075]    2916.0   1.00
# 1|userID[s_1089]    2357.0   1.00
# 1|userID[s_1090]    2651.0   1.00
# 1|userID[s_1094]    2856.0   1.00
# 1|userID[s_1099]    3260.0   1.00
# 1|userID[s_1117]    2719.0   1.00
# 1|userID[s_112]     2503.0   1.00
# 1|userID[s_1121]    3042.0   1.00
# 1|userID[s_1124]    2894.0   1.00
# 1|userID[s_128]     2546.0   1.00
# 1|userID[s_139]     3236.0   1.00
# 1|userID[s_168]     2683.0   1.00
# 1|userID[s_184]     3042.0   1.00
# 1|userID[s_189]     2540.0   1.00
# 1|userID[s_200]     2508.0   1.00
# 1|userID[s_204]     2868.0   1.00
# 1|userID[s_218]     2738.0   1.00
# 1|userID[s_222]     2647.0   1.00
# 1|userID[s_225]     2388.0   1.00
# ...
#
#                                                      mean     sd  hdi_3%  \
# 1|userID[s_880]                                    -0.150  0.031  -0.206
# 1|userID[s_881]                                     0.040  0.030  -0.017
# 1|userID[s_888]                                    -0.081  0.030  -0.137
# 1|userID[s_902]                                     0.011  0.030  -0.047
# 1|userID[s_907]                                    -0.080  0.030  -0.134
# 1|userID[s_908]                                     0.029  0.030  -0.030
# 1|userID[s_916]                                     0.088  0.030   0.032
# 1|userID[s_920]                                    -0.072  0.030  -0.127
# 1|userID[s_926]                                     0.106  0.030   0.052
# 1|userID[s_928]                                     0.047  0.030  -0.010
# 1|userID[s_933]                                    -0.010  0.029  -0.065
# 1|userID[s_967]                                     0.132  0.030   0.077
# 1|userID[s_973]                                    -0.041  0.031  -0.099
# 1|userID[s_981]                                     0.040  0.030  -0.016
# 1|userID[s_986]                                    -0.011  0.030  -0.065
# 1|userID[s_990]                                     0.055  0.031  -0.003
# 1|userID_sigma                                      0.084  0.006   0.074
# C(task, levels=base_lvl)[Unfilled Delay]           -0.098  0.013  -0.123
# C(task, levels=base_lvl)[Filled Delay - math]      -0.107  0.013  -0.130
# C(task, levels=base_lvl)[Filled Delay - emotions]  -0.192  0.013  -0.215
# C(task, levels=base_lvl):difficulty[Unfilled De...  0.008  0.018  -0.027
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.003  0.018  -0.037
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.009  0.018  -0.023
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.017  0.018  -0.016
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.024  0.018  -0.011
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.036  0.018   0.002
# Intercept                                           0.893  0.011   0.873
# difficulty[2]                                      -0.035  0.013  -0.059
# difficulty[3]                                      -0.094  0.013  -0.117
# sigma                                               0.110  0.002   0.106
#
#                                                     hdi_97%  mcse_mean  \
# 1|userID[s_880]                                      -0.094        0.0
# 1|userID[s_881]                                       0.094        0.0
# 1|userID[s_888]                                      -0.024        0.0
# 1|userID[s_902]                                       0.067        0.0
# 1|userID[s_907]                                      -0.021        0.0
# 1|userID[s_908]                                       0.084        0.0
# 1|userID[s_916]                                       0.146        0.0
# 1|userID[s_920]                                      -0.015        0.0
# 1|userID[s_926]                                       0.164        0.0
# 1|userID[s_928]                                       0.100        0.0
# 1|userID[s_933]                                       0.045        0.0
# 1|userID[s_967]                                       0.188        0.0
# 1|userID[s_973]                                       0.014        0.0
# 1|userID[s_981]                                       0.097        0.0
# 1|userID[s_986]                                       0.046        0.0
# 1|userID[s_990]                                       0.111        0.0
# 1|userID_sigma                                        0.094        0.0
# C(task, levels=base_lvl)[Unfilled Delay]             -0.075        0.0
# C(task, levels=base_lvl)[Filled Delay - math]        -0.082        0.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    -0.167        0.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.039        0.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.028        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.043        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.051        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.057        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.071        0.0
# Intercept                                             0.914        0.0
# difficulty[2]                                        -0.011        0.0
# difficulty[3]                                        -0.071        0.0
# sigma                                                 0.113        0.0
#
#                                                     mcse_sd  ess_bulk  \
# 1|userID[s_880]                                         0.0    5794.0
# 1|userID[s_881]                                         0.0    5942.0
# 1|userID[s_888]                                         0.0    5982.0
# 1|userID[s_902]                                         0.0    5721.0
# 1|userID[s_907]                                         0.0    6286.0
# 1|userID[s_908]                                         0.0    6463.0
# 1|userID[s_916]                                         0.0    5942.0
# 1|userID[s_920]                                         0.0    6272.0
# 1|userID[s_926]                                         0.0    6186.0
# 1|userID[s_928]                                         0.0    6028.0
# 1|userID[s_933]                                         0.0    5702.0
# 1|userID[s_967]                                         0.0    5704.0
# 1|userID[s_973]                                         0.0    6988.0
# 1|userID[s_981]                                         0.0    5718.0
# 1|userID[s_986]                                         0.0    6146.0
# 1|userID[s_990]                                         0.0    5986.0
# 1|userID_sigma                                          0.0     976.0
# C(task, levels=base_lvl)[Unfilled Delay]                0.0    2178.0
# C(task, levels=base_lvl)[Filled Delay - math]           0.0    2187.0
# C(task, levels=base_lvl)[Filled Delay - emotions]       0.0    2008.0
# C(task, levels=base_lvl):difficulty[Unfilled De...      0.0    2493.0
# C(task, levels=base_lvl):difficulty[Unfilled De...      0.0    2365.0
# C(task, levels=base_lvl):difficulty[Filled Dela...      0.0    2335.0
# C(task, levels=base_lvl):difficulty[Filled Dela...      0.0    2382.0
# C(task, levels=base_lvl):difficulty[Filled Dela...      0.0    2125.0
# C(task, levels=base_lvl):difficulty[Filled Dela...      0.0    2154.0
# Intercept                                               0.0    1122.0
# difficulty[2]                                           0.0    1904.0
# difficulty[3]                                           0.0    1654.0
# sigma                                                   0.0    6308.0
#
#                                                     ess_tail  r_hat
# 1|userID[s_880]                                       2931.0    1.0
# 1|userID[s_881]                                       3000.0    1.0
# 1|userID[s_888]                                       2951.0    1.0
# 1|userID[s_902]                                       2743.0    1.0
# 1|userID[s_907]                                       2592.0    1.0
# 1|userID[s_908]                                       2482.0    1.0
# 1|userID[s_916]                                       2657.0    1.0
# 1|userID[s_920]                                       2756.0    1.0
# 1|userID[s_926]                                       2993.0    1.0
# 1|userID[s_928]                                       2758.0    1.0
# 1|userID[s_933]                                       3013.0    1.0
# 1|userID[s_967]                                       2565.0    1.0
# 1|userID[s_973]                                       2758.0    1.0
# 1|userID[s_981]                                       2486.0    1.0
# 1|userID[s_986]                                       2305.0    1.0
# 1|userID[s_990]                                       2819.0    1.0
# 1|userID_sigma                                        2098.0    1.0
# C(task, levels=base_lvl)[Unfilled Delay]              2424.0    1.0
# C(task, levels=base_lvl)[Filled Delay - math]         2977.0    1.0
# C(task, levels=base_lvl)[Filled Delay - emotions]     2945.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    2969.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    2474.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2917.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2418.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2710.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2719.0    1.0
# Intercept                                             1994.0    1.0
# difficulty[2]                                         2499.0    1.0
# difficulty[3]                                         2401.0    1.0
# sigma                                                 2622.0    1.0
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1010] -0.052  0.030  -0.107    0.006        0.0    0.000    7053.0
# 1|userID[s_1018] -0.041  0.031  -0.098    0.019        0.0    0.000    5927.0
# 1|userID[s_1024]  0.041  0.030  -0.013    0.098        0.0    0.000    6612.0
# 1|userID[s_1029]  0.028  0.032  -0.032    0.086        0.0    0.000    6517.0
# 1|userID[s_1031]  0.013  0.031  -0.041    0.074        0.0    0.001    6500.0
# 1|userID[s_1035]  0.067  0.031   0.006    0.123        0.0    0.000    5700.0
# 1|userID[s_1037] -0.085  0.031  -0.139   -0.023        0.0    0.000    6394.0
# 1|userID[s_1041]  0.031  0.030  -0.026    0.087        0.0    0.000    6190.0
# 1|userID[s_1054]  0.007  0.030  -0.047    0.065        0.0    0.001    5454.0
# 1|userID[s_1059]  0.068  0.030   0.011    0.123        0.0    0.000    6112.0
# 1|userID[s_1066] -0.038  0.030  -0.092    0.021        0.0    0.000    5691.0
# 1|userID[s_1075]  0.064  0.031   0.008    0.124        0.0    0.000    6470.0
# 1|userID[s_1089]  0.113  0.032   0.054    0.173        0.0    0.000    6249.0
# 1|userID[s_1090] -0.059  0.031  -0.116    0.000        0.0    0.000    6768.0
# 1|userID[s_1094] -0.007  0.030  -0.065    0.047        0.0    0.000    6673.0
# 1|userID[s_1099]  0.066  0.031   0.008    0.123        0.0    0.000    6051.0
# 1|userID[s_1117]  0.035  0.030  -0.021    0.092        0.0    0.000    5817.0
# 1|userID[s_112]  -0.004  0.030  -0.056    0.055        0.0    0.001    5824.0
# 1|userID[s_1121]  0.071  0.030   0.016    0.129        0.0    0.000    6020.0
# 1|userID[s_1124] -0.019  0.031  -0.079    0.036        0.0    0.000    5897.0
# 1|userID[s_128]  -0.090  0.030  -0.147   -0.033        0.0    0.000    5208.0
# 1|userID[s_139]  -0.127  0.030  -0.185   -0.073        0.0    0.000    5334.0
# 1|userID[s_168]   0.144  0.030   0.090    0.202        0.0    0.000    5892.0
# 1|userID[s_184]  -0.157  0.031  -0.217   -0.103        0.0    0.000    5955.0
# 1|userID[s_189]   0.079  0.030   0.025    0.138        0.0    0.000    6533.0
# 1|userID[s_200]  -0.040  0.031  -0.096    0.018        0.0    0.000    6189.0
# 1|userID[s_204]  -0.088  0.029  -0.144   -0.034        0.0    0.000    7005.0
# 1|userID[s_218]   0.088  0.031   0.029    0.146        0.0    0.000    6365.0
# 1|userID[s_222]  -0.060  0.031  -0.115   -0.002        0.0    0.000    6271.0
# 1|userID[s_225]   0.097  0.031   0.040    0.154        0.0    0.000    6354.0
#
#                   ess_tail  r_hat
# 1|userID[s_1010]    2766.0    1.0
# 1|userID[s_1018]    2338.0    1.0
# 1|userID[s_1024]    2707.0    1.0
# 1|userID[s_1029]    2539.0    1.0
# 1|userID[s_1031]    2649.0    1.0
# 1|userID[s_1035]    2724.0    1.0
# 1|userID[s_1037]    3241.0    1.0
# 1|userID[s_1041]    3178.0    1.0
# 1|userID[s_1054]    2417.0    1.0
# 1|userID[s_1059]    3026.0    1.0
# 1|userID[s_1066]    2565.0    1.0
# 1|userID[s_1075]    2607.0    1.0
# 1|userID[s_1089]    2847.0    1.0
# 1|userID[s_1090]    2771.0    1.0
# 1|userID[s_1094]    2903.0    1.0
# 1|userID[s_1099]    2362.0    1.0
# 1|userID[s_1117]    2720.0    1.0
# 1|userID[s_112]     2983.0    1.0
# 1|userID[s_1121]    2547.0    1.0
# 1|userID[s_1124]    3185.0    1.0
# 1|userID[s_128]     2680.0    1.0
# 1|userID[s_139]     2833.0    1.0
# 1|userID[s_168]     2851.0    1.0
# 1|userID[s_184]     3243.0    1.0
# 1|userID[s_189]     2775.0    1.0
# 1|userID[s_200]     3010.0    1.0
# 1|userID[s_204]     3137.0    1.0
# 1|userID[s_218]     2475.0    1.0
# 1|userID[s_222]     2790.0    1.0
# 1|userID[s_225]     2973.0    1.0
# ...
#
#                                                     mean     sd  hdi_3%  \
# 1|userID[s_841]                                    0.149  0.031   0.093
# 1|userID[s_850]                                    0.062  0.029   0.008
# 1|userID[s_856]                                   -0.015  0.031  -0.075
# 1|userID[s_857]                                   -0.018  0.029  -0.074
# 1|userID[s_866]                                   -0.016  0.031  -0.072
# 1|userID[s_88]                                     0.047  0.031  -0.010
# 1|userID[s_880]                                   -0.151  0.030  -0.207
# 1|userID[s_881]                                    0.039  0.030  -0.016
# 1|userID[s_888]                                   -0.081  0.030  -0.136
# 1|userID[s_902]                                    0.011  0.030  -0.043
# 1|userID[s_907]                                   -0.080  0.030  -0.135
# 1|userID[s_908]                                    0.029  0.031  -0.029
# 1|userID[s_916]                                    0.087  0.030   0.033
# 1|userID[s_920]                                   -0.073  0.031  -0.131
# 1|userID[s_926]                                    0.106  0.031   0.048
# 1|userID[s_928]                                    0.047  0.031  -0.009
# 1|userID[s_933]                                   -0.010  0.030  -0.066
# 1|userID[s_967]                                    0.131  0.031   0.072
# 1|userID[s_973]                                   -0.041  0.031  -0.097
# 1|userID[s_981]                                    0.040  0.030  -0.020
# 1|userID[s_986]                                   -0.011  0.030  -0.067
# 1|userID[s_990]                                    0.055  0.029  -0.000
# 1|userID_sigma                                     0.084  0.006   0.073
# C(task, levels=base_lvl)[Unfilled Delay]          -0.096  0.007  -0.110
# C(task, levels=base_lvl)[Filled Delay - math]     -0.098  0.007  -0.112
# C(task, levels=base_lvl)[Filled Delay - emotions] -0.172  0.007  -0.185
# Intercept                                          0.885  0.009   0.868
# difficulty[2]                                     -0.025  0.006  -0.037
# difficulty[3]                                     -0.082  0.006  -0.094
# sigma                                              0.110  0.002   0.106
#
#                                                    hdi_97%  mcse_mean  \
# 1|userID[s_841]                                      0.207        0.0
# 1|userID[s_850]                                      0.119        0.0
# 1|userID[s_856]                                      0.042        0.0
# 1|userID[s_857]                                      0.036        0.0
# 1|userID[s_866]                                      0.044        0.0
# 1|userID[s_88]                                       0.106        0.0
# 1|userID[s_880]                                     -0.094        0.0
# 1|userID[s_881]                                      0.096        0.0
# 1|userID[s_888]                                     -0.023        0.0
# 1|userID[s_902]                                      0.068        0.0
# 1|userID[s_907]                                     -0.022        0.0
# 1|userID[s_908]                                      0.086        0.0
# 1|userID[s_916]                                      0.142        0.0
# 1|userID[s_920]                                     -0.017        0.0
# 1|userID[s_926]                                      0.164        0.0
# 1|userID[s_928]                                      0.105        0.0
# 1|userID[s_933]                                      0.048        0.0
# 1|userID[s_967]                                      0.187        0.0
# 1|userID[s_973]                                      0.018        0.0
# 1|userID[s_981]                                      0.095        0.0
# 1|userID[s_986]                                      0.044        0.0
# 1|userID[s_990]                                      0.111        0.0
# 1|userID_sigma                                       0.094        0.0
# C(task, levels=base_lvl)[Unfilled Delay]            -0.083        0.0
# C(task, levels=base_lvl)[Filled Delay - math]       -0.085        0.0
# C(task, levels=base_lvl)[Filled Delay - emotions]   -0.158        0.0
# Intercept                                            0.903        0.0
# difficulty[2]                                       -0.013        0.0
# difficulty[3]                                       -0.070        0.0
# sigma                                                0.113        0.0
#
#                                                    mcse_sd  ess_bulk  \
# 1|userID[s_841]                                      0.000    5961.0
# 1|userID[s_850]                                      0.000    5911.0
# 1|userID[s_856]                                      0.001    5815.0
# 1|userID[s_857]                                      0.000    6037.0
# 1|userID[s_866]                                      0.000    6282.0
# 1|userID[s_88]                                       0.000    6114.0
# 1|userID[s_880]                                      0.000    5338.0
# 1|userID[s_881]                                      0.000    6986.0
# 1|userID[s_888]                                      0.000    5565.0
# 1|userID[s_902]                                      0.000    6549.0
# 1|userID[s_907]                                      0.000    5797.0
# 1|userID[s_908]                                      0.000    6115.0
# 1|userID[s_916]                                      0.000    6096.0
# 1|userID[s_920]                                      0.000    6612.0
# 1|userID[s_926]                                      0.000    6025.0
# 1|userID[s_928]                                      0.000    5728.0
# 1|userID[s_933]                                      0.001    5612.0
# 1|userID[s_967]                                      0.000    5987.0
# 1|userID[s_973]                                      0.000    5088.0
# 1|userID[s_981]                                      0.000    5473.0
# 1|userID[s_986]                                      0.000    6248.0
# 1|userID[s_990]                                      0.000    6385.0
# 1|userID_sigma                                       0.000    1229.0
# C(task, levels=base_lvl)[Unfilled Delay]             0.000    5208.0
# C(task, levels=base_lvl)[Filled Delay - math]        0.000    5934.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    0.000    5516.0
# Intercept                                            0.000    1908.0
# difficulty[2]                                        0.000    7410.0
# difficulty[3]                                        0.000    7779.0
# sigma                                                0.000    5772.0
#
#                                                    ess_tail  r_hat
# 1|userID[s_841]                                      3067.0    1.0
# 1|userID[s_850]                                      2697.0    1.0
# 1|userID[s_856]                                      2759.0    1.0
# 1|userID[s_857]                                      2628.0    1.0
# 1|userID[s_866]                                      2602.0    1.0
# 1|userID[s_88]                                       2692.0    1.0
# 1|userID[s_880]                                      2611.0    1.0
# 1|userID[s_881]                                      3035.0    1.0
# 1|userID[s_888]                                      2942.0    1.0
# 1|userID[s_902]                                      2981.0    1.0
# 1|userID[s_907]                                      2679.0    1.0
# 1|userID[s_908]                                      2990.0    1.0
# 1|userID[s_916]                                      2948.0    1.0
# 1|userID[s_920]                                      3257.0    1.0
# 1|userID[s_926]                                      2638.0    1.0
# 1|userID[s_928]                                      2794.0    1.0
# 1|userID[s_933]                                      2742.0    1.0
# 1|userID[s_967]                                      2535.0    1.0
# 1|userID[s_973]                                      2342.0    1.0
# 1|userID[s_981]                                      2499.0    1.0
# 1|userID[s_986]                                      2367.0    1.0
# 1|userID[s_990]                                      2561.0    1.0
# 1|userID_sigma                                       2075.0    1.0
# C(task, levels=base_lvl)[Unfilled Delay]             3042.0    1.0
# C(task, levels=base_lvl)[Filled Delay - math]        3238.0    1.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    3052.0    1.0
# Intercept                                            2482.0    1.0
# difficulty[2]                                        3555.0    1.0
# difficulty[3]                                        3487.0    1.0
# sigma                                                2563.0    1.0

# %% [markdown]
# ### Compare all data
# [top](#top)

# %%
df_compare_formulas_bernoulli = {}
for f in result_dic_bernoulli.keys():
    print(f, '\n')
    df_compare_formulas_bernoulli[f] = az.compare(result_dic_bernoulli[f])
    
    print(df_compare_formulas_bernoulli[f])
    
    az.plot_compare(df_compare_formulas_bernoulli[f], insample_dev=False);

    
    print()
# df_compare_formulas_bernoulli[f]
# Out:
# dataset_4
#
#                                                     rank     elpd_loo  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...     0  1353.803352
# correct_flt ~ C(task, levels=base_lvl) * diffic...     1  1351.754594
#
#                                                          p_loo  elpd_diff  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  133.720891   0.000000
# correct_flt ~ C(task, levels=base_lvl) * diffic...  138.674097   2.048757
#
#                                                       weight         se  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.782408  30.636410
# correct_flt ~ C(task, levels=base_lvl) * diffic...  0.217592  30.875488
#
#                                                          dse  warning scale
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.000000    False   log
# correct_flt ~ C(task, levels=base_lvl) * diffic...  2.695777    False   log

# %%
fig, ax = plt.subplots(figsize=(8, 4))
az.plot_forest(
    result_dic_bernoulli['dataset_4']['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'],
#     model_names=['Dataset 4'],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
az.plot_forest(
    list(result_dic_bernoulli['dataset_4'].values()),
    model_names=[f'{f}\n{formula}' for f in result_dic_bernoulli.keys() for formula in formulas2run],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
az.plot_forest(
    (list(result_dic_bernoulli['dataset_4'].values())
    )[::2],
#     model_names=[f'{f}' for f in result_dic_bernoulli.keys()],
    var_names=["C(task, levels=base_lvl):difficulty"],
    combined=True,
#     figsize=(12, 10)
    ax=ax
);

ax.axvline(0, c='k')

# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
# # plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
# plt.show()


# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.6, 1))
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
az.plot_forest(result_dic_bernoulli['dataset_4']['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'], 
               var_names=["C(task, levels=base_lvl):difficulty"], combined=True, figsize=(8, 4))
plt.axvline(0, c='k');

# %% [markdown]
# ### Run some predictions
# [top](#top)

# %%
interactions = ['Unfilled Delay, 2', 'Unfilled Delay, 3', 'Filled Delay - math, 2', 'Filled Delay - math, 3', 'Filled Delay - emotions, 2', 'Filled Delay - emotions, 3']
d2, d3, m2, m3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]

# %%
_, ax = plt.subplots()
for idx, x in enumerate([d2, d3, m2, m3, i2, i3]):
    az.plot_dist(x, label=x["C(task, levels=base_lvl):difficulty_dim"].item(), plot_kwargs={"color": f"C{idx}"}, ax=ax)
ax.legend(loc="upper left");

# %%
# Probability that the FM slope is less than 0

print(f"""
Probability that the UD slope is less than 0:
level 2: {(d2 < 0).mean().item()}
level 3: {(d3 < 0).mean().item()}
""")
# Out:
# Probability that the UD slope is less than 0:
# level 2: 0.34025
# level 3: 0.57675

# %% [markdown]
# ---

# %%
for f in result_dic_bernoulli.keys():

    d2, d3, m2, m3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]
    print(f"""
Experiment {f}:
  Probability that the UD slope is less than 0:
    level 2: {(d2 < 0).mean().item()}
    level 3: {(d3 < 0).mean().item()}
    
  Probability that the FD-m (Math) slope is less than 0:
    level 2: {(m2 < 0).mean().item()}
    level 3: {(m3 < 0).mean().item()}
    
  Probability that the FD-e slope is less than 0:
    level 2: {(i2 < 0).mean().item()}
    level 3: {(i3 < 0).mean().item()}
    
    """)
# Out:
# Experiment dataset_4:
#   Probability that the UD slope is less than 0:
#     level 2: 0.34025
#     level 3: 0.57675
#
#   Probability that the FD-m (Math) slope is less than 0:
#     level 2: 0.3055
#     level 3: 0.175
#
#   Probability that the FD-e slope is less than 0:
#     level 2: 0.089
#     level 3: 0.02525

# %% [markdown]
# ### Save the inference
# [top](#top)
#
# It could be possible to use this:
# ```
# result_dic_bernoulli['dataset_4']['correct_flt ~ task * difficulty + (1|userID)'].to_netcdf()
# ```
#
# but it doesn't preserve the dictionary, so I use pickle.

# %%
# save the dictionary to a pickle file
with open(opj(path_inference_data,'FMP_math_baselineFM_inference_data_dict.pkl'), 'wb') as f:
    pickle.dump(result_dic_bernoulli['dataset_4'], f)

# %%
# # Load the dictionary from the pickle file
# with open(opj(path_inference_data,'FMP_math_baselineFM_inference_data_dict.pkl'), 'rb') as f:
#     loaded_inference_data_dict = pickle.load(f)

# %%
# %load_ext watermark

# %watermark -a 'Jan Kadlec' -nmvu -iv -iv -w -p pytensor
# Out:
# Author: Jan Kadlec
#
# Last updated: Fri May 16 2025
#
# Python implementation: CPython
# Python version       : 3.12.5
# IPython version      : 8.25.0
#
# pytensor: 2.23.0
#
# Compiler    : GCC 12.4.0
# OS          : Linux
# Release     : 5.14.0-427.42.1.el9_4.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 96
# Architecture: 64bit
#
# numpy     : 1.26.4
# bambi     : 0.14.0
# pandas    : 2.2.2
# sys       : 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:36:51) [GCC 12.4.0]
# matplotlib: 3.9.2
# arviz     : 0.19.0
#
# Watermark: 2.4.3

# %% [markdown]
# [top](#top)
