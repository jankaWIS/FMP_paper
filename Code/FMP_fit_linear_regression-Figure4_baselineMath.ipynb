# %% [markdown]
# ##### top

# %% [markdown]
# # FMP modelling for Figure 4 (Math)
#
# This notebook runs Bayesian models on Datasets 4 (dataset with Math condition) that is described in the article to assess interaction between perception and memory difficulty levels in the FMP. We fit the following formula to mean score within the condition. Throughout the notebook, I use `task` as a term for memory difficulty levels (M, UD, FD-e, FD-m), `difficulty` as a term for perceptual difficulty levels (1, 2, 3), and `userID` as a variable denoting individual participants. It is the exact same principle and code as the `FMP_fit_linear_regression-Figure4.ipynb` but it sets the FD-m (Math) as a reference level instead of UD.
#
#
# * Model task and difficulty interaction with user as a random effect. Equation:
#     * _correct_flt ~ task * difficulty + (1|userID)_
# * Model task and difficulty as main effects without interaction with user as a random effect. Equation:
#     * _correct_flt ~ task + difficulty + (1|userID)_
#
#
#
# We model mean accuracy per participant per condition.
#
#
# * [Models](#Models)
# * [Plot results](#Plot-results)
# * [Compare all data](#Compare-all-data)
# * [Save the inference](#Save-the-inference)

# %%
import os, sys
import pickle
from os.path import join as opj
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

az.style.use("arviz-darkgrid")
SEED = 7355608


# Importing module for functions
functions_modul =  "./functions"
sys.path.insert(0, functions_modul)

# import all processing and plotting functions
from bayesian_modelling_functions import fit_model, print_model

path_general = "../"
path_data = opj(path_general, "Data", "datasets")
path_inference_data = opj(path_general, "Data", "model_inference_data")


# set the numer of CPU
num_cpu = min(4, os.cpu_count()-1)
print(f'We will have {num_cpu} cores.\n')

path_dic = {
#     'dataset_1' : opj(path_data, 'FMP_dataset_1.csv'),
#     'dataset_2': opj(path_data, 'FMP_dataset_2.csv'),
#     'dataset_3': opj(path_data, 'FMP_dataset_3.csv'),
#     'concat_datasets_123': opj(path_data, 'FMP_concat_datasets_123.csv'),
    'dataset_4': opj(path_data, 'FMP_dataset_4.csv'),
}


# load all dataframes
df_dic = {}

# only selected cols
select_cols = ['stim1', 'stim2', 'target', 'RT', 'userID', 'difficulty', 'levels', 'task', 'correct_flt', 'order']


for f in path_dic.keys():   
    if f=="first_pilot":
        df_dic[f] = pd.read_csv(path_dic[f], usecols=(set(['correct_check'])|set(select_cols))-set(['correct_flt']))
        # convert boolean answers to floats to be able to do mean
        df_dic[f]['correct_flt'] = df_dic[f].correct_check.astype(float)
    elif 'longitudinal_' in f:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols+['target_loc', 'target_loc_simple'])
    else:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols)
    
    df_dic[f]["Experiment"] = f
        

    # clean
    df_dic[f].reset_index(drop=True, inplace=True)
    
    if 'Unnamed: 0' in df_dic[f].columns:
        df_dic[f].drop('Unnamed: 0', inplace=True, axis=1)
        
    
    # find low performing participants
    tt = df_dic[f].loc[df_dic[f]['task'].isin(['face matching', 'perc', 'perception'])].groupby(['userID', 'difficulty']).correct_flt.mean()

    drop_ptc = tt[tt<=0.5].reset_index().userID.values
    print(f'\nIn {f} dropping {len(drop_ptc)} participants for low accuracy in FM.')
    print(tt[tt<=0.5])

    # and remove them
    df_dic[f] = df_dic[f].loc[~df_dic[f]['userID'].isin(drop_ptc)]
    # clean up
    drop_ptc, tt = None, None
    
    print(f"\nThere is now N={df_dic[f]['userID'].unique().size} participants in {f}.")



#####
# rename the levels
rename_tasks_dic = {'perception':'Matching', 'perc':'Matching', 'blank':'Unfilled Delay', 'faces':'Filled Delay - emotions', 'math':'Filled Delay - math'}

# define orders
hue_order = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions']
hue_order_math = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - math']



# rename the memory task labels in the df
for f in df_dic.keys():
    if f=='noise':
        continue
    df_dic[f]['task'] = df_dic[f]['task'].map(rename_tasks_dic).fillna(df_dic[f]['task'])
# Out:
# We will have 4 cores.
#
#
# In dataset_4 dropping 0 participants for low accuracy in FM.
# Series([], Name: correct_flt, dtype: float64)
#
# There is now N=150 participants in dataset_4.

# %%
# select only specific datasets and prepare them
datasets2fit = ['dataset_4']

df_dic_fit = {}


for f in datasets2fit:
    data=None
    
    # groupby and make means for ptc and condition
    data = df_dic[f].groupby(['userID', 'task', 'difficulty'], observed=False).correct_flt.mean().reset_index()

    # convert all variables to categories
    # categorical_cols = data.columns[data.dtypes == object].tolist() + ['difficulty']
    categorical_cols = ['userID', 'task', 'difficulty']
    for col in categorical_cols:
        if col == 'task':
            # specify the order that we want
            data[col] = pd.Categorical(data[col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
            #['Unfilled Delay', 'Matching', 'Filled Delay - emotions']
            
            # also do it for the original datasets
            df_dic[f][col] = pd.Categorical(df_dic[f][col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
        else:
            data[col] = data[col].astype("category")
            df_dic[f][col] = df_dic[f][col].astype("category")

    # check
    print('\n',f)
    df_dic[f].info()
        
    # save
    df_dic_fit[f] = data.copy()

# # drop them for now
# data[data.correct_flt.isna()]
# Out:
#  dataset_4
# <class 'pandas.core.frame.DataFrame'>
# Index: 36000 entries, 0 to 35999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userID       36000 non-null  category
#  1   target       36000 non-null  object
#  2   stim1        36000 non-null  object
#  3   stim2        36000 non-null  object
#  4   correct_flt  35298 non-null  float64
#  5   RT           35298 non-null  float64
#  6   task         36000 non-null  category
#  7   order        36000 non-null  int64
#  8   difficulty   36000 non-null  category
#  9   levels       36000 non-null  int64
#  10  Experiment   36000 non-null  object
# dtypes: category(3), float64(2), int64(2), object(4)
# memory usage: 2.6+ MB

# %% [markdown]
# ## Model as means
# [top](#top)

# %%
model_assumptions = {
    "correct_flt ~ task * difficulty + (1|userID)": "Each user has their own baseline performance, but the effect of task and difficulty is assumed to be the same across all users.",
    "correct_flt ~ task + difficulty + (1|userID)": "Assumes that each user has their own baseline performance, but the effects of task and difficulty are consistent across all users without any interaction between task and difficulty.",
}

# define what we want to run
base_lvl = ['Filled Delay - math', 'Matching', 'Unfilled Delay', 'Filled Delay - emotions']
formulas2run = [
    "correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)",
    "correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)",
]

# %%
# define where we will store the results
model_dic_bernoulli = {}
result_dic_bernoulli = {}

for f in df_dic_fit.keys():
    print(f'\nFitting dataset {f}\n')
    # create datasets
    if f not in model_dic_bernoulli.keys():
        model_dic_bernoulli[f] = {}
    if f not in result_dic_bernoulli.keys():
        result_dic_bernoulli[f] = {}
    
    for formula in formulas2run:
        print(f'\nFitting formula {formula}\n')
    
        model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula] = fit_model(formula, df_dic_fit[f], categorical_cols, base_lvl=base_lvl,
                                                                                      num_cpu=num_cpu, check_priors=False, sample_priors=False)
# Out:
# Sampling 4 chains, 0 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:18
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 18 seconds.

# %%
model_dic_bernoulli[f][formulas2run[0]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.7247)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#             C(task, levels=base_lvl):difficulty ~ Normal(mu: [0. 0. 0. 0. 0. 0.], sigma: [1.3926 1.3926
#                 1.3926 1.3926 1.3926 1.3926])
#
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.7247))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
model_dic_bernoulli[f][formulas2run[1]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.6667)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.6667))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# ### check priors

# %%
model_dic_bernoulli[f][formulas2run[0]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), C(task, levels=base_lvl):difficulty, Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nMatching, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nMatching, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 2'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
model_dic_bernoulli[f][formulas2run[1]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>]], dtype=object)

# %% [markdown]
# ### check posterior

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[0]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[1]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %% [markdown]
# ---
# ## Plot results

# %% [markdown]
# ## FMP dataset 4 -- with Math condition
# [top](#top)

# %%
f = 'dataset_4'

print(f'Dataset: {f}')
for formula in formulas2run:
    print(f'\nFitting formula {formula}\n')
    print_model(model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula])
# Out:
# Dataset: dataset_4
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_100]  -0.161  0.029  -0.216   -0.108        0.0    0.000    5593.0
# 1|userID[s_1011] -0.011  0.031  -0.068    0.045        0.0    0.001    8203.0
# 1|userID[s_1015] -0.116  0.029  -0.173   -0.064        0.0    0.000    5859.0
# 1|userID[s_1016] -0.026  0.030  -0.081    0.032        0.0    0.000    7126.0
# 1|userID[s_1022] -0.081  0.031  -0.139   -0.022        0.0    0.000    6277.0
# 1|userID[s_1024]  0.035  0.031  -0.019    0.093        0.0    0.000    6970.0
# 1|userID[s_1032] -0.010  0.030  -0.064    0.051        0.0    0.001    7233.0
# 1|userID[s_107]   0.048  0.030  -0.011    0.103        0.0    0.000    6366.0
# 1|userID[s_108]   0.013  0.030  -0.043    0.068        0.0    0.000    6705.0
# 1|userID[s_1080] -0.123  0.031  -0.180   -0.066        0.0    0.000    6409.0
# 1|userID[s_1089]  0.069  0.031   0.010    0.125        0.0    0.000    6963.0
# 1|userID[s_1094] -0.048  0.031  -0.106    0.010        0.0    0.000    6511.0
# 1|userID[s_1103]  0.128  0.030   0.070    0.184        0.0    0.000    6812.0
# 1|userID[s_1110]  0.105  0.030   0.050    0.163        0.0    0.000    7547.0
# 1|userID[s_1112] -0.015  0.031  -0.069    0.044        0.0    0.000    7078.0
# 1|userID[s_1116]  0.025  0.030  -0.028    0.083        0.0    0.000    7437.0
# 1|userID[s_1126] -0.011  0.030  -0.068    0.046        0.0    0.000    5930.0
# 1|userID[s_1128] -0.045  0.030  -0.100    0.014        0.0    0.000    5898.0
# 1|userID[s_133]   0.027  0.030  -0.031    0.080        0.0    0.000    6862.0
# 1|userID[s_135]   0.072  0.030   0.017    0.129        0.0    0.000    7974.0
# 1|userID[s_157]  -0.060  0.032  -0.119   -0.001        0.0    0.000    7089.0
# 1|userID[s_160]  -0.091  0.031  -0.149   -0.035        0.0    0.000    7596.0
# 1|userID[s_166]  -0.041  0.030  -0.098    0.014        0.0    0.000    6969.0
# 1|userID[s_168]  -0.070  0.030  -0.125   -0.013        0.0    0.000    5415.0
# 1|userID[s_189]  -0.038  0.031  -0.096    0.020        0.0    0.000    6264.0
# 1|userID[s_190]  -0.147  0.030  -0.206   -0.095        0.0    0.000    6644.0
# 1|userID[s_205]   0.017  0.030  -0.039    0.072        0.0    0.000    6344.0
# 1|userID[s_23]   -0.007  0.030  -0.062    0.049        0.0    0.001    6954.0
# 1|userID[s_263]   0.037  0.030  -0.015    0.095        0.0    0.000    6560.0
# 1|userID[s_265]   0.002  0.029  -0.056    0.054        0.0    0.001    5740.0
#
#                   ess_tail  r_hat
# 1|userID[s_100]     2995.0    1.0
# 1|userID[s_1011]    2855.0    1.0
# 1|userID[s_1015]    2943.0    1.0
# 1|userID[s_1016]    2537.0    1.0
# 1|userID[s_1022]    2145.0    1.0
# 1|userID[s_1024]    2898.0    1.0
# 1|userID[s_1032]    2709.0    1.0
# 1|userID[s_107]     2338.0    1.0
# 1|userID[s_108]     2942.0    1.0
# 1|userID[s_1080]    3158.0    1.0
# 1|userID[s_1089]    2533.0    1.0
# 1|userID[s_1094]    2919.0    1.0
# 1|userID[s_1103]    2764.0    1.0
# 1|userID[s_1110]    2587.0    1.0
# 1|userID[s_1112]    2892.0    1.0
# 1|userID[s_1116]    2822.0    1.0
# 1|userID[s_1126]    2770.0    1.0
# 1|userID[s_1128]    2585.0    1.0
# 1|userID[s_133]     2855.0    1.0
# 1|userID[s_135]     2402.0    1.0
# 1|userID[s_157]     2697.0    1.0
# 1|userID[s_160]     2492.0    1.0
# 1|userID[s_166]     2878.0    1.0
# 1|userID[s_168]     2908.0    1.0
# 1|userID[s_189]     2813.0    1.0
# 1|userID[s_190]     3040.0    1.0
# 1|userID[s_205]     2913.0    1.0
# 1|userID[s_23]      2918.0    1.0
# 1|userID[s_263]     3000.0    1.0
# 1|userID[s_265]     2855.0    1.0
# ...
#
#                                                      mean     sd  hdi_3%  \
# 1|userID[s_882]                                     0.080  0.030   0.026
# 1|userID[s_923]                                    -0.080  0.030  -0.140
# 1|userID[s_93]                                      0.084  0.031   0.026
# 1|userID[s_931]                                    -0.004  0.030  -0.058
# 1|userID[s_936]                                     0.082  0.030   0.026
# 1|userID[s_937]                                     0.111  0.030   0.055
# 1|userID[s_939]                                    -0.110  0.029  -0.163
# 1|userID[s_940]                                     0.011  0.029  -0.042
# 1|userID[s_945]                                     0.067  0.029   0.014
# 1|userID[s_958]                                    -0.119  0.031  -0.177
# 1|userID[s_960]                                    -0.083  0.030  -0.138
# 1|userID[s_966]                                    -0.061  0.031  -0.121
# 1|userID[s_975]                                     0.039  0.031  -0.017
# 1|userID[s_976]                                     0.113  0.030   0.056
# 1|userID[s_993]                                     0.012  0.031  -0.045
# 1|userID[s_996]                                     0.041  0.031  -0.015
# 1|userID_sigma                                      0.084  0.006   0.073
# C(task, levels=base_lvl)[Matching]                  0.107  0.012   0.084
# C(task, levels=base_lvl)[Unfilled Delay]            0.010  0.012  -0.014
# C(task, levels=base_lvl)[Filled Delay - emotions]  -0.084  0.013  -0.107
# C(task, levels=base_lvl):difficulty[Matching, 2]   -0.009  0.017  -0.040
# C(task, levels=base_lvl):difficulty[Matching, 3]   -0.018  0.017  -0.049
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.002  0.017  -0.035
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.021  0.017  -0.054
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.014  0.017  -0.019
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.018  0.018  -0.016
# Intercept                                           0.785  0.011   0.765
# difficulty[2]                                      -0.026  0.012  -0.048
# difficulty[3]                                      -0.077  0.012  -0.100
# sigma                                               0.110  0.002   0.106
#
#                                                     hdi_97%  mcse_mean  \
# 1|userID[s_882]                                       0.138        0.0
# 1|userID[s_923]                                      -0.025        0.0
# 1|userID[s_93]                                        0.141        0.0
# 1|userID[s_931]                                       0.053        0.0
# 1|userID[s_936]                                       0.137        0.0
# 1|userID[s_937]                                       0.166        0.0
# 1|userID[s_939]                                      -0.053        0.0
# 1|userID[s_940]                                       0.067        0.0
# 1|userID[s_945]                                       0.123        0.0
# 1|userID[s_958]                                      -0.063        0.0
# 1|userID[s_960]                                      -0.026        0.0
# 1|userID[s_966]                                      -0.005        0.0
# 1|userID[s_975]                                       0.100        0.0
# 1|userID[s_976]                                       0.168        0.0
# 1|userID[s_993]                                       0.069        0.0
# 1|userID[s_996]                                       0.100        0.0
# 1|userID_sigma                                        0.094        0.0
# C(task, levels=base_lvl)[Matching]                    0.130        0.0
# C(task, levels=base_lvl)[Unfilled Delay]              0.032        0.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    -0.060        0.0
# C(task, levels=base_lvl):difficulty[Matching, 2]      0.025        0.0
# C(task, levels=base_lvl):difficulty[Matching, 3]      0.017        0.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.029        0.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.011        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.045        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.050        0.0
# Intercept                                             0.806        0.0
# difficulty[2]                                        -0.002        0.0
# difficulty[3]                                        -0.055        0.0
# sigma                                                 0.113        0.0
#
#                                                     mcse_sd  ess_bulk  \
# 1|userID[s_882]                                       0.000    5654.0
# 1|userID[s_923]                                       0.000    6685.0
# 1|userID[s_93]                                        0.000    7145.0
# 1|userID[s_931]                                       0.001    5822.0
# 1|userID[s_936]                                       0.000    7021.0
# 1|userID[s_937]                                       0.000    6082.0
# 1|userID[s_939]                                       0.000    6641.0
# 1|userID[s_940]                                       0.000    6324.0
# 1|userID[s_945]                                       0.000    7007.0
# 1|userID[s_958]                                       0.000    7155.0
# 1|userID[s_960]                                       0.000    6482.0
# 1|userID[s_966]                                       0.000    7159.0
# 1|userID[s_975]                                       0.000    6366.0
# 1|userID[s_976]                                       0.000    6124.0
# 1|userID[s_993]                                       0.001    6853.0
# 1|userID[s_996]                                       0.000    6973.0
# 1|userID_sigma                                        0.000    1369.0
# C(task, levels=base_lvl)[Matching]                    0.000    2538.0
# C(task, levels=base_lvl)[Unfilled Delay]              0.000    2405.0
# C(task, levels=base_lvl)[Filled Delay - emotions]     0.000    2326.0
# C(task, levels=base_lvl):difficulty[Matching, 2]      0.000    2418.0
# C(task, levels=base_lvl):difficulty[Matching, 3]      0.000    2626.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.000    2327.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.000    2536.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2611.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2446.0
# Intercept                                             0.000    1404.0
# difficulty[2]                                         0.000    2126.0
# difficulty[3]                                         0.000    2038.0
# sigma                                                 0.000    6987.0
#
#                                                     ess_tail  r_hat
# 1|userID[s_882]                                       2602.0   1.00
# 1|userID[s_923]                                       2896.0   1.00
# 1|userID[s_93]                                        2447.0   1.00
# 1|userID[s_931]                                       2837.0   1.00
# 1|userID[s_936]                                       2933.0   1.00
# 1|userID[s_937]                                       2777.0   1.00
# 1|userID[s_939]                                       2980.0   1.00
# 1|userID[s_940]                                       2507.0   1.00
# 1|userID[s_945]                                       2849.0   1.00
# 1|userID[s_958]                                       2627.0   1.00
# 1|userID[s_960]                                       2527.0   1.00
# 1|userID[s_966]                                       2499.0   1.00
# 1|userID[s_975]                                       2266.0   1.00
# 1|userID[s_976]                                       2579.0   1.00
# 1|userID[s_993]                                       2832.0   1.00
# 1|userID[s_996]                                       2781.0   1.00
# 1|userID_sigma                                        2305.0   1.00
# C(task, levels=base_lvl)[Matching]                    2521.0   1.00
# C(task, levels=base_lvl)[Unfilled Delay]              3138.0   1.00
# C(task, levels=base_lvl)[Filled Delay - emotions]     3144.0   1.00
# C(task, levels=base_lvl):difficulty[Matching, 2]      2781.0   1.00
# C(task, levels=base_lvl):difficulty[Matching, 3]      2862.0   1.00
# C(task, levels=base_lvl):difficulty[Unfilled De...    2937.0   1.00
# C(task, levels=base_lvl):difficulty[Unfilled De...    2797.0   1.00
# C(task, levels=base_lvl):difficulty[Filled Dela...    2952.0   1.00
# C(task, levels=base_lvl):difficulty[Filled Dela...    2873.0   1.00
# Intercept                                             1951.0   1.01
# difficulty[2]                                         2727.0   1.00
# difficulty[3]                                         2947.0   1.00
# sigma                                                 2668.0   1.00
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_100]  -0.162  0.030  -0.216   -0.104        0.0    0.000    5970.0
# 1|userID[s_1011] -0.012  0.030  -0.072    0.042        0.0    0.000    6833.0
# 1|userID[s_1015] -0.116  0.031  -0.172   -0.058        0.0    0.000    6173.0
# 1|userID[s_1016] -0.027  0.030  -0.082    0.029        0.0    0.000    7253.0
# 1|userID[s_1022] -0.081  0.031  -0.139   -0.026        0.0    0.000    5920.0
# 1|userID[s_1024]  0.035  0.030  -0.018    0.095        0.0    0.000    6931.0
# 1|userID[s_1032] -0.010  0.030  -0.069    0.043        0.0    0.001    6003.0
# 1|userID[s_107]   0.047  0.030  -0.006    0.107        0.0    0.000    6164.0
# 1|userID[s_108]   0.013  0.030  -0.041    0.070        0.0    0.000    6156.0
# 1|userID[s_1080] -0.123  0.030  -0.179   -0.064        0.0    0.000    5974.0
# 1|userID[s_1089]  0.069  0.030   0.017    0.128        0.0    0.000    6366.0
# 1|userID[s_1094] -0.049  0.030  -0.104    0.008        0.0    0.000    6469.0
# 1|userID[s_1103]  0.128  0.030   0.070    0.185        0.0    0.000    6436.0
# 1|userID[s_1110]  0.105  0.030   0.047    0.159        0.0    0.000    6959.0
# 1|userID[s_1112] -0.016  0.031  -0.075    0.040        0.0    0.000    7368.0
# 1|userID[s_1116]  0.025  0.030  -0.034    0.079        0.0    0.000    5747.0
# 1|userID[s_1126] -0.011  0.030  -0.066    0.043        0.0    0.000    4795.0
# 1|userID[s_1128] -0.045  0.031  -0.105    0.009        0.0    0.000    7585.0
# 1|userID[s_133]   0.027  0.030  -0.032    0.080        0.0    0.000    6600.0
# 1|userID[s_135]   0.072  0.031   0.016    0.131        0.0    0.000    6968.0
# 1|userID[s_157]  -0.060  0.029  -0.118   -0.006        0.0    0.000    5949.0
# 1|userID[s_160]  -0.091  0.029  -0.145   -0.038        0.0    0.000    6937.0
# 1|userID[s_166]  -0.041  0.029  -0.097    0.012        0.0    0.000    6414.0
# 1|userID[s_168]  -0.070  0.030  -0.125   -0.012        0.0    0.000    6501.0
# 1|userID[s_189]  -0.037  0.031  -0.094    0.023        0.0    0.000    6164.0
# 1|userID[s_190]  -0.148  0.030  -0.204   -0.093        0.0    0.000    5423.0
# 1|userID[s_205]   0.016  0.031  -0.042    0.074        0.0    0.000    7028.0
# 1|userID[s_23]   -0.007  0.030  -0.062    0.052        0.0    0.001    7191.0
# 1|userID[s_263]   0.037  0.029  -0.017    0.094        0.0    0.000    5977.0
# 1|userID[s_265]   0.002  0.030  -0.056    0.057        0.0    0.001    5598.0
#
#                   ess_tail  r_hat
# 1|userID[s_100]     2839.0   1.00
# 1|userID[s_1011]    3059.0   1.00
# 1|userID[s_1015]    2680.0   1.01
# 1|userID[s_1016]    3049.0   1.00
# 1|userID[s_1022]    2813.0   1.00
# 1|userID[s_1024]    2504.0   1.00
# 1|userID[s_1032]    2439.0   1.00
# 1|userID[s_107]     2767.0   1.00
# 1|userID[s_108]     2807.0   1.00
# 1|userID[s_1080]    2941.0   1.00
# 1|userID[s_1089]    2890.0   1.00
# 1|userID[s_1094]    2808.0   1.00
# 1|userID[s_1103]    2615.0   1.00
# 1|userID[s_1110]    2963.0   1.00
# 1|userID[s_1112]    2783.0   1.00
# 1|userID[s_1116]    2807.0   1.00
# 1|userID[s_1126]    2892.0   1.00
# 1|userID[s_1128]    3122.0   1.00
# 1|userID[s_133]     2953.0   1.00
# 1|userID[s_135]     2760.0   1.00
# 1|userID[s_157]     2564.0   1.00
# 1|userID[s_160]     3174.0   1.00
# 1|userID[s_166]     2728.0   1.00
# 1|userID[s_168]     3030.0   1.00
# 1|userID[s_189]     2860.0   1.00
# 1|userID[s_190]     2765.0   1.00
# 1|userID[s_205]     2653.0   1.00
# 1|userID[s_23]      2501.0   1.00
# 1|userID[s_263]     2787.0   1.00
# 1|userID[s_265]     2567.0   1.00
# ...
#
#                                                     mean     sd  hdi_3%  \
# 1|userID[s_858]                                    0.006  0.030  -0.052
# 1|userID[s_860]                                   -0.048  0.030  -0.104
# 1|userID[s_865]                                   -0.084  0.030  -0.139
# 1|userID[s_870]                                   -0.008  0.030  -0.062
# 1|userID[s_874]                                    0.007  0.031  -0.051
# 1|userID[s_875]                                    0.073  0.030   0.018
# 1|userID[s_882]                                    0.080  0.031   0.024
# 1|userID[s_923]                                   -0.081  0.030  -0.138
# 1|userID[s_93]                                     0.084  0.031   0.022
# 1|userID[s_931]                                   -0.004  0.029  -0.056
# 1|userID[s_936]                                    0.082  0.030   0.025
# 1|userID[s_937]                                    0.112  0.030   0.057
# 1|userID[s_939]                                   -0.111  0.030  -0.167
# 1|userID[s_940]                                    0.011  0.029  -0.045
# 1|userID[s_945]                                    0.067  0.031   0.010
# 1|userID[s_958]                                   -0.119  0.030  -0.176
# 1|userID[s_960]                                   -0.083  0.030  -0.141
# 1|userID[s_966]                                   -0.061  0.030  -0.116
# 1|userID[s_975]                                    0.039  0.030  -0.014
# 1|userID[s_976]                                    0.112  0.030   0.056
# 1|userID[s_993]                                    0.011  0.030  -0.048
# 1|userID[s_996]                                    0.041  0.030  -0.018
# 1|userID_sigma                                     0.084  0.005   0.074
# C(task, levels=base_lvl)[Matching]                 0.098  0.007   0.085
# C(task, levels=base_lvl)[Unfilled Delay]           0.002  0.007  -0.012
# C(task, levels=base_lvl)[Filled Delay - emotions] -0.074  0.007  -0.087
# Intercept                                          0.787  0.009   0.769
# difficulty[2]                                     -0.025  0.007  -0.038
# difficulty[3]                                     -0.082  0.007  -0.094
# sigma                                              0.110  0.002   0.106
#
#                                                    hdi_97%  mcse_mean  \
# 1|userID[s_858]                                      0.062        0.0
# 1|userID[s_860]                                      0.009        0.0
# 1|userID[s_865]                                     -0.026        0.0
# 1|userID[s_870]                                      0.050        0.0
# 1|userID[s_874]                                      0.062        0.0
# 1|userID[s_875]                                      0.130        0.0
# 1|userID[s_882]                                      0.138        0.0
# 1|userID[s_923]                                     -0.025        0.0
# 1|userID[s_93]                                       0.140        0.0
# 1|userID[s_931]                                      0.055        0.0
# 1|userID[s_936]                                      0.138        0.0
# 1|userID[s_937]                                      0.170        0.0
# 1|userID[s_939]                                     -0.054        0.0
# 1|userID[s_940]                                      0.065        0.0
# 1|userID[s_945]                                      0.126        0.0
# 1|userID[s_958]                                     -0.063        0.0
# 1|userID[s_960]                                     -0.029        0.0
# 1|userID[s_966]                                     -0.004        0.0
# 1|userID[s_975]                                      0.100        0.0
# 1|userID[s_976]                                      0.168        0.0
# 1|userID[s_993]                                      0.064        0.0
# 1|userID[s_996]                                      0.096        0.0
# 1|userID_sigma                                       0.094        0.0
# C(task, levels=base_lvl)[Matching]                   0.112        0.0
# C(task, levels=base_lvl)[Unfilled Delay]             0.015        0.0
# C(task, levels=base_lvl)[Filled Delay - emotions]   -0.059        0.0
# Intercept                                            0.804        0.0
# difficulty[2]                                       -0.013        0.0
# difficulty[3]                                       -0.070        0.0
# sigma                                                0.113        0.0
#
#                                                    mcse_sd  ess_bulk  \
# 1|userID[s_858]                                      0.001    6498.0
# 1|userID[s_860]                                      0.000    6831.0
# 1|userID[s_865]                                      0.000    6281.0
# 1|userID[s_870]                                      0.001    5735.0
# 1|userID[s_874]                                      0.001    5966.0
# 1|userID[s_875]                                      0.000    7490.0
# 1|userID[s_882]                                      0.000    6407.0
# 1|userID[s_923]                                      0.000    6941.0
# 1|userID[s_93]                                       0.000    6023.0
# 1|userID[s_931]                                      0.000    6080.0
# 1|userID[s_936]                                      0.000    6740.0
# 1|userID[s_937]                                      0.000    6150.0
# 1|userID[s_939]                                      0.000    5801.0
# 1|userID[s_940]                                      0.000    7051.0
# 1|userID[s_945]                                      0.000    6845.0
# 1|userID[s_958]                                      0.000    5537.0
# 1|userID[s_960]                                      0.000    5676.0
# 1|userID[s_966]                                      0.000    5770.0
# 1|userID[s_975]                                      0.000    6737.0
# 1|userID[s_976]                                      0.000    6065.0
# 1|userID[s_993]                                      0.000    7080.0
# 1|userID[s_996]                                      0.000    6707.0
# 1|userID_sigma                                       0.000    1355.0
# C(task, levels=base_lvl)[Matching]                   0.000    5946.0
# C(task, levels=base_lvl)[Unfilled Delay]             0.000    6262.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    0.000    5899.0
# Intercept                                            0.000    1687.0
# difficulty[2]                                        0.000    7504.0
# difficulty[3]                                        0.000    7586.0
# sigma                                                0.000    7076.0
#
#                                                    ess_tail  r_hat
# 1|userID[s_858]                                      2495.0    1.0
# 1|userID[s_860]                                      2859.0    1.0
# 1|userID[s_865]                                      2586.0    1.0
# 1|userID[s_870]                                      2548.0    1.0
# 1|userID[s_874]                                      2619.0    1.0
# 1|userID[s_875]                                      2741.0    1.0
# 1|userID[s_882]                                      2794.0    1.0
# 1|userID[s_923]                                      2617.0    1.0
# 1|userID[s_93]                                       3208.0    1.0
# 1|userID[s_931]                                      2957.0    1.0
# 1|userID[s_936]                                      2816.0    1.0
# 1|userID[s_937]                                      2954.0    1.0
# 1|userID[s_939]                                      2530.0    1.0
# 1|userID[s_940]                                      3009.0    1.0
# 1|userID[s_945]                                      2669.0    1.0
# 1|userID[s_958]                                      2491.0    1.0
# 1|userID[s_960]                                      3026.0    1.0
# 1|userID[s_966]                                      2797.0    1.0
# 1|userID[s_975]                                      2641.0    1.0
# 1|userID[s_976]                                      2864.0    1.0
# 1|userID[s_993]                                      2933.0    1.0
# 1|userID[s_996]                                      2848.0    1.0
# 1|userID_sigma                                       2086.0    1.0
# C(task, levels=base_lvl)[Matching]                   3035.0    1.0
# C(task, levels=base_lvl)[Unfilled Delay]             3086.0    1.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    3395.0    1.0
# Intercept                                            2233.0    1.0
# difficulty[2]                                        3255.0    1.0
# difficulty[3]                                        3356.0    1.0
# sigma                                                3454.0    1.0

# %% [markdown]
# ### Compare all data
# [top](#top)

# %%
df_compare_formulas_bernoulli = {}
for f in result_dic_bernoulli.keys():
    print(f, '\n')
    df_compare_formulas_bernoulli[f] = az.compare(result_dic_bernoulli[f])
    
    print(df_compare_formulas_bernoulli[f])
    
    az.plot_compare(df_compare_formulas_bernoulli[f], insample_dev=False);

    
    print()
# df_compare_formulas_bernoulli[f]
# Out:
# dataset_4
#
#                                                     rank     elpd_loo  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...     0  1355.481445
# correct_flt ~ C(task, levels=base_lvl) * diffic...     1  1351.651125
#
#                                                          p_loo  elpd_diff  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  132.204321    0.00000
# correct_flt ~ C(task, levels=base_lvl) * diffic...  138.574443    3.83032
#
#                                                     weight         se  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...     1.0  30.582265
# correct_flt ~ C(task, levels=base_lvl) * diffic...     0.0  30.864983
#
#                                                          dse  warning scale
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.000000    False   log
# correct_flt ~ C(task, levels=base_lvl) * diffic...  2.678487    False   log

# %%
fig, ax = plt.subplots(figsize=(8, 4))
az.plot_forest(
    result_dic_bernoulli['dataset_4']['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'],
#     model_names=['Dataset 4'],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
az.plot_forest(
    list(result_dic_bernoulli['dataset_4'].values()),
    model_names=[f'{f}\n{formula}' for f in result_dic_bernoulli.keys() for formula in formulas2run],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.69, .42), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
az.plot_forest(
    (list(result_dic_bernoulli['dataset_4'].values())
    )[::2],
#     model_names=[f'{f}' for f in result_dic_bernoulli.keys()],
    var_names=["C(task, levels=base_lvl):difficulty"],
    combined=True,
#     figsize=(12, 10)
    ax=ax
);

ax.axvline(0, c='k')

# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
# # plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
# plt.show()


# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.6, 1))
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %% [markdown]
# ### Run some predictions
# [top](#top)

# %%
interactions = ['Matching, 2', 'Matching, 3', 'Unfilled Delay, 2', 'Unfilled Delay, 3', 'Filled Delay - emotions, 2', 'Filled Delay - emotions, 3']
fm2, fm3, d2, d3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]

# %%
_, ax = plt.subplots()
for idx, x in enumerate([fm2, fm3, d2, d3, i2, i3]):
    az.plot_dist(x, label=x["C(task, levels=base_lvl):difficulty_dim"].item(), plot_kwargs={"color": f"C{idx}"}, ax=ax)
ax.legend(loc="upper left");

# %%
# Probability that the FM slope is less than 0

print(f"""
Probability that the UD slope is less than 0:
level 2: {(d2 < 0).mean().item()}
level 3: {(d3 < 0).mean().item()}
""")
# Out:
# Probability that the UD slope is less than 0:
# level 2: 0.5365
# level 3: 0.887

# %% [markdown]
# ---

# %%
for f in result_dic_bernoulli.keys():

    fm2, fm3, d2, d3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]
    print(f"""
Experiment {f}:    
  Probability that the Matching slope is less than 0:
    level 2: {(fm2 < 0).mean().item()}
    level 3: {(fm3 < 0).mean().item()}

  Probability that the UD slope is less than 0:
    level 2: {(d2 < 0).mean().item()}
    level 3: {(d3 < 0).mean().item()}
    
  Probability that the FD-e slope is less than 0:
    level 2: {(i2 < 0).mean().item()}
    level 3: {(i3 < 0).mean().item()}
    
    """)
# Out:
# Experiment dataset_4:
#   Probability that the Matching slope is less than 0:
#     level 2: 0.70475
#     level 3: 0.84275
#
#   Probability that the UD slope is less than 0:
#     level 2: 0.5365
#     level 3: 0.887
#
#   Probability that the FD-e slope is less than 0:
#     level 2: 0.204
#     level 3: 0.156

# %% [markdown]
# ### Save the inference
# [top](#top)
#
# It could be possible to use this:
# ```
# result_dic_bernoulli['dataset_4']['correct_flt ~ task * difficulty + (1|userID)'].to_netcdf()
# ```
#
# but it doesn't preserve the dictionary, so I use pickle.

# %%
# save the dictionary to a pickle file
with open(opj(path_inference_data,'FMP_math_baselineMath_inference_data_dict.pkl'), 'wb') as f:
    pickle.dump(result_dic_bernoulli['dataset_4'], f)

# %%
# # Load the dictionary from the pickle file
# with open(opj(path_inference_data,'FMP_math_baselineMath_inference_data_dict.pkl'), 'rb') as f:
#     loaded_inference_data_dict = pickle.load(f)

# %%
# %load_ext watermark

# %watermark -a 'Jan Kadlec' -nmvu -iv -iv -w -p pytensor
# Out:
# Author: Jan Kadlec
#
# Last updated: Wed Feb 05 2025
#
# Python implementation: CPython
# Python version       : 3.12.5
# IPython version      : 8.25.0
#
# pytensor: 2.23.0
#
# Compiler    : GCC 12.4.0
# OS          : Linux
# Release     : 5.14.0-427.42.1.el9_4.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 96
# Architecture: 64bit
#
# sys       : 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:36:51) [GCC 12.4.0]
# bambi     : 0.14.0
# arviz     : 0.19.0
# matplotlib: 3.9.2
# numpy     : 1.26.4
# pandas    : 2.2.2
#
# Watermark: 2.4.3

# %% [markdown]
# [top](#top)
