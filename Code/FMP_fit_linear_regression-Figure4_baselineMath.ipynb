# %% [markdown]
# ##### top

# %% [markdown]
# # FMP modelling for Figure 4 (Math)
#
# This notebook runs Bayesian models on Datasets 4 (dataset with Math condition) that is described in the article to assess interaction between perception and memory difficulty levels in the FMP. We fit the following formula to mean score within the condition. Throughout the notebook, I use `task` as a term for memory difficulty levels (M, UD, FD-e, FD-m), `difficulty` as a term for perceptual difficulty levels (1, 2, 3), and `userID` as a variable denoting individual participants. It is the exact same principle and code as the `FMP_fit_linear_regression-Figure4.ipynb` but it sets the FD-m (Math) as a reference level instead of UD.
#
#
# * Model task and difficulty interaction with user as a random effect. Equation:
#     * _correct_flt ~ task * difficulty + (1|userID)_
# * Model task and difficulty as main effects without interaction with user as a random effect. Equation:
#     * _correct_flt ~ task + difficulty + (1|userID)_
#
#
#
# We model mean accuracy per participant per condition.
#
#
# * [Models](#Models)
# * [Plot results](#Plot-results)
# * [Compare all data](#Compare-all-data)
# * [Save the inference](#Save-the-inference)

# %%
import os, sys
import pickle
from os.path import join as opj
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

az.style.use("arviz-darkgrid")
SEED = 7355608


# Importing module for functions
functions_modul =  "./functions"
sys.path.insert(0, functions_modul)

# import all processing and plotting functions
from bayesian_modelling_functions import fit_model, print_model

path_general = "../"
path_data = opj(path_general, "Data", "datasets")
path_inference_data = opj(path_general, "Data", "model_inference_data")


# set the numer of CPU
num_cpu = min(4, os.cpu_count()-1)
print(f'We will have {num_cpu} cores.\n')

path_dic = {
#     'dataset_1' : opj(path_data, 'FMP_dataset_1.csv'),
#     'dataset_2': opj(path_data, 'FMP_dataset_2.csv'),
#     'dataset_3': opj(path_data, 'FMP_dataset_3.csv'),
#     'concat_datasets_123': opj(path_data, 'FMP_concat_datasets_123.csv'),
    'dataset_4': opj(path_data, 'FMP_dataset_4.csv'),
}


# load all dataframes
df_dic = {}

# only selected cols
select_cols = ['stim1', 'stim2', 'target', 'RT', 'userID', 'difficulty', 'levels', 'task', 'correct_flt', 'order']


for f in path_dic.keys():   
    if f=="first_pilot":
        df_dic[f] = pd.read_csv(path_dic[f], usecols=(set(['correct_check'])|set(select_cols))-set(['correct_flt']))
        # convert boolean answers to floats to be able to do mean
        df_dic[f]['correct_flt'] = df_dic[f].correct_check.astype(float)
    elif 'longitudinal_' in f:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols+['target_loc', 'target_loc_simple'])
    else:
        df_dic[f] = pd.read_csv(path_dic[f], usecols=select_cols)
    
    df_dic[f]["Experiment"] = f
        

    # clean
    df_dic[f].reset_index(drop=True, inplace=True)
    
    if 'Unnamed: 0' in df_dic[f].columns:
        df_dic[f].drop('Unnamed: 0', inplace=True, axis=1)
        
    
    # find low performing participants
    tt = df_dic[f].loc[df_dic[f]['task'].isin(['face matching', 'perc', 'perception'])].groupby(['userID', 'difficulty']).correct_flt.mean()

    drop_ptc = tt[tt<=0.5].reset_index().userID.values
    print(f'\nIn {f} dropping {len(drop_ptc)} participants for low accuracy in FM.')
    print(tt[tt<=0.5])

    # and remove them
    df_dic[f] = df_dic[f].loc[~df_dic[f]['userID'].isin(drop_ptc)]
    # clean up
    drop_ptc, tt = None, None
    
    print(f"\nThere is now N={df_dic[f]['userID'].unique().size} participants in {f}.")



#####
# rename the levels
rename_tasks_dic = {'perception':'Matching', 'perc':'Matching', 'blank':'Unfilled Delay', 'faces':'Filled Delay - emotions', 'math':'Filled Delay - math'}

# define orders
hue_order = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions']
hue_order_math = ['Matching', 'Unfilled Delay', 'Filled Delay - emotions', 'Filled Delay - math']



# rename the memory task labels in the df
for f in df_dic.keys():
    if f=='noise':
        continue
    df_dic[f]['task'] = df_dic[f]['task'].map(rename_tasks_dic).fillna(df_dic[f]['task'])
# Out:
# We will have 4 cores.
#
#
# In dataset_4 dropping 0 participants for low accuracy in FM.
# Series([], Name: correct_flt, dtype: float64)
#
# There is now N=150 participants in dataset_4.

# %%
# select only specific datasets and prepare them
datasets2fit = ['dataset_4']

df_dic_fit = {}


for f in datasets2fit:
    data=None
    
    # groupby and make means for ptc and condition
    data = df_dic[f].groupby(['userID', 'task', 'difficulty'], observed=False).correct_flt.mean().reset_index()

    # convert all variables to categories
    # categorical_cols = data.columns[data.dtypes == object].tolist() + ['difficulty']
    categorical_cols = ['userID', 'task', 'difficulty']
    for col in categorical_cols:
        if col == 'task':
            # specify the order that we want
            data[col] = pd.Categorical(data[col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
            #['Unfilled Delay', 'Matching', 'Filled Delay - emotions']
            
            # also do it for the original datasets
            df_dic[f][col] = pd.Categorical(df_dic[f][col], categories=['Unfilled Delay', 'Matching', 'Filled Delay - emotions', 'Filled Delay - math'], ordered=True)
        else:
            data[col] = data[col].astype("category")
            df_dic[f][col] = df_dic[f][col].astype("category")

    # check
    print('\n',f)
    df_dic[f].info()
        
    # save
    df_dic_fit[f] = data.copy()

# # drop them for now
# data[data.correct_flt.isna()]
# Out:
#  dataset_4
# <class 'pandas.core.frame.DataFrame'>
# Index: 36000 entries, 0 to 35999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userID       36000 non-null  category
#  1   target       36000 non-null  object
#  2   stim1        36000 non-null  object
#  3   stim2        36000 non-null  object
#  4   correct_flt  35298 non-null  float64
#  5   RT           35298 non-null  float64
#  6   task         36000 non-null  category
#  7   order        36000 non-null  int64
#  8   difficulty   36000 non-null  category
#  9   levels       36000 non-null  int64
#  10  Experiment   36000 non-null  object
# dtypes: category(3), float64(2), int64(2), object(4)
# memory usage: 2.6+ MB

# %% [markdown]
# ## Model as means
# [top](#top)

# %%
model_assumptions = {
    "correct_flt ~ task * difficulty + (1|userID)": "Each user has their own baseline performance, but the effect of task and difficulty is assumed to be the same across all users.",
    "correct_flt ~ task + difficulty + (1|userID)": "Assumes that each user has their own baseline performance, but the effects of task and difficulty are consistent across all users without any interaction between task and difficulty.",
}

# define what we want to run
base_lvl = ['Filled Delay - math', 'Matching', 'Unfilled Delay', 'Filled Delay - emotions']
formulas2run = [
    "correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)",
    "correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)",
]

# %%
# define where we will store the results
model_dic_bernoulli = {}
result_dic_bernoulli = {}

for f in df_dic_fit.keys():
    print(f'\nFitting dataset {f}\n')
    # create datasets
    if f not in model_dic_bernoulli.keys():
        model_dic_bernoulli[f] = {}
    if f not in result_dic_bernoulli.keys():
        result_dic_bernoulli[f] = {}
    
    for formula in formulas2run:
        print(f'\nFitting formula {formula}\n')
    
        model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula] = fit_model(formula, df_dic_fit[f], categorical_cols, base_lvl=base_lvl,
                                                                                      num_cpu=num_cpu, check_priors=False, sample_priors=False)
# Out:
# Sampling 4 chains, 0 divergences ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 / 0:00:28
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 28 seconds.

# %%
model_dic_bernoulli[f][formulas2run[0]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.7247)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#             C(task, levels=base_lvl):difficulty ~ Normal(mu: [0. 0. 0. 0. 0. 0.], sigma: [1.3926 1.3926
#                 1.3926 1.3926 1.3926 1.3926])
#
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.7247))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
model_dic_bernoulli[f][formulas2run[1]]
# Out:
#        Formula: correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#         Family: gaussian
#           Link: mu = identity
#   Observations: 1800
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 0.7579, sigma: 0.6667)
#             C(task, levels=base_lvl) ~ Normal(mu: [0. 0. 0.], sigma: [0.8889 0.8889 0.8889])
#             difficulty ~ Normal(mu: [0. 0.], sigma: [0.8165 0.8165])
#
#         Group-level effects
#             1|userID ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 0.6667))
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 0.154)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# ### check priors

# %%
model_dic_bernoulli[f][formulas2run[0]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), C(task, levels=base_lvl):difficulty, Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nMatching, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nMatching, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 2'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nUnfilled Delay, 3'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 2'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl):difficulty\nFilled Delay - emotions, 3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
model_dic_bernoulli[f][formulas2run[1]].plot_priors()
# Out:
# Sampling: [1|userID_sigma, C(task, levels=base_lvl), Intercept, difficulty, sigma]
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>,
#         <Axes: title={'center': '1|userID_sigma'}>]], dtype=object)

# %% [markdown]
# ### check posterior

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[0]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %%
az.plot_posterior(result_dic_bernoulli[f][formulas2run[1]], 
                  var_names=['Intercept', 'difficulty', 'C(task, levels=base_lvl)'],#, 'task:difficulty'],
                  hdi_prob=.94)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'difficulty\n2'}>,
#         <Axes: title={'center': 'difficulty\n3'}>],
#        [<Axes: title={'center': 'C(task, levels=base_lvl)\nMatching'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nUnfilled Delay'}>,
#         <Axes: title={'center': 'C(task, levels=base_lvl)\nFilled Delay - emotions'}>]],
#       dtype=object)

# %% [markdown]
# ---
# ## Plot results

# %% [markdown]
# ## FMP dataset 4 -- with Math condition
# [top](#top)

# %%
f = 'dataset_4'

print(f'Dataset: {f}')
for formula in formulas2run:
    print(f'\nFitting formula {formula}\n')
    print_model(model_dic_bernoulli[f][formula], result_dic_bernoulli[f][formula])
# Out:
# Dataset: dataset_4
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1010] -0.052  0.030  -0.106    0.004        0.0    0.000    5736.0
# 1|userID[s_1018] -0.042  0.030  -0.098    0.015        0.0    0.000    5717.0
# 1|userID[s_1024]  0.041  0.030  -0.017    0.096        0.0    0.000    5379.0
# 1|userID[s_1029]  0.028  0.030  -0.027    0.085        0.0    0.000    6718.0
# 1|userID[s_1031]  0.013  0.031  -0.048    0.068        0.0    0.000    6782.0
# 1|userID[s_1035]  0.067  0.030   0.009    0.120        0.0    0.000    5895.0
# 1|userID[s_1037] -0.084  0.029  -0.139   -0.029        0.0    0.000    6082.0
# 1|userID[s_1041]  0.030  0.030  -0.027    0.087        0.0    0.000    5633.0
# 1|userID[s_1054]  0.007  0.030  -0.048    0.064        0.0    0.001    6856.0
# 1|userID[s_1059]  0.068  0.030   0.014    0.126        0.0    0.000    6544.0
# 1|userID[s_1066] -0.038  0.031  -0.098    0.020        0.0    0.000    7046.0
# 1|userID[s_1075]  0.063  0.031   0.006    0.123        0.0    0.000    6207.0
# 1|userID[s_1089]  0.112  0.030   0.057    0.171        0.0    0.000    6550.0
# 1|userID[s_1090] -0.058  0.030  -0.113   -0.003        0.0    0.000    6537.0
# 1|userID[s_1094] -0.007  0.031  -0.064    0.050        0.0    0.001    5950.0
# 1|userID[s_1099]  0.067  0.030   0.006    0.122        0.0    0.000    6614.0
# 1|userID[s_1117]  0.035  0.030  -0.022    0.091        0.0    0.000    6103.0
# 1|userID[s_112]  -0.004  0.031  -0.062    0.055        0.0    0.001    7764.0
# 1|userID[s_1121]  0.072  0.030   0.016    0.129        0.0    0.000    6026.0
# 1|userID[s_1124] -0.018  0.031  -0.078    0.037        0.0    0.000    5497.0
# 1|userID[s_128]  -0.091  0.031  -0.147   -0.031        0.0    0.000    6651.0
# 1|userID[s_139]  -0.128  0.030  -0.183   -0.073        0.0    0.000    5831.0
# 1|userID[s_168]   0.144  0.031   0.089    0.204        0.0    0.000    6427.0
# 1|userID[s_184]  -0.157  0.030  -0.211   -0.099        0.0    0.000    6884.0
# 1|userID[s_189]   0.080  0.031   0.020    0.135        0.0    0.000    6771.0
# 1|userID[s_200]  -0.040  0.030  -0.093    0.020        0.0    0.000    7406.0
# 1|userID[s_204]  -0.088  0.030  -0.146   -0.035        0.0    0.000    5718.0
# 1|userID[s_218]   0.088  0.030   0.031    0.146        0.0    0.000    6247.0
# 1|userID[s_222]  -0.061  0.031  -0.120   -0.005        0.0    0.000    6360.0
# 1|userID[s_225]   0.097  0.030   0.038    0.151        0.0    0.000    5587.0
#
#                   ess_tail  r_hat
# 1|userID[s_1010]    2950.0   1.00
# 1|userID[s_1018]    2730.0   1.00
# 1|userID[s_1024]    2837.0   1.00
# 1|userID[s_1029]    2869.0   1.00
# 1|userID[s_1031]    2937.0   1.00
# 1|userID[s_1035]    2811.0   1.00
# 1|userID[s_1037]    2953.0   1.00
# 1|userID[s_1041]    2738.0   1.00
# 1|userID[s_1054]    2850.0   1.00
# 1|userID[s_1059]    2208.0   1.00
# 1|userID[s_1066]    2927.0   1.00
# 1|userID[s_1075]    2002.0   1.01
# 1|userID[s_1089]    3094.0   1.00
# 1|userID[s_1090]    2559.0   1.00
# 1|userID[s_1094]    2340.0   1.00
# 1|userID[s_1099]    3056.0   1.00
# 1|userID[s_1117]    2824.0   1.00
# 1|userID[s_112]     2850.0   1.01
# 1|userID[s_1121]    2867.0   1.00
# 1|userID[s_1124]    2513.0   1.00
# 1|userID[s_128]     2777.0   1.00
# 1|userID[s_139]     2862.0   1.00
# 1|userID[s_168]     2858.0   1.00
# 1|userID[s_184]     3021.0   1.00
# 1|userID[s_189]     2555.0   1.00
# 1|userID[s_200]     2460.0   1.00
# 1|userID[s_204]     2614.0   1.00
# 1|userID[s_218]     2450.0   1.00
# 1|userID[s_222]     3036.0   1.00
# 1|userID[s_225]     2701.0   1.00
# ...
#
#                                                      mean     sd  hdi_3%  \
# 1|userID[s_880]                                    -0.150  0.031  -0.209
# 1|userID[s_881]                                     0.039  0.030  -0.022
# 1|userID[s_888]                                    -0.081  0.030  -0.139
# 1|userID[s_902]                                     0.011  0.030  -0.044
# 1|userID[s_907]                                    -0.080  0.030  -0.137
# 1|userID[s_908]                                     0.029  0.031  -0.026
# 1|userID[s_916]                                     0.088  0.030   0.028
# 1|userID[s_920]                                    -0.072  0.031  -0.130
# 1|userID[s_926]                                     0.106  0.029   0.053
# 1|userID[s_928]                                     0.047  0.030  -0.008
# 1|userID[s_933]                                    -0.010  0.030  -0.065
# 1|userID[s_967]                                     0.131  0.031   0.068
# 1|userID[s_973]                                    -0.041  0.031  -0.098
# 1|userID[s_981]                                     0.041  0.030  -0.017
# 1|userID[s_986]                                    -0.011  0.031  -0.070
# 1|userID[s_990]                                     0.055  0.030  -0.000
# 1|userID_sigma                                      0.084  0.006   0.073
# C(task, levels=base_lvl)[Matching]                  0.107  0.013   0.084
# C(task, levels=base_lvl)[Unfilled Delay]            0.009  0.013  -0.014
# C(task, levels=base_lvl)[Filled Delay - emotions]  -0.084  0.013  -0.110
# C(task, levels=base_lvl):difficulty[Matching, 2]   -0.009  0.018  -0.042
# C(task, levels=base_lvl):difficulty[Matching, 3]   -0.017  0.018  -0.053
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.002  0.018  -0.033
# C(task, levels=base_lvl):difficulty[Unfilled De... -0.021  0.018  -0.054
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.015  0.018  -0.018
# C(task, levels=base_lvl):difficulty[Filled Dela...  0.018  0.018  -0.015
# Intercept                                           0.786  0.012   0.764
# difficulty[2]                                      -0.027  0.013  -0.050
# difficulty[3]                                      -0.077  0.013  -0.100
# sigma                                               0.110  0.002   0.106
#
#                                                     hdi_97%  mcse_mean  \
# 1|userID[s_880]                                      -0.090        0.0
# 1|userID[s_881]                                       0.092        0.0
# 1|userID[s_888]                                      -0.026        0.0
# 1|userID[s_902]                                       0.069        0.0
# 1|userID[s_907]                                      -0.025        0.0
# 1|userID[s_908]                                       0.088        0.0
# 1|userID[s_916]                                       0.142        0.0
# 1|userID[s_920]                                      -0.015        0.0
# 1|userID[s_926]                                       0.161        0.0
# 1|userID[s_928]                                       0.103        0.0
# 1|userID[s_933]                                       0.048        0.0
# 1|userID[s_967]                                       0.186        0.0
# 1|userID[s_973]                                       0.016        0.0
# 1|userID[s_981]                                       0.097        0.0
# 1|userID[s_986]                                       0.045        0.0
# 1|userID[s_990]                                       0.113        0.0
# 1|userID_sigma                                        0.094        0.0
# C(task, levels=base_lvl)[Matching]                    0.132        0.0
# C(task, levels=base_lvl)[Unfilled Delay]              0.034        0.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    -0.062        0.0
# C(task, levels=base_lvl):difficulty[Matching, 2]      0.026        0.0
# C(task, levels=base_lvl):difficulty[Matching, 3]      0.015        0.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.035        0.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.016        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.050        0.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.052        0.0
# Intercept                                             0.808        0.0
# difficulty[2]                                        -0.001        0.0
# difficulty[3]                                        -0.052        0.0
# sigma                                                 0.113        0.0
#
#                                                     mcse_sd  ess_bulk  \
# 1|userID[s_880]                                       0.000    6468.0
# 1|userID[s_881]                                       0.000    7067.0
# 1|userID[s_888]                                       0.000    6203.0
# 1|userID[s_902]                                       0.000    5790.0
# 1|userID[s_907]                                       0.000    6447.0
# 1|userID[s_908]                                       0.000    7805.0
# 1|userID[s_916]                                       0.000    7093.0
# 1|userID[s_920]                                       0.000    6818.0
# 1|userID[s_926]                                       0.000    5558.0
# 1|userID[s_928]                                       0.000    5929.0
# 1|userID[s_933]                                       0.001    6408.0
# 1|userID[s_967]                                       0.000    5667.0
# 1|userID[s_973]                                       0.000    7619.0
# 1|userID[s_981]                                       0.000    6173.0
# 1|userID[s_986]                                       0.001    7870.0
# 1|userID[s_990]                                       0.000    6733.0
# 1|userID_sigma                                        0.000    1188.0
# C(task, levels=base_lvl)[Matching]                    0.000    2125.0
# C(task, levels=base_lvl)[Unfilled Delay]              0.000    2157.0
# C(task, levels=base_lvl)[Filled Delay - emotions]     0.000    2138.0
# C(task, levels=base_lvl):difficulty[Matching, 2]      0.000    2319.0
# C(task, levels=base_lvl):difficulty[Matching, 3]      0.000    2322.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.000    2294.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    0.000    2254.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2262.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    0.000    2318.0
# Intercept                                             0.000    1206.0
# difficulty[2]                                         0.000    1849.0
# difficulty[3]                                         0.000    1880.0
# sigma                                                 0.000    6649.0
#
#                                                     ess_tail  r_hat
# 1|userID[s_880]                                       2779.0    1.0
# 1|userID[s_881]                                       2520.0    1.0
# 1|userID[s_888]                                       2708.0    1.0
# 1|userID[s_902]                                       3315.0    1.0
# 1|userID[s_907]                                       2959.0    1.0
# 1|userID[s_908]                                       2863.0    1.0
# 1|userID[s_916]                                       3262.0    1.0
# 1|userID[s_920]                                       2594.0    1.0
# 1|userID[s_926]                                       2791.0    1.0
# 1|userID[s_928]                                       2704.0    1.0
# 1|userID[s_933]                                       2500.0    1.0
# 1|userID[s_967]                                       2433.0    1.0
# 1|userID[s_973]                                       2840.0    1.0
# 1|userID[s_981]                                       2274.0    1.0
# 1|userID[s_986]                                       2606.0    1.0
# 1|userID[s_990]                                       2774.0    1.0
# 1|userID_sigma                                        2231.0    1.0
# C(task, levels=base_lvl)[Matching]                    2998.0    1.0
# C(task, levels=base_lvl)[Unfilled Delay]              2809.0    1.0
# C(task, levels=base_lvl)[Filled Delay - emotions]     2862.0    1.0
# C(task, levels=base_lvl):difficulty[Matching, 2]      3064.0    1.0
# C(task, levels=base_lvl):difficulty[Matching, 3]      2639.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    2746.0    1.0
# C(task, levels=base_lvl):difficulty[Unfilled De...    3058.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    2926.0    1.0
# C(task, levels=base_lvl):difficulty[Filled Dela...    3308.0    1.0
# Intercept                                             2092.0    1.0
# difficulty[2]                                         2454.0    1.0
# difficulty[3]                                         2581.0    1.0
# sigma                                                 2946.0    1.0
#
# Fitting formula correct_flt ~ C(task, levels=base_lvl) + difficulty + (1|userID)
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# 1|userID[s_1010] -0.052  0.030  -0.107    0.007        0.0    0.000    6142.0
# 1|userID[s_1018] -0.041  0.029  -0.095    0.014        0.0    0.000    5943.0
# 1|userID[s_1024]  0.041  0.031  -0.016    0.098        0.0    0.000    7384.0
# 1|userID[s_1029]  0.027  0.030  -0.026    0.083        0.0    0.000    5835.0
# 1|userID[s_1031]  0.013  0.030  -0.038    0.072        0.0    0.000    6674.0
# 1|userID[s_1035]  0.068  0.030   0.012    0.123        0.0    0.000    6217.0
# 1|userID[s_1037] -0.085  0.031  -0.140   -0.024        0.0    0.000    6408.0
# 1|userID[s_1041]  0.031  0.031  -0.028    0.085        0.0    0.000    6575.0
# 1|userID[s_1054]  0.007  0.030  -0.051    0.063        0.0    0.000    7203.0
# 1|userID[s_1059]  0.069  0.030   0.012    0.124        0.0    0.000    6330.0
# 1|userID[s_1066] -0.037  0.031  -0.098    0.019        0.0    0.000    6836.0
# 1|userID[s_1075]  0.064  0.030   0.009    0.120        0.0    0.000    5468.0
# 1|userID[s_1089]  0.113  0.030   0.060    0.172        0.0    0.000    6433.0
# 1|userID[s_1090] -0.058  0.030  -0.114   -0.000        0.0    0.000    5986.0
# 1|userID[s_1094] -0.007  0.030  -0.064    0.048        0.0    0.000    6610.0
# 1|userID[s_1099]  0.067  0.031   0.009    0.125        0.0    0.000    6097.0
# 1|userID[s_1117]  0.035  0.030  -0.023    0.092        0.0    0.000    6665.0
# 1|userID[s_112]  -0.004  0.030  -0.060    0.052        0.0    0.001    6548.0
# 1|userID[s_1121]  0.072  0.030   0.012    0.127        0.0    0.000    6333.0
# 1|userID[s_1124] -0.018  0.031  -0.075    0.039        0.0    0.000    6554.0
# 1|userID[s_128]  -0.090  0.030  -0.147   -0.036        0.0    0.000    5429.0
# 1|userID[s_139]  -0.127  0.030  -0.187   -0.073        0.0    0.000    5799.0
# 1|userID[s_168]   0.144  0.030   0.092    0.201        0.0    0.000    5312.0
# 1|userID[s_184]  -0.156  0.030  -0.210   -0.098        0.0    0.000    6084.0
# 1|userID[s_189]   0.080  0.030   0.023    0.135        0.0    0.000    6360.0
# 1|userID[s_200]  -0.039  0.030  -0.098    0.015        0.0    0.000    6792.0
# 1|userID[s_204]  -0.088  0.030  -0.145   -0.032        0.0    0.000    5382.0
# 1|userID[s_218]   0.087  0.030   0.031    0.144        0.0    0.000    6570.0
# 1|userID[s_222]  -0.061  0.030  -0.118   -0.003        0.0    0.000    6535.0
# 1|userID[s_225]   0.096  0.030   0.040    0.151        0.0    0.000    6827.0
#
#                   ess_tail  r_hat
# 1|userID[s_1010]    2993.0    1.0
# 1|userID[s_1018]    2779.0    1.0
# 1|userID[s_1024]    2890.0    1.0
# 1|userID[s_1029]    2562.0    1.0
# 1|userID[s_1031]    2397.0    1.0
# 1|userID[s_1035]    2740.0    1.0
# 1|userID[s_1037]    2966.0    1.0
# 1|userID[s_1041]    2678.0    1.0
# 1|userID[s_1054]    2865.0    1.0
# 1|userID[s_1059]    3373.0    1.0
# 1|userID[s_1066]    2833.0    1.0
# 1|userID[s_1075]    2518.0    1.0
# 1|userID[s_1089]    2638.0    1.0
# 1|userID[s_1090]    2873.0    1.0
# 1|userID[s_1094]    3170.0    1.0
# 1|userID[s_1099]    2776.0    1.0
# 1|userID[s_1117]    2522.0    1.0
# 1|userID[s_112]     2931.0    1.0
# 1|userID[s_1121]    2814.0    1.0
# 1|userID[s_1124]    2866.0    1.0
# 1|userID[s_128]     2684.0    1.0
# 1|userID[s_139]     2676.0    1.0
# 1|userID[s_168]     3075.0    1.0
# 1|userID[s_184]     2983.0    1.0
# 1|userID[s_189]     2697.0    1.0
# 1|userID[s_200]     2904.0    1.0
# 1|userID[s_204]     2538.0    1.0
# 1|userID[s_218]     3160.0    1.0
# 1|userID[s_222]     3052.0    1.0
# 1|userID[s_225]     2431.0    1.0
# ...
#
#                                                     mean     sd  hdi_3%  \
# 1|userID[s_841]                                    0.149  0.030   0.093
# 1|userID[s_850]                                    0.062  0.030   0.004
# 1|userID[s_856]                                   -0.015  0.030  -0.073
# 1|userID[s_857]                                   -0.018  0.029  -0.073
# 1|userID[s_866]                                   -0.016  0.031  -0.073
# 1|userID[s_88]                                     0.048  0.030  -0.010
# 1|userID[s_880]                                   -0.150  0.031  -0.207
# 1|userID[s_881]                                    0.039  0.030  -0.016
# 1|userID[s_888]                                   -0.080  0.031  -0.139
# 1|userID[s_902]                                    0.011  0.030  -0.048
# 1|userID[s_907]                                   -0.080  0.032  -0.141
# 1|userID[s_908]                                    0.029  0.031  -0.029
# 1|userID[s_916]                                    0.087  0.030   0.032
# 1|userID[s_920]                                   -0.072  0.030  -0.132
# 1|userID[s_926]                                    0.106  0.031   0.050
# 1|userID[s_928]                                    0.047  0.030  -0.008
# 1|userID[s_933]                                   -0.010  0.030  -0.064
# 1|userID[s_967]                                    0.131  0.030   0.080
# 1|userID[s_973]                                   -0.041  0.030  -0.099
# 1|userID[s_981]                                    0.040  0.031  -0.017
# 1|userID[s_986]                                   -0.011  0.031  -0.070
# 1|userID[s_990]                                    0.055  0.031   0.001
# 1|userID_sigma                                     0.084  0.006   0.073
# C(task, levels=base_lvl)[Matching]                 0.098  0.007   0.085
# C(task, levels=base_lvl)[Unfilled Delay]           0.002  0.007  -0.012
# C(task, levels=base_lvl)[Filled Delay - emotions] -0.074  0.007  -0.088
# Intercept                                          0.787  0.009   0.771
# difficulty[2]                                     -0.025  0.006  -0.037
# difficulty[3]                                     -0.082  0.006  -0.094
# sigma                                              0.110  0.002   0.106
#
#                                                    hdi_97%  mcse_mean  \
# 1|userID[s_841]                                      0.209        0.0
# 1|userID[s_850]                                      0.117        0.0
# 1|userID[s_856]                                      0.041        0.0
# 1|userID[s_857]                                      0.034        0.0
# 1|userID[s_866]                                      0.041        0.0
# 1|userID[s_88]                                       0.102        0.0
# 1|userID[s_880]                                     -0.093        0.0
# 1|userID[s_881]                                      0.095        0.0
# 1|userID[s_888]                                     -0.025        0.0
# 1|userID[s_902]                                      0.063        0.0
# 1|userID[s_907]                                     -0.021        0.0
# 1|userID[s_908]                                      0.087        0.0
# 1|userID[s_916]                                      0.145        0.0
# 1|userID[s_920]                                     -0.018        0.0
# 1|userID[s_926]                                      0.165        0.0
# 1|userID[s_928]                                      0.105        0.0
# 1|userID[s_933]                                      0.046        0.0
# 1|userID[s_967]                                      0.191        0.0
# 1|userID[s_973]                                      0.015        0.0
# 1|userID[s_981]                                      0.098        0.0
# 1|userID[s_986]                                      0.044        0.0
# 1|userID[s_990]                                      0.117        0.0
# 1|userID_sigma                                       0.095        0.0
# C(task, levels=base_lvl)[Matching]                   0.112        0.0
# C(task, levels=base_lvl)[Unfilled Delay]             0.015        0.0
# C(task, levels=base_lvl)[Filled Delay - emotions]   -0.060        0.0
# Intercept                                            0.805        0.0
# difficulty[2]                                       -0.014        0.0
# difficulty[3]                                       -0.071        0.0
# sigma                                                0.113        0.0
#
#                                                    mcse_sd  ess_bulk  \
# 1|userID[s_841]                                      0.000    5094.0
# 1|userID[s_850]                                      0.000    6096.0
# 1|userID[s_856]                                      0.000    6211.0
# 1|userID[s_857]                                      0.000    5168.0
# 1|userID[s_866]                                      0.001    5666.0
# 1|userID[s_88]                                       0.000    6250.0
# 1|userID[s_880]                                      0.000    5592.0
# 1|userID[s_881]                                      0.000    6600.0
# 1|userID[s_888]                                      0.000    5230.0
# 1|userID[s_902]                                      0.000    5611.0
# 1|userID[s_907]                                      0.000    6487.0
# 1|userID[s_908]                                      0.000    5887.0
# 1|userID[s_916]                                      0.000    6113.0
# 1|userID[s_920]                                      0.000    6954.0
# 1|userID[s_926]                                      0.000    5372.0
# 1|userID[s_928]                                      0.000    6044.0
# 1|userID[s_933]                                      0.001    6675.0
# 1|userID[s_967]                                      0.000    6297.0
# 1|userID[s_973]                                      0.000    6668.0
# 1|userID[s_981]                                      0.000    5819.0
# 1|userID[s_986]                                      0.000    6530.0
# 1|userID[s_990]                                      0.000    7503.0
# 1|userID_sigma                                       0.000    1337.0
# C(task, levels=base_lvl)[Matching]                   0.000    4981.0
# C(task, levels=base_lvl)[Unfilled Delay]             0.000    5146.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    0.000    5666.0
# Intercept                                            0.000    2126.0
# difficulty[2]                                        0.000    6310.0
# difficulty[3]                                        0.000    6787.0
# sigma                                                0.000    5740.0
#
#                                                    ess_tail  r_hat
# 1|userID[s_841]                                      2568.0    1.0
# 1|userID[s_850]                                      3025.0    1.0
# 1|userID[s_856]                                      2939.0    1.0
# 1|userID[s_857]                                      2590.0    1.0
# 1|userID[s_866]                                      2206.0    1.0
# 1|userID[s_88]                                       3012.0    1.0
# 1|userID[s_880]                                      2797.0    1.0
# 1|userID[s_881]                                      2943.0    1.0
# 1|userID[s_888]                                      2371.0    1.0
# 1|userID[s_902]                                      2494.0    1.0
# 1|userID[s_907]                                      2407.0    1.0
# 1|userID[s_908]                                      2399.0    1.0
# 1|userID[s_916]                                      2815.0    1.0
# 1|userID[s_920]                                      3220.0    1.0
# 1|userID[s_926]                                      2580.0    1.0
# 1|userID[s_928]                                      2912.0    1.0
# 1|userID[s_933]                                      2581.0    1.0
# 1|userID[s_967]                                      2579.0    1.0
# 1|userID[s_973]                                      2659.0    1.0
# 1|userID[s_981]                                      2513.0    1.0
# 1|userID[s_986]                                      2765.0    1.0
# 1|userID[s_990]                                      2769.0    1.0
# 1|userID_sigma                                       1694.0    1.0
# C(task, levels=base_lvl)[Matching]                   2825.0    1.0
# C(task, levels=base_lvl)[Unfilled Delay]             3406.0    1.0
# C(task, levels=base_lvl)[Filled Delay - emotions]    3216.0    1.0
# Intercept                                            2795.0    1.0
# difficulty[2]                                        3154.0    1.0
# difficulty[3]                                        3133.0    1.0
# sigma                                                3061.0    1.0

# %% [markdown]
# ### Compare all data
# [top](#top)

# %%
df_compare_formulas_bernoulli = {}
for f in result_dic_bernoulli.keys():
    print(f, '\n')
    df_compare_formulas_bernoulli[f] = az.compare(result_dic_bernoulli[f])
    
    print(df_compare_formulas_bernoulli[f])
    
    az.plot_compare(df_compare_formulas_bernoulli[f], insample_dev=False);

    
    print()
# df_compare_formulas_bernoulli[f]
# Out:
# dataset_4
#
#                                                     rank     elpd_loo  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...     0  1354.619882
# correct_flt ~ C(task, levels=base_lvl) * diffic...     1  1350.948071
#
#                                                          p_loo  elpd_diff  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  132.749139    0.00000
# correct_flt ~ C(task, levels=base_lvl) * diffic...  139.256601    3.67181
#
#                                                           weight         se  \
# correct_flt ~ C(task, levels=base_lvl) + diffic...  1.000000e+00  30.605306
# correct_flt ~ C(task, levels=base_lvl) * diffic...  1.332268e-15  30.872860
#
#                                                          dse  warning scale
# correct_flt ~ C(task, levels=base_lvl) + diffic...  0.000000    False   log
# correct_flt ~ C(task, levels=base_lvl) * diffic...  2.686555    False   log

# %%
fig, ax = plt.subplots(figsize=(8, 4))
az.plot_forest(
    result_dic_bernoulli['dataset_4']['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'],
#     model_names=['Dataset 4'],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.56, -.02), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
az.plot_forest(
    list(result_dic_bernoulli['dataset_4'].values()),
    model_names=[f'{f}\n{formula}' for f in result_dic_bernoulli.keys() for formula in formulas2run],
    var_names=["Intercept", "difficulty", "C(task, levels=base_lvl)"],
    combined=True,
    ax=ax
)

ax.axvline(0, c='k')

# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="lower right", bbox_to_anchor=(1.69, .42), ncols=1)
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
az.plot_forest(
    (list(result_dic_bernoulli['dataset_4'].values())
    )[::2],
#     model_names=[f'{f}' for f in result_dic_bernoulli.keys()],
    var_names=["C(task, levels=base_lvl):difficulty"],
    combined=True,
#     figsize=(12, 10)
    ax=ax
);

ax.axvline(0, c='k')

# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
# # plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
# plt.show()


# manually adjust the legend, there is some weird bug
legend = ax.get_legend()
labels = [] if legend is None else [str(x._text) for x in legend.texts]
handles = [] if legend is None else legend.legend_handles
ax.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.6, 1))
# plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust plot area to make space for the legend
plt.show()

# %% [markdown]
# ### Run some predictions
# [top](#top)

# %%
interactions = ['Matching, 2', 'Matching, 3', 'Unfilled Delay, 2', 'Unfilled Delay, 3', 'Filled Delay - emotions, 2', 'Filled Delay - emotions, 3']
fm2, fm3, d2, d3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]

# %%
_, ax = plt.subplots()
for idx, x in enumerate([fm2, fm3, d2, d3, i2, i3]):
    az.plot_dist(x, label=x["C(task, levels=base_lvl):difficulty_dim"].item(), plot_kwargs={"color": f"C{idx}"}, ax=ax)
ax.legend(loc="upper left");

# %%
# Probability that the FM slope is less than 0

print(f"""
Probability that the UD slope is less than 0:
level 2: {(d2 < 0).mean().item()}
level 3: {(d3 < 0).mean().item()}
""")
# Out:
# Probability that the UD slope is less than 0:
# level 2: 0.53325
# level 3: 0.86975

# %% [markdown]
# ---

# %%
for f in result_dic_bernoulli.keys():

    fm2, fm3, d2, d3, i2, i3 = [result_dic_bernoulli[f]['correct_flt ~ C(task, levels=base_lvl) * difficulty + (1|userID)'].posterior["C(task, levels=base_lvl):difficulty"].sel({"C(task, levels=base_lvl):difficulty_dim":tsk}) for tsk in interactions]
    print(f"""
Experiment {f}:    
  Probability that the Matching slope is less than 0:
    level 2: {(fm2 < 0).mean().item()}
    level 3: {(fm3 < 0).mean().item()}

  Probability that the UD slope is less than 0:
    level 2: {(d2 < 0).mean().item()}
    level 3: {(d3 < 0).mean().item()}
    
  Probability that the FD-e slope is less than 0:
    level 2: {(i2 < 0).mean().item()}
    level 3: {(i3 < 0).mean().item()}
    
    """)
# Out:
# Experiment dataset_4:
#   Probability that the Matching slope is less than 0:
#     level 2: 0.6965
#     level 3: 0.83225
#
#   Probability that the UD slope is less than 0:
#     level 2: 0.53325
#     level 3: 0.86975
#
#   Probability that the FD-e slope is less than 0:
#     level 2: 0.20775
#     level 3: 0.15675

# %% [markdown]
# ### Save the inference
# [top](#top)
#
# It could be possible to use this:
# ```
# result_dic_bernoulli['dataset_4']['correct_flt ~ task * difficulty + (1|userID)'].to_netcdf()
# ```
#
# but it doesn't preserve the dictionary, so I use pickle.

# %%
# save the dictionary to a pickle file
with open(opj(path_inference_data,'FMP_math_baselineMath_inference_data_dict.pkl'), 'wb') as f:
    pickle.dump(result_dic_bernoulli['dataset_4'], f)

# %%
# # Load the dictionary from the pickle file
# with open(opj(path_inference_data,'FMP_math_baselineMath_inference_data_dict.pkl'), 'rb') as f:
#     loaded_inference_data_dict = pickle.load(f)

# %%
# %load_ext watermark

# %watermark -a 'Jan Kadlec' -nmvu -iv -iv -w -p pytensor
# Out:
# Author: Jan Kadlec
#
# Last updated: Fri May 16 2025
#
# Python implementation: CPython
# Python version       : 3.12.5
# IPython version      : 8.25.0
#
# pytensor: 2.23.0
#
# Compiler    : GCC 12.4.0
# OS          : Linux
# Release     : 5.14.0-427.42.1.el9_4.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 96
# Architecture: 64bit
#
# sys       : 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:36:51) [GCC 12.4.0]
# bambi     : 0.14.0
# pandas    : 2.2.2
# matplotlib: 3.9.2
# numpy     : 1.26.4
# arviz     : 0.19.0
#
# Watermark: 2.4.3

# %% [markdown]
# [top](#top)
